# %%
import glob
import re
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
files = glob.glob("weigth stats\*")
len(files)
# Out:
# 83

# %%
class signal:
    def __init__(self, name, ap, TP, FP):
        self.name = name
        self.ap = ap
        self.TP = TP
        self.FP = FP
    
    def printstats(self):
        print("Signal [ name:{}, ap:{}%, tp:{}, fp:{} ]".format(self.name, self.ap, self.TP, self.FP))
    
class signal_summary:
    def __init__(self, TP, FP, FN, average_iou, mean_ap):
        self.TP = TP
        self.FP = FP
        self.FN = FN
        self.average_iou = average_iou
        self.mean_ap = mean_ap   
        
    def printstats(self):
        print("Summary [ TP:{}, FP:{}, FN:{}, averageIoU:{}%, meanAP:{}% ]".format(self.TP, self.FP, self.FN, self.average_iou, self.mean_ap))

# %%
def addSignalToDictionary(dictionary, key, value):
    if key in dictionary:
        dictionary[str(key)] = np.append(dictionary[str(key)], value)
    else:
        dictionary[str(key)] = np.array([value])

# %%
signal_stat = {}

for file in files:
    with open(file, "r") as openfile:
        summary = signal_summary(0,0,0,0,0)
        for line in openfile:
            
            # get single signal data
            if line.startswith("class_id"):
                result_name = re.search("name = .*, ap", line)
                result_ap = re.search("ap = .*%", line)
                result_tp = re.search("TP = .*,", line)
                result_fp = re.search("FP = .*\)", line)

                if result_name is not None and result_ap is not None and result_tp is not None and result_fp is not None:
                    name = result_name.group().replace(", ap","").replace("name = ","")
                    ap = result_ap.group().replace("ap = ","").replace("%","")
                    tp = result_tp.group().replace("TP = ","").replace(",","")
                    fp = result_fp.group().replace("FP = ","").replace(")","")
                    new_signal = signal(name, ap, tp, fp)
                    #new.printstats()
                    addSignalToDictionary(signal_stat, name, new_signal)
                continue
                    
            # get summary
            if line.startswith(" for thresh"):
                result_tp = re.search("TP = .*, FP", line)
                result_fp = re.search("FP = .*, FN", line)
                result_fn = re.search("FN = .*,", line)
                result_iou = re.search("average IoU = .* %", line)
                
                if result_tp is not None and result_fp is not None and result_fn is not None and result_iou is not None:                    
                    summary.TP = result_tp.group().replace("TP = ","").replace(", FP","")
                    summary.FP = result_fp.group().replace("FP = ","").replace(", FN","")
                    summary.FN = result_fn.group().replace("FN = ","").replace(",","")
                    summary.average_iou = result_iou.group().replace("average IoU = ","").replace(" %","")
                continue
                
            # get mean average precision
            if line.startswith(" mean average"):
                result_map = re.search(", or .* %", line)
                if result_map is not None:
                    summary.mean_ap = result_map.group().replace(", or ", "").replace(" %", "")
                    #summary.printstats()
                    addSignalToDictionary(signal_stat, "summary", summary)
                continue


signal_stat
# Out:
# {'white-info-1': array([<__main__.signal object at 0x0000029F5BE5FC88>,
#         <__main__.signal object at 0x0000029F5BE70D68>,
#         <__main__.signal object at 0x0000029F5BE7F198>,
#         <__main__.signal object at 0x0000029F5BE83400>,
#         <__main__.signal object at 0x0000029F5BE86668>,
#         <__main__.signal object at 0x0000029F5BE898D0>,
#         <__main__.signal object at 0x0000029F5BE8DB38>,
#         <__main__.signal object at 0x0000029F5BE91DA0>,
#         <__main__.signal object at 0x0000029F5BE96048>,
#         <__main__.signal object at 0x0000029F5BE992B0>,
#         <__main__.signal object at 0x0000029F5BE9D518>,
#         <__main__.signal object at 0x0000029F5BEA1780>,
#         <__main__.signal object at 0x0000029F5BEA49E8>,
#         <__main__.signal object at 0x0000029F5BEA7C50>,
#         <__main__.signal object at 0x0000029F5BEABEB8>,
#         <__main__.signal object at 0x0000029F5BEB0160>,
#         <__main__.signal object at 0x0000029F5BEB33C8>,
#         <__main__.signal object at 0x0000029F5BEB8630>,
#         <__main__.signal object at 0x0000029F5BEBA898>,
#         <__main__.signal object at 0x0000029F5BEBEB00>,
#         <__main__.signal object at 0x0000029F5BEC2D68>,
#         <__main__.signal object at 0x0000029F5BEC5FD0>,
#         <__main__.signal object at 0x0000029F5BECB278>,
#         <__main__.signal object at 0x0000029F5BECE4E0>,
#         <__main__.signal object at 0x0000029F5BED1748>,
#         <__main__.signal object at 0x0000029F5BED59B0>,
#         <__main__.signal object at 0x0000029F5BED9C18>,
#         <__main__.signal object at 0x0000029F5BEDBE80>,
#         <__main__.signal object at 0x0000029F5BEE1128>,
#         <__main__.signal object at 0x0000029F5BEE5390>,
#         <__main__.signal object at 0x0000029F5BEE85F8>,
#         <__main__.signal object at 0x0000029F5BEEC860>,
#         <__main__.signal object at 0x0000029F5BEEFAC8>,
#         <__main__.signal object at 0x0000029F5BEF3D30>,
#         <__main__.signal object at 0x0000029F5BEF6F98>,
#         <__main__.signal object at 0x0000029F5BEFC240>,
#         <__main__.signal object at 0x0000029F5BF004A8>,
#         <__main__.signal object at 0x0000029F5BF02710>,
#         <__main__.signal object at 0x0000029F5BF07978>,
#         <__main__.signal object at 0x0000029F5BF09BE0>,
#         <__main__.signal object at 0x0000029F5BF0DE48>,
#         <__main__.signal object at 0x0000029F5BF120F0>,
#         <__main__.signal object at 0x0000029F5BF16358>,
#         <__main__.signal object at 0x0000029F5BF1A5C0>,
#         <__main__.signal object at 0x0000029F5BF1D828>,
#         <__main__.signal object at 0x0000029F5BF21A90>,
#         <__main__.signal object at 0x0000029F5BF24CF8>,
#         <__main__.signal object at 0x0000029F5BF28F60>,
#         <__main__.signal object at 0x0000029F5BF2C208>,
#         <__main__.signal object at 0x0000029F5BF30470>,
#         <__main__.signal object at 0x0000029F5BF346D8>,
#         <__main__.signal object at 0x0000029F5BF38940>,
#         <__main__.signal object at 0x0000029F5BF3BBA8>,
#         <__main__.signal object at 0x0000029F5BF3EE10>,
#         <__main__.signal object at 0x0000029F5BF440B8>,
#         <__main__.signal object at 0x0000029F5BF46320>,
#         <__main__.signal object at 0x0000029F5BF4A588>,
#         <__main__.signal object at 0x0000029F5BF4F7F0>,
#         <__main__.signal object at 0x0000029F5BF51A58>,
#         <__main__.signal object at 0x0000029F5BF56CC0>,
#         <__main__.signal object at 0x0000029F5BF59F28>,
#         <__main__.signal object at 0x0000029F5BF5E1D0>,
#         <__main__.signal object at 0x0000029F5BF61438>,
#         <__main__.signal object at 0x0000029F5BF656A0>,
#         <__main__.signal object at 0x0000029F5BF67908>,
#         <__main__.signal object at 0x0000029F5BF6DB70>,
#         <__main__.signal object at 0x0000029F5BF71DD8>,
#         <__main__.signal object at 0x0000029F5BF76080>,
#         <__main__.signal object at 0x0000029F5BF792E8>,
#         <__main__.signal object at 0x0000029F5BF7C550>,
#         <__main__.signal object at 0x0000029F5BF817B8>,
#         <__main__.signal object at 0x0000029F5BF83A20>,
#         <__main__.signal object at 0x0000029F5BF87C88>,
#         <__main__.signal object at 0x0000029F5BF8BEF0>,
#         <__main__.signal object at 0x0000029F5BF8F198>,
#         <__main__.signal object at 0x0000029F5BF94400>,
#         <__main__.signal object at 0x0000029F5BF97668>,
#         <__main__.signal object at 0x0000029F5BF9A8D0>,
#         <__main__.signal object at 0x0000029F5BF9EB38>,
#         <__main__.signal object at 0x0000029F5BFA2DA0>,
#         <__main__.signal object at 0x0000029F5BFA8048>,
#         <__main__.signal object at 0x0000029F5BFAA2B0>,
#         <__main__.signal object at 0x0000029F5BFAE518>], dtype=object),
#  'white-info-2': array([<__main__.signal object at 0x0000029F5BE5FDD8>,
#         <__main__.signal object at 0x0000029F5BE70FD0>,
#         <__main__.signal object at 0x0000029F5BE7F278>,
#         <__main__.signal object at 0x0000029F5BE834E0>,
#         <__main__.signal object at 0x0000029F5BE86748>,
#         <__main__.signal object at 0x0000029F5BE899B0>,
#         <__main__.signal object at 0x0000029F5BE8DC18>,
#         <__main__.signal object at 0x0000029F5BE91E80>,
#         <__main__.signal object at 0x0000029F5BE96128>,
#         <__main__.signal object at 0x0000029F5BE99390>,
#         <__main__.signal object at 0x0000029F5BE9D5F8>,
#         <__main__.signal object at 0x0000029F5BEA1860>,
#         <__main__.signal object at 0x0000029F5BEA4AC8>,
#         <__main__.signal object at 0x0000029F5BEA7D30>,
#         <__main__.signal object at 0x0000029F5BEABF98>,
#         <__main__.signal object at 0x0000029F5BEB0240>,
#         <__main__.signal object at 0x0000029F5BEB34A8>,
#         <__main__.signal object at 0x0000029F5BEB8710>,
#         <__main__.signal object at 0x0000029F5BEBA978>,
#         <__main__.signal object at 0x0000029F5BEBEBE0>,
#         <__main__.signal object at 0x0000029F5BEC2E48>,
#         <__main__.signal object at 0x0000029F5BEC60F0>,
#         <__main__.signal object at 0x0000029F5BECB358>,
#         <__main__.signal object at 0x0000029F5BECE5C0>,
#         <__main__.signal object at 0x0000029F5BED1828>,
#         <__main__.signal object at 0x0000029F5BED5A90>,
#         <__main__.signal object at 0x0000029F5BED9CF8>,
#         <__main__.signal object at 0x0000029F5BEDBF60>,
#         <__main__.signal object at 0x0000029F5BEE1208>,
#         <__main__.signal object at 0x0000029F5BEE5470>,
#         <__main__.signal object at 0x0000029F5BEE86D8>,
#         <__main__.signal object at 0x0000029F5BEEC940>,
#         <__main__.signal object at 0x0000029F5BEEFBA8>,
#         <__main__.signal object at 0x0000029F5BEF3E10>,
#         <__main__.signal object at 0x0000029F5BEF70B8>,
#         <__main__.signal object at 0x0000029F5BEFC320>,
#         <__main__.signal object at 0x0000029F5BF00588>,
#         <__main__.signal object at 0x0000029F5BF027F0>,
#         <__main__.signal object at 0x0000029F5BF07A58>,
#         <__main__.signal object at 0x0000029F5BF09CC0>,
#         <__main__.signal object at 0x0000029F5BF0DF28>,
#         <__main__.signal object at 0x0000029F5BF121D0>,
#         <__main__.signal object at 0x0000029F5BF16438>,
#         <__main__.signal object at 0x0000029F5BF1A6A0>,
#         <__main__.signal object at 0x0000029F5BF1D908>,
#         <__main__.signal object at 0x0000029F5BF21B70>,
#         <__main__.signal object at 0x0000029F5BF24DD8>,
#         <__main__.signal object at 0x0000029F5BF29080>,
#         <__main__.signal object at 0x0000029F5BF2C2E8>,
#         <__main__.signal object at 0x0000029F5BF30550>,
#         <__main__.signal object at 0x0000029F5BF347B8>,
#         <__main__.signal object at 0x0000029F5BF38A20>,
#         <__main__.signal object at 0x0000029F5BF3BC88>,
#         <__main__.signal object at 0x0000029F5BF3EEF0>,
#         <__main__.signal object at 0x0000029F5BF44198>,
#         <__main__.signal object at 0x0000029F5BF46400>,
#         <__main__.signal object at 0x0000029F5BF4A668>,
#         <__main__.signal object at 0x0000029F5BF4F8D0>,
#         <__main__.signal object at 0x0000029F5BF51B38>,
#         <__main__.signal object at 0x0000029F5BF56DA0>,
#         <__main__.signal object at 0x0000029F5BF5A048>,
#         <__main__.signal object at 0x0000029F5BF5E2B0>,
#         <__main__.signal object at 0x0000029F5BF61518>,
#         <__main__.signal object at 0x0000029F5BF65780>,
#         <__main__.signal object at 0x0000029F5BF679E8>,
#         <__main__.signal object at 0x0000029F5BF6DC50>,
#         <__main__.signal object at 0x0000029F5BF71EB8>,
#         <__main__.signal object at 0x0000029F5BF76160>,
#         <__main__.signal object at 0x0000029F5BF793C8>,
#         <__main__.signal object at 0x0000029F5BF7C630>,
#         <__main__.signal object at 0x0000029F5BF81898>,
#         <__main__.signal object at 0x0000029F5BF83B00>,
#         <__main__.signal object at 0x0000029F5BF87D68>,
#         <__main__.signal object at 0x0000029F5BF8BFD0>,
#         <__main__.signal object at 0x0000029F5BF8F278>,
#         <__main__.signal object at 0x0000029F5BF944E0>,
#         <__main__.signal object at 0x0000029F5BF97748>,
#         <__main__.signal object at 0x0000029F5BF9A9B0>,
#         <__main__.signal object at 0x0000029F5BF9EC18>,
#         <__main__.signal object at 0x0000029F5BFA2E80>,
#         <__main__.signal object at 0x0000029F5BFA8128>,
#         <__main__.signal object at 0x0000029F5BFAA390>,
#         <__main__.signal object at 0x0000029F5BFAE5F8>], dtype=object),
#  'white-info-3': array([<__main__.signal object at 0x0000029F5BE5FEB8>,
#         <__main__.signal object at 0x0000029F5BE760F0>,
#         <__main__.signal object at 0x0000029F5BE7F358>,
#         <__main__.signal object at 0x0000029F5BE835C0>,
#         <__main__.signal object at 0x0000029F5BE86828>,
#         <__main__.signal object at 0x0000029F5BE89A90>,
#         <__main__.signal object at 0x0000029F5BE8DCF8>,
#         <__main__.signal object at 0x0000029F5BE91F60>,
#         <__main__.signal object at 0x0000029F5BE96208>,
#         <__main__.signal object at 0x0000029F5BE99470>,
#         <__main__.signal object at 0x0000029F5BE9D6D8>,
#         <__main__.signal object at 0x0000029F5BEA1940>,
#         <__main__.signal object at 0x0000029F5BEA4BA8>,
#         <__main__.signal object at 0x0000029F5BEA7E10>,
#         <__main__.signal object at 0x0000029F5BEAD0B8>,
#         <__main__.signal object at 0x0000029F5BEB0320>,
#         <__main__.signal object at 0x0000029F5BEB3588>,
#         <__main__.signal object at 0x0000029F5BEB87F0>,
#         <__main__.signal object at 0x0000029F5BEBAA58>,
#         <__main__.signal object at 0x0000029F5BEBECC0>,
#         <__main__.signal object at 0x0000029F5BEC2F28>,
#         <__main__.signal object at 0x0000029F5BEC61D0>,
#         <__main__.signal object at 0x0000029F5BECB438>,
#         <__main__.signal object at 0x0000029F5BECE6A0>,
#         <__main__.signal object at 0x0000029F5BED1908>,
#         <__main__.signal object at 0x0000029F5BED5B70>,
#         <__main__.signal object at 0x0000029F5BED9DD8>,
#         <__main__.signal object at 0x0000029F5BEDF080>,
#         <__main__.signal object at 0x0000029F5BEE12E8>,
#         <__main__.signal object at 0x0000029F5BEE5550>,
#         <__main__.signal object at 0x0000029F5BEE87B8>,
#         <__main__.signal object at 0x0000029F5BEECA20>,
#         <__main__.signal object at 0x0000029F5BEEFC88>,
#         <__main__.signal object at 0x0000029F5BEF3EF0>,
#         <__main__.signal object at 0x0000029F5BEF7198>,
#         <__main__.signal object at 0x0000029F5BEFC400>,
#         <__main__.signal object at 0x0000029F5BF00668>,
#         <__main__.signal object at 0x0000029F5BF028D0>,
#         <__main__.signal object at 0x0000029F5BF07B38>,
#         <__main__.signal object at 0x0000029F5BF09DA0>,
#         <__main__.signal object at 0x0000029F5BF0F048>,
#         <__main__.signal object at 0x0000029F5BF122B0>,
#         <__main__.signal object at 0x0000029F5BF16518>,
#         <__main__.signal object at 0x0000029F5BF1A780>,
#         <__main__.signal object at 0x0000029F5BF1D9E8>,
#         <__main__.signal object at 0x0000029F5BF21C50>,
#         <__main__.signal object at 0x0000029F5BF24EB8>,
#         <__main__.signal object at 0x0000029F5BF29160>,
#         <__main__.signal object at 0x0000029F5BF2C3C8>,
#         <__main__.signal object at 0x0000029F5BF30630>,
#         <__main__.signal object at 0x0000029F5BF34898>,
#         <__main__.signal object at 0x0000029F5BF38B00>,
#         <__main__.signal object at 0x0000029F5BF3BD68>,
#         <__main__.signal object at 0x0000029F5BF3EFD0>,
#         <__main__.signal object at 0x0000029F5BF44278>,
#         <__main__.signal object at 0x0000029F5BF464E0>,
#         <__main__.signal object at 0x0000029F5BF4A748>,
#         <__main__.signal object at 0x0000029F5BF4F9B0>,
#         <__main__.signal object at 0x0000029F5BF51C18>,
#         <__main__.signal object at 0x0000029F5BF56E80>,
#         <__main__.signal object at 0x0000029F5BF5A128>,
#         <__main__.signal object at 0x0000029F5BF5E390>,
#         <__main__.signal object at 0x0000029F5BF615F8>,
#         <__main__.signal object at 0x0000029F5BF65860>,
#         <__main__.signal object at 0x0000029F5BF67AC8>,
#         <__main__.signal object at 0x0000029F5BF6DD30>,
#         <__main__.signal object at 0x0000029F5BF71F98>,
#         <__main__.signal object at 0x0000029F5BF76240>,
#         <__main__.signal object at 0x0000029F5BF794A8>,
#         <__main__.signal object at 0x0000029F5BF7C710>,
#         <__main__.signal object at 0x0000029F5BF81978>,
#         <__main__.signal object at 0x0000029F5BF83BE0>,
#         <__main__.signal object at 0x0000029F5BF87E48>,
#         <__main__.signal object at 0x0000029F5BF8D0F0>,
#         <__main__.signal object at 0x0000029F5BF8F358>,
#         <__main__.signal object at 0x0000029F5BF945C0>,
#         <__main__.signal object at 0x0000029F5BF97828>,
#         <__main__.signal object at 0x0000029F5BF9AA90>,
#         <__main__.signal object at 0x0000029F5BF9ECF8>,
#         <__main__.signal object at 0x0000029F5BFA2F60>,
#         <__main__.signal object at 0x0000029F5BFA8208>,
#         <__main__.signal object at 0x0000029F5BFAA470>,
#         <__main__.signal object at 0x0000029F5BFAE6D8>], dtype=object),
#  'white-info-4': array([<__main__.signal object at 0x0000029F5BE5FF98>,
#         <__main__.signal object at 0x0000029F5BE761D0>,
#         <__main__.signal object at 0x0000029F5BE7F438>,
#         <__main__.signal object at 0x0000029F5BE836A0>,
#         <__main__.signal object at 0x0000029F5BE86908>,
#         <__main__.signal object at 0x0000029F5BE89B70>,
#         <__main__.signal object at 0x0000029F5BE8DDD8>,
#         <__main__.signal object at 0x0000029F5BE92080>,
#         <__main__.signal object at 0x0000029F5BE962E8>,
#         <__main__.signal object at 0x0000029F5BE99550>,
#         <__main__.signal object at 0x0000029F5BE9D7B8>,
#         <__main__.signal object at 0x0000029F5BEA1A20>,
#         <__main__.signal object at 0x0000029F5BEA4C88>,
#         <__main__.signal object at 0x0000029F5BEA7EF0>,
#         <__main__.signal object at 0x0000029F5BEAD198>,
#         <__main__.signal object at 0x0000029F5BEB0400>,
#         <__main__.signal object at 0x0000029F5BEB3668>,
#         <__main__.signal object at 0x0000029F5BEB88D0>,
#         <__main__.signal object at 0x0000029F5BEBAB38>,
#         <__main__.signal object at 0x0000029F5BEBEDA0>,
#         <__main__.signal object at 0x0000029F5BEC4048>,
#         <__main__.signal object at 0x0000029F5BEC62B0>,
#         <__main__.signal object at 0x0000029F5BECB518>,
#         <__main__.signal object at 0x0000029F5BECE780>,
#         <__main__.signal object at 0x0000029F5BED19E8>,
#         <__main__.signal object at 0x0000029F5BED5C50>,
#         <__main__.signal object at 0x0000029F5BED9EB8>,
#         <__main__.signal object at 0x0000029F5BEDF160>,
#         <__main__.signal object at 0x0000029F5BEE13C8>,
#         <__main__.signal object at 0x0000029F5BEE5630>,
#         <__main__.signal object at 0x0000029F5BEE8898>,
#         <__main__.signal object at 0x0000029F5BEECB00>,
#         <__main__.signal object at 0x0000029F5BEEFD68>,
#         <__main__.signal object at 0x0000029F5BEF3FD0>,
#         <__main__.signal object at 0x0000029F5BEF7278>,
#         <__main__.signal object at 0x0000029F5BEFC4E0>,
#         <__main__.signal object at 0x0000029F5BF00748>,
#         <__main__.signal object at 0x0000029F5BF029B0>,
#         <__main__.signal object at 0x0000029F5BF07C18>,
#         <__main__.signal object at 0x0000029F5BF09E80>,
#         <__main__.signal object at 0x0000029F5BF0F128>,
#         <__main__.signal object at 0x0000029F5BF12390>,
#         <__main__.signal object at 0x0000029F5BF165F8>,
#         <__main__.signal object at 0x0000029F5BF1A860>,
#         <__main__.signal object at 0x0000029F5BF1DAC8>,
#         <__main__.signal object at 0x0000029F5BF21D30>,
#         <__main__.signal object at 0x0000029F5BF24F98>,
#         <__main__.signal object at 0x0000029F5BF29240>,
#         <__main__.signal object at 0x0000029F5BF2C4A8>,
#         <__main__.signal object at 0x0000029F5BF30710>,
#         <__main__.signal object at 0x0000029F5BF34978>,
#         <__main__.signal object at 0x0000029F5BF38BE0>,
#         <__main__.signal object at 0x0000029F5BF3BE48>,
#         <__main__.signal object at 0x0000029F5BF3F0F0>,
#         <__main__.signal object at 0x0000029F5BF44358>,
#         <__main__.signal object at 0x0000029F5BF465C0>,
#         <__main__.signal object at 0x0000029F5BF4A828>,
#         <__main__.signal object at 0x0000029F5BF4FA90>,
#         <__main__.signal object at 0x0000029F5BF51CF8>,
#         <__main__.signal object at 0x0000029F5BF56F60>,
#         <__main__.signal object at 0x0000029F5BF5A208>,
#         <__main__.signal object at 0x0000029F5BF5E470>,
#         <__main__.signal object at 0x0000029F5BF616D8>,
#         <__main__.signal object at 0x0000029F5BF65940>,
#         <__main__.signal object at 0x0000029F5BF67BA8>,
#         <__main__.signal object at 0x0000029F5BF6DE10>,
#         <__main__.signal object at 0x0000029F5BF720B8>,
#         <__main__.signal object at 0x0000029F5BF76320>,
#         <__main__.signal object at 0x0000029F5BF79588>,
#         <__main__.signal object at 0x0000029F5BF7C7F0>,
#         <__main__.signal object at 0x0000029F5BF81A58>,
#         <__main__.signal object at 0x0000029F5BF83CC0>,
#         <__main__.signal object at 0x0000029F5BF87F28>,
#         <__main__.signal object at 0x0000029F5BF8D1D0>,
#         <__main__.signal object at 0x0000029F5BF8F438>,
#         <__main__.signal object at 0x0000029F5BF946A0>,
#         <__main__.signal object at 0x0000029F5BF97908>,
#         <__main__.signal object at 0x0000029F5BF9AB70>,
#         <__main__.signal object at 0x0000029F5BF9EDD8>,
#         <__main__.signal object at 0x0000029F5BFA3080>,
#         <__main__.signal object at 0x0000029F5BFA82E8>,
#         <__main__.signal object at 0x0000029F5BFAA550>,
#         <__main__.signal object at 0x0000029F5BFAE7B8>], dtype=object),
#  'white-info-5': array([<__main__.signal object at 0x0000029F5BE6A0B8>,
#         <__main__.signal object at 0x0000029F5BE762B0>,
#         <__main__.signal object at 0x0000029F5BE7F518>,
#         <__main__.signal object at 0x0000029F5BE83780>,
#         <__main__.signal object at 0x0000029F5BE869E8>,
#         <__main__.signal object at 0x0000029F5BE89C50>,
#         <__main__.signal object at 0x0000029F5BE8DEB8>,
#         <__main__.signal object at 0x0000029F5BE92160>,
#         <__main__.signal object at 0x0000029F5BE963C8>,
#         <__main__.signal object at 0x0000029F5BE99630>,
#         <__main__.signal object at 0x0000029F5BE9D898>,
#         <__main__.signal object at 0x0000029F5BEA1B00>,
#         <__main__.signal object at 0x0000029F5BEA4D68>,
#         <__main__.signal object at 0x0000029F5BEA7FD0>,
#         <__main__.signal object at 0x0000029F5BEAD278>,
#         <__main__.signal object at 0x0000029F5BEB04E0>,
#         <__main__.signal object at 0x0000029F5BEB3748>,
#         <__main__.signal object at 0x0000029F5BEB89B0>,
#         <__main__.signal object at 0x0000029F5BEBAC18>,
#         <__main__.signal object at 0x0000029F5BEBEE80>,
#         <__main__.signal object at 0x0000029F5BEC4128>,
#         <__main__.signal object at 0x0000029F5BEC6390>,
#         <__main__.signal object at 0x0000029F5BECB5F8>,
#         <__main__.signal object at 0x0000029F5BECE860>,
#         <__main__.signal object at 0x0000029F5BED1AC8>,
#         <__main__.signal object at 0x0000029F5BED5D30>,
#         <__main__.signal object at 0x0000029F5BED9F98>,
#         <__main__.signal object at 0x0000029F5BEDF240>,
#         <__main__.signal object at 0x0000029F5BEE14A8>,
#         <__main__.signal object at 0x0000029F5BEE5710>,
#         <__main__.signal object at 0x0000029F5BEE8978>,
#         <__main__.signal object at 0x0000029F5BEECBE0>,
#         <__main__.signal object at 0x0000029F5BEEFE48>,
#         <__main__.signal object at 0x0000029F5BEF50F0>,
#         <__main__.signal object at 0x0000029F5BEF7358>,
#         <__main__.signal object at 0x0000029F5BEFC5C0>,
#         <__main__.signal object at 0x0000029F5BF00828>,
#         <__main__.signal object at 0x0000029F5BF02A90>,
#         <__main__.signal object at 0x0000029F5BF07CF8>,
#         <__main__.signal object at 0x0000029F5BF09F60>,
#         <__main__.signal object at 0x0000029F5BF0F208>,
#         <__main__.signal object at 0x0000029F5BF12470>,
#         <__main__.signal object at 0x0000029F5BF166D8>,
#         <__main__.signal object at 0x0000029F5BF1A940>,
#         <__main__.signal object at 0x0000029F5BF1DBA8>,
#         <__main__.signal object at 0x0000029F5BF21E10>,
#         <__main__.signal object at 0x0000029F5BF250B8>,
#         <__main__.signal object at 0x0000029F5BF29320>,
#         <__main__.signal object at 0x0000029F5BF2C588>,
#         <__main__.signal object at 0x0000029F5BF307F0>,
#         <__main__.signal object at 0x0000029F5BF34A58>,
#         <__main__.signal object at 0x0000029F5BF38CC0>,
#         <__main__.signal object at 0x0000029F5BF3BF28>,
#         <__main__.signal object at 0x0000029F5BF3F1D0>,
#         <__main__.signal object at 0x0000029F5BF44438>,
#         <__main__.signal object at 0x0000029F5BF466A0>,
#         <__main__.signal object at 0x0000029F5BF4A908>,
#         <__main__.signal object at 0x0000029F5BF4FB70>,
#         <__main__.signal object at 0x0000029F5BF51DD8>,
#         <__main__.signal object at 0x0000029F5BF57080>,
#         <__main__.signal object at 0x0000029F5BF5A2E8>,
#         <__main__.signal object at 0x0000029F5BF5E550>,
#         <__main__.signal object at 0x0000029F5BF617B8>,
#         <__main__.signal object at 0x0000029F5BF65A20>,
#         <__main__.signal object at 0x0000029F5BF67C88>,
#         <__main__.signal object at 0x0000029F5BF6DEF0>,
#         <__main__.signal object at 0x0000029F5BF72198>,
#         <__main__.signal object at 0x0000029F5BF76400>,
#         <__main__.signal object at 0x0000029F5BF79668>,
#         <__main__.signal object at 0x0000029F5BF7C8D0>,
#         <__main__.signal object at 0x0000029F5BF81B38>,
#         <__main__.signal object at 0x0000029F5BF83DA0>,
#         <__main__.signal object at 0x0000029F5BF89048>,
#         <__main__.signal object at 0x0000029F5BF8D2B0>,
#         <__main__.signal object at 0x0000029F5BF8F518>,
#         <__main__.signal object at 0x0000029F5BF94780>,
#         <__main__.signal object at 0x0000029F5BF979E8>,
#         <__main__.signal object at 0x0000029F5BF9AC50>,
#         <__main__.signal object at 0x0000029F5BF9EEB8>,
#         <__main__.signal object at 0x0000029F5BFA3160>,
#         <__main__.signal object at 0x0000029F5BFA83C8>,
#         <__main__.signal object at 0x0000029F5BFAA630>,
#         <__main__.signal object at 0x0000029F5BFAE898>], dtype=object),
#  'white-info-6': array([<__main__.signal object at 0x0000029F5BE6A198>,
#         <__main__.signal object at 0x0000029F5BE76390>,
#         <__main__.signal object at 0x0000029F5BE7F5F8>,
#         <__main__.signal object at 0x0000029F5BE83860>,
#         <__main__.signal object at 0x0000029F5BE86AC8>,
#         <__main__.signal object at 0x0000029F5BE89D30>,
#         <__main__.signal object at 0x0000029F5BE8DF98>,
#         <__main__.signal object at 0x0000029F5BE92240>,
#         <__main__.signal object at 0x0000029F5BE964A8>,
#         <__main__.signal object at 0x0000029F5BE99710>,
#         <__main__.signal object at 0x0000029F5BE9D978>,
#         <__main__.signal object at 0x0000029F5BEA1BE0>,
#         <__main__.signal object at 0x0000029F5BEA4E48>,
#         <__main__.signal object at 0x0000029F5BEA90F0>,
#         <__main__.signal object at 0x0000029F5BEAD358>,
#         <__main__.signal object at 0x0000029F5BEB05C0>,
#         <__main__.signal object at 0x0000029F5BEB3828>,
#         <__main__.signal object at 0x0000029F5BEB8A90>,
#         <__main__.signal object at 0x0000029F5BEBACF8>,
#         <__main__.signal object at 0x0000029F5BEBEF60>,
#         <__main__.signal object at 0x0000029F5BEC4208>,
#         <__main__.signal object at 0x0000029F5BEC6470>,
#         <__main__.signal object at 0x0000029F5BECB6D8>,
#         <__main__.signal object at 0x0000029F5BECE940>,
#         <__main__.signal object at 0x0000029F5BED1BA8>,
#         <__main__.signal object at 0x0000029F5BED5E10>,
#         <__main__.signal object at 0x0000029F5BEDA0B8>,
#         <__main__.signal object at 0x0000029F5BEDF320>,
#         <__main__.signal object at 0x0000029F5BEE1588>,
#         <__main__.signal object at 0x0000029F5BEE57F0>,
#         <__main__.signal object at 0x0000029F5BEE8A58>,
#         <__main__.signal object at 0x0000029F5BEECCC0>,
#         <__main__.signal object at 0x0000029F5BEEFF28>,
#         <__main__.signal object at 0x0000029F5BEF51D0>,
#         <__main__.signal object at 0x0000029F5BEF7438>,
#         <__main__.signal object at 0x0000029F5BEFC6A0>,
#         <__main__.signal object at 0x0000029F5BF00908>,
#         <__main__.signal object at 0x0000029F5BF02B70>,
#         <__main__.signal object at 0x0000029F5BF07DD8>,
#         <__main__.signal object at 0x0000029F5BF0B080>,
#         <__main__.signal object at 0x0000029F5BF0F2E8>,
#         <__main__.signal object at 0x0000029F5BF12550>,
#         <__main__.signal object at 0x0000029F5BF167B8>,
#         <__main__.signal object at 0x0000029F5BF1AA20>,
#         <__main__.signal object at 0x0000029F5BF1DC88>,
#         <__main__.signal object at 0x0000029F5BF21EF0>,
#         <__main__.signal object at 0x0000029F5BF25198>,
#         <__main__.signal object at 0x0000029F5BF29400>,
#         <__main__.signal object at 0x0000029F5BF2C668>,
#         <__main__.signal object at 0x0000029F5BF308D0>,
#         <__main__.signal object at 0x0000029F5BF34B38>,
#         <__main__.signal object at 0x0000029F5BF38DA0>,
#         <__main__.signal object at 0x0000029F5BF3D048>,
#         <__main__.signal object at 0x0000029F5BF3F2B0>,
#         <__main__.signal object at 0x0000029F5BF44518>,
#         <__main__.signal object at 0x0000029F5BF46780>,
#         <__main__.signal object at 0x0000029F5BF4A9E8>,
#         <__main__.signal object at 0x0000029F5BF4FC50>,
#         <__main__.signal object at 0x0000029F5BF51EB8>,
#         <__main__.signal object at 0x0000029F5BF57160>,
#         <__main__.signal object at 0x0000029F5BF5A3C8>,
#         <__main__.signal object at 0x0000029F5BF5E630>,
#         <__main__.signal object at 0x0000029F5BF61898>,
#         <__main__.signal object at 0x0000029F5BF65B00>,
#         <__main__.signal object at 0x0000029F5BF67D68>,
#         <__main__.signal object at 0x0000029F5BF6DFD0>,
#         <__main__.signal object at 0x0000029F5BF72278>,
#         <__main__.signal object at 0x0000029F5BF764E0>,
#         <__main__.signal object at 0x0000029F5BF79748>,
#         <__main__.signal object at 0x0000029F5BF7C9B0>,
#         <__main__.signal object at 0x0000029F5BF81C18>,
#         <__main__.signal object at 0x0000029F5BF83E80>,
#         <__main__.signal object at 0x0000029F5BF89128>,
#         <__main__.signal object at 0x0000029F5BF8D390>,
#         <__main__.signal object at 0x0000029F5BF8F5F8>,
#         <__main__.signal object at 0x0000029F5BF94860>,
#         <__main__.signal object at 0x0000029F5BF97AC8>,
#         <__main__.signal object at 0x0000029F5BF9AD30>,
#         <__main__.signal object at 0x0000029F5BF9EF98>,
#         <__main__.signal object at 0x0000029F5BFA3240>,
#         <__main__.signal object at 0x0000029F5BFA84A8>,
#         <__main__.signal object at 0x0000029F5BFAA710>,
#         <__main__.signal object at 0x0000029F5BFAE978>], dtype=object),
#  'white-info-7': array([<__main__.signal object at 0x0000029F5BE6A278>,
#         <__main__.signal object at 0x0000029F5BE76470>,
#         <__main__.signal object at 0x0000029F5BE7F6D8>,
#         <__main__.signal object at 0x0000029F5BE83940>,
#         <__main__.signal object at 0x0000029F5BE86BA8>,
#         <__main__.signal object at 0x0000029F5BE89E10>,
#         <__main__.signal object at 0x0000029F5BE8F0B8>,
#         <__main__.signal object at 0x0000029F5BE92320>,
#         <__main__.signal object at 0x0000029F5BE96588>,
#         <__main__.signal object at 0x0000029F5BE997F0>,
#         <__main__.signal object at 0x0000029F5BE9DA58>,
#         <__main__.signal object at 0x0000029F5BEA1CC0>,
#         <__main__.signal object at 0x0000029F5BEA4F28>,
#         <__main__.signal object at 0x0000029F5BEA91D0>,
#         <__main__.signal object at 0x0000029F5BEAD438>,
#         <__main__.signal object at 0x0000029F5BEB06A0>,
#         <__main__.signal object at 0x0000029F5BEB3908>,
#         <__main__.signal object at 0x0000029F5BEB8B70>,
#         <__main__.signal object at 0x0000029F5BEBADD8>,
#         <__main__.signal object at 0x0000029F5BEC0080>,
#         <__main__.signal object at 0x0000029F5BEC42E8>,
#         <__main__.signal object at 0x0000029F5BEC6550>,
#         <__main__.signal object at 0x0000029F5BECB7B8>,
#         <__main__.signal object at 0x0000029F5BECEA20>,
#         <__main__.signal object at 0x0000029F5BED1C88>,
#         <__main__.signal object at 0x0000029F5BED5EF0>,
#         <__main__.signal object at 0x0000029F5BEDA198>,
#         <__main__.signal object at 0x0000029F5BEDF400>,
#         <__main__.signal object at 0x0000029F5BEE1668>,
#         <__main__.signal object at 0x0000029F5BEE58D0>,
#         <__main__.signal object at 0x0000029F5BEE8B38>,
#         <__main__.signal object at 0x0000029F5BEECDA0>,
#         <__main__.signal object at 0x0000029F5BEF1048>,
#         <__main__.signal object at 0x0000029F5BEF52B0>,
#         <__main__.signal object at 0x0000029F5BEF7518>,
#         <__main__.signal object at 0x0000029F5BEFC780>,
#         <__main__.signal object at 0x0000029F5BF009E8>,
#         <__main__.signal object at 0x0000029F5BF02C50>,
#         <__main__.signal object at 0x0000029F5BF07EB8>,
#         <__main__.signal object at 0x0000029F5BF0B160>,
#         <__main__.signal object at 0x0000029F5BF0F3C8>,
#         <__main__.signal object at 0x0000029F5BF12630>,
#         <__main__.signal object at 0x0000029F5BF16898>,
#         <__main__.signal object at 0x0000029F5BF1AB00>,
#         <__main__.signal object at 0x0000029F5BF1DD68>,
#         <__main__.signal object at 0x0000029F5BF21FD0>,
#         <__main__.signal object at 0x0000029F5BF25278>,
#         <__main__.signal object at 0x0000029F5BF294E0>,
#         <__main__.signal object at 0x0000029F5BF2C748>,
#         <__main__.signal object at 0x0000029F5BF309B0>,
#         <__main__.signal object at 0x0000029F5BF34C18>,
#         <__main__.signal object at 0x0000029F5BF38E80>,
#         <__main__.signal object at 0x0000029F5BF3D128>,
#         <__main__.signal object at 0x0000029F5BF3F390>,
#         <__main__.signal object at 0x0000029F5BF445F8>,
#         <__main__.signal object at 0x0000029F5BF46860>,
#         <__main__.signal object at 0x0000029F5BF4AAC8>,
#         <__main__.signal object at 0x0000029F5BF4FD30>,
#         <__main__.signal object at 0x0000029F5BF51F98>,
#         <__main__.signal object at 0x0000029F5BF57240>,
#         <__main__.signal object at 0x0000029F5BF5A4A8>,
#         <__main__.signal object at 0x0000029F5BF5E710>,
#         <__main__.signal object at 0x0000029F5BF61978>,
#         <__main__.signal object at 0x0000029F5BF65BE0>,
#         <__main__.signal object at 0x0000029F5BF67E48>,
#         <__main__.signal object at 0x0000029F5BF6E0F0>,
#         <__main__.signal object at 0x0000029F5BF72358>,
#         <__main__.signal object at 0x0000029F5BF765C0>,
#         <__main__.signal object at 0x0000029F5BF79828>,
#         <__main__.signal object at 0x0000029F5BF7CA90>,
#         <__main__.signal object at 0x0000029F5BF81CF8>,
#         <__main__.signal object at 0x0000029F5BF83F60>,
#         <__main__.signal object at 0x0000029F5BF89208>,
#         <__main__.signal object at 0x0000029F5BF8D470>,
#         <__main__.signal object at 0x0000029F5BF8F6D8>,
#         <__main__.signal object at 0x0000029F5BF94940>,
#         <__main__.signal object at 0x0000029F5BF97BA8>,
#         <__main__.signal object at 0x0000029F5BF9AE10>,
#         <__main__.signal object at 0x0000029F5BFA00B8>,
#         <__main__.signal object at 0x0000029F5BFA3320>,
#         <__main__.signal object at 0x0000029F5BFA8588>,
#         <__main__.signal object at 0x0000029F5BFAA7F0>,
#         <__main__.signal object at 0x0000029F5BFAEA58>], dtype=object),
#  'white-info-8': array([<__main__.signal object at 0x0000029F5BE6A358>,
#         <__main__.signal object at 0x0000029F5BE76550>,
#         <__main__.signal object at 0x0000029F5BE7F7B8>,
#         <__main__.signal object at 0x0000029F5BE83A20>,
#         <__main__.signal object at 0x0000029F5BE86C88>,
#         <__main__.signal object at 0x0000029F5BE89EF0>,
#         <__main__.signal object at 0x0000029F5BE8F198>,
#         <__main__.signal object at 0x0000029F5BE92400>,
#         <__main__.signal object at 0x0000029F5BE96668>,
#         <__main__.signal object at 0x0000029F5BE998D0>,
#         <__main__.signal object at 0x0000029F5BE9DB38>,
#         <__main__.signal object at 0x0000029F5BEA1DA0>,
#         <__main__.signal object at 0x0000029F5BEA5048>,
#         <__main__.signal object at 0x0000029F5BEA92B0>,
#         <__main__.signal object at 0x0000029F5BEAD518>,
#         <__main__.signal object at 0x0000029F5BEB0780>,
#         <__main__.signal object at 0x0000029F5BEB39E8>,
#         <__main__.signal object at 0x0000029F5BEB8C50>,
#         <__main__.signal object at 0x0000029F5BEBAEB8>,
#         <__main__.signal object at 0x0000029F5BEC0160>,
#         <__main__.signal object at 0x0000029F5BEC43C8>,
#         <__main__.signal object at 0x0000029F5BEC6630>,
#         <__main__.signal object at 0x0000029F5BECB898>,
#         <__main__.signal object at 0x0000029F5BECEB00>,
#         <__main__.signal object at 0x0000029F5BED1D68>,
#         <__main__.signal object at 0x0000029F5BED5FD0>,
#         <__main__.signal object at 0x0000029F5BEDA278>,
#         <__main__.signal object at 0x0000029F5BEDF4E0>,
#         <__main__.signal object at 0x0000029F5BEE1748>,
#         <__main__.signal object at 0x0000029F5BEE59B0>,
#         <__main__.signal object at 0x0000029F5BEE8C18>,
#         <__main__.signal object at 0x0000029F5BEECE80>,
#         <__main__.signal object at 0x0000029F5BEF1128>,
#         <__main__.signal object at 0x0000029F5BEF5390>,
#         <__main__.signal object at 0x0000029F5BEF75F8>,
#         <__main__.signal object at 0x0000029F5BEFC860>,
#         <__main__.signal object at 0x0000029F5BF00AC8>,
#         <__main__.signal object at 0x0000029F5BF02D30>,
#         <__main__.signal object at 0x0000029F5BF07F98>,
#         <__main__.signal object at 0x0000029F5BF0B240>,
#         <__main__.signal object at 0x0000029F5BF0F4A8>,
#         <__main__.signal object at 0x0000029F5BF12710>,
#         <__main__.signal object at 0x0000029F5BF16978>,
#         <__main__.signal object at 0x0000029F5BF1ABE0>,
#         <__main__.signal object at 0x0000029F5BF1DE48>,
#         <__main__.signal object at 0x0000029F5BF220F0>,
#         <__main__.signal object at 0x0000029F5BF25358>,
#         <__main__.signal object at 0x0000029F5BF295C0>,
#         <__main__.signal object at 0x0000029F5BF2C828>,
#         <__main__.signal object at 0x0000029F5BF30A90>,
#         <__main__.signal object at 0x0000029F5BF34CF8>,
#         <__main__.signal object at 0x0000029F5BF38F60>,
#         <__main__.signal object at 0x0000029F5BF3D208>,
#         <__main__.signal object at 0x0000029F5BF3F470>,
#         <__main__.signal object at 0x0000029F5BF446D8>,
#         <__main__.signal object at 0x0000029F5BF46940>,
#         <__main__.signal object at 0x0000029F5BF4ABA8>,
#         <__main__.signal object at 0x0000029F5BF4FE10>,
#         <__main__.signal object at 0x0000029F5BF530B8>,
#         <__main__.signal object at 0x0000029F5BF57320>,
#         <__main__.signal object at 0x0000029F5BF5A588>,
#         <__main__.signal object at 0x0000029F5BF5E7F0>,
#         <__main__.signal object at 0x0000029F5BF61A58>,
#         <__main__.signal object at 0x0000029F5BF65CC0>,
#         <__main__.signal object at 0x0000029F5BF67F28>,
#         <__main__.signal object at 0x0000029F5BF6E1D0>,
#         <__main__.signal object at 0x0000029F5BF72438>,
#         <__main__.signal object at 0x0000029F5BF766A0>,
#         <__main__.signal object at 0x0000029F5BF79908>,
#         <__main__.signal object at 0x0000029F5BF7CB70>,
#         <__main__.signal object at 0x0000029F5BF81DD8>,
#         <__main__.signal object at 0x0000029F5BF86080>,
#         <__main__.signal object at 0x0000029F5BF892E8>,
#         <__main__.signal object at 0x0000029F5BF8D550>,
#         <__main__.signal object at 0x0000029F5BF8F7B8>,
#         <__main__.signal object at 0x0000029F5BF94A20>,
#         <__main__.signal object at 0x0000029F5BF97C88>,
#         <__main__.signal object at 0x0000029F5BF9AEF0>,
#         <__main__.signal object at 0x0000029F5BFA0198>,
#         <__main__.signal object at 0x0000029F5BFA3400>,
#         <__main__.signal object at 0x0000029F5BFA8668>,
#         <__main__.signal object at 0x0000029F5BFAA8D0>,
#         <__main__.signal object at 0x0000029F5BFAEB38>], dtype=object),
#  'white-info-9': array([<__main__.signal object at 0x0000029F5BE6A438>,
#         <__main__.signal object at 0x0000029F5BE76630>,
#         <__main__.signal object at 0x0000029F5BE7F898>,
#         <__main__.signal object at 0x0000029F5BE83B00>,
#         <__main__.signal object at 0x0000029F5BE86D68>,
#         <__main__.signal object at 0x0000029F5BE89FD0>,
#         <__main__.signal object at 0x0000029F5BE8F278>,
#         <__main__.signal object at 0x0000029F5BE924E0>,
#         <__main__.signal object at 0x0000029F5BE96748>,
#         <__main__.signal object at 0x0000029F5BE999B0>,
#         <__main__.signal object at 0x0000029F5BE9DC18>,
#         <__main__.signal object at 0x0000029F5BEA1E80>,
#         <__main__.signal object at 0x0000029F5BEA5128>,
#         <__main__.signal object at 0x0000029F5BEA9390>,
#         <__main__.signal object at 0x0000029F5BEAD5F8>,
#         <__main__.signal object at 0x0000029F5BEB0860>,
#         <__main__.signal object at 0x0000029F5BEB3AC8>,
#         <__main__.signal object at 0x0000029F5BEB8D30>,
#         <__main__.signal object at 0x0000029F5BEBAF98>,
#         <__main__.signal object at 0x0000029F5BEC0240>,
#         <__main__.signal object at 0x0000029F5BEC44A8>,
#         <__main__.signal object at 0x0000029F5BEC6710>,
#         <__main__.signal object at 0x0000029F5BECB978>,
#         <__main__.signal object at 0x0000029F5BECEBE0>,
#         <__main__.signal object at 0x0000029F5BED1E48>,
#         <__main__.signal object at 0x0000029F5BED60F0>,
#         <__main__.signal object at 0x0000029F5BEDA358>,
#         <__main__.signal object at 0x0000029F5BEDF5C0>,
#         <__main__.signal object at 0x0000029F5BEE1828>,
#         <__main__.signal object at 0x0000029F5BEE5A90>,
#         <__main__.signal object at 0x0000029F5BEE8CF8>,
#         <__main__.signal object at 0x0000029F5BEECF60>,
#         <__main__.signal object at 0x0000029F5BEF1208>,
#         <__main__.signal object at 0x0000029F5BEF5470>,
#         <__main__.signal object at 0x0000029F5BEF76D8>,
#         <__main__.signal object at 0x0000029F5BEFC940>,
#         <__main__.signal object at 0x0000029F5BF00BA8>,
#         <__main__.signal object at 0x0000029F5BF02E10>,
#         <__main__.signal object at 0x0000029F5BF080B8>,
#         <__main__.signal object at 0x0000029F5BF0B320>,
#         <__main__.signal object at 0x0000029F5BF0F588>,
#         <__main__.signal object at 0x0000029F5BF127F0>,
#         <__main__.signal object at 0x0000029F5BF16A58>,
#         <__main__.signal object at 0x0000029F5BF1ACC0>,
#         <__main__.signal object at 0x0000029F5BF1DF28>,
#         <__main__.signal object at 0x0000029F5BF221D0>,
#         <__main__.signal object at 0x0000029F5BF25438>,
#         <__main__.signal object at 0x0000029F5BF296A0>,
#         <__main__.signal object at 0x0000029F5BF2C908>,
#         <__main__.signal object at 0x0000029F5BF30B70>,
#         <__main__.signal object at 0x0000029F5BF34DD8>,
#         <__main__.signal object at 0x0000029F5BF39080>,
#         <__main__.signal object at 0x0000029F5BF3D2E8>,
#         <__main__.signal object at 0x0000029F5BF3F550>,
#         <__main__.signal object at 0x0000029F5BF447B8>,
#         <__main__.signal object at 0x0000029F5BF46A20>,
#         <__main__.signal object at 0x0000029F5BF4AC88>,
#         <__main__.signal object at 0x0000029F5BF4FEF0>,
#         <__main__.signal object at 0x0000029F5BF53198>,
#         <__main__.signal object at 0x0000029F5BF57400>,
#         <__main__.signal object at 0x0000029F5BF5A668>,
#         <__main__.signal object at 0x0000029F5BF5E8D0>,
#         <__main__.signal object at 0x0000029F5BF61B38>,
#         <__main__.signal object at 0x0000029F5BF65DA0>,
#         <__main__.signal object at 0x0000029F5BF6C048>,
#         <__main__.signal object at 0x0000029F5BF6E2B0>,
#         <__main__.signal object at 0x0000029F5BF72518>,
#         <__main__.signal object at 0x0000029F5BF76780>,
#         <__main__.signal object at 0x0000029F5BF799E8>,
#         <__main__.signal object at 0x0000029F5BF7CC50>,
#         <__main__.signal object at 0x0000029F5BF81EB8>,
#         <__main__.signal object at 0x0000029F5BF86160>,
#         <__main__.signal object at 0x0000029F5BF893C8>,
#         <__main__.signal object at 0x0000029F5BF8D630>,
#         <__main__.signal object at 0x0000029F5BF8F898>,
#         <__main__.signal object at 0x0000029F5BF94B00>,
#         <__main__.signal object at 0x0000029F5BF97D68>,
#         <__main__.signal object at 0x0000029F5BF9AFD0>,
#         <__main__.signal object at 0x0000029F5BFA0278>,
#         <__main__.signal object at 0x0000029F5BFA34E0>,
#         <__main__.signal object at 0x0000029F5BFA8748>,
#         <__main__.signal object at 0x0000029F5BFAA9B0>,
#         <__main__.signal object at 0x0000029F5BFAEC18>], dtype=object),
#  'black-info-1': array([<__main__.signal object at 0x0000029F5BE6A518>,
#         <__main__.signal object at 0x0000029F5BE76710>,
#         <__main__.signal object at 0x0000029F5BE7F978>,
#         <__main__.signal object at 0x0000029F5BE83BE0>,
#         <__main__.signal object at 0x0000029F5BE86E48>,
#         <__main__.signal object at 0x0000029F5BE8B0F0>,
#         <__main__.signal object at 0x0000029F5BE8F358>,
#         <__main__.signal object at 0x0000029F5BE925C0>,
#         <__main__.signal object at 0x0000029F5BE96828>,
#         <__main__.signal object at 0x0000029F5BE99A90>,
#         <__main__.signal object at 0x0000029F5BE9DCF8>,
#         <__main__.signal object at 0x0000029F5BEA1F60>,
#         <__main__.signal object at 0x0000029F5BEA5208>,
#         <__main__.signal object at 0x0000029F5BEA9470>,
#         <__main__.signal object at 0x0000029F5BEAD6D8>,
#         <__main__.signal object at 0x0000029F5BEB0940>,
#         <__main__.signal object at 0x0000029F5BEB3BA8>,
#         <__main__.signal object at 0x0000029F5BEB8E10>,
#         <__main__.signal object at 0x0000029F5BEBC0B8>,
#         <__main__.signal object at 0x0000029F5BEC0320>,
#         <__main__.signal object at 0x0000029F5BEC4588>,
#         <__main__.signal object at 0x0000029F5BEC67F0>,
#         <__main__.signal object at 0x0000029F5BECBA58>,
#         <__main__.signal object at 0x0000029F5BECECC0>,
#         <__main__.signal object at 0x0000029F5BED1F28>,
#         <__main__.signal object at 0x0000029F5BED61D0>,
#         <__main__.signal object at 0x0000029F5BEDA438>,
#         <__main__.signal object at 0x0000029F5BEDF6A0>,
#         <__main__.signal object at 0x0000029F5BEE1908>,
#         <__main__.signal object at 0x0000029F5BEE5B70>,
#         <__main__.signal object at 0x0000029F5BEE8DD8>,
#         <__main__.signal object at 0x0000029F5BEED080>,
#         <__main__.signal object at 0x0000029F5BEF12E8>,
#         <__main__.signal object at 0x0000029F5BEF5550>,
#         <__main__.signal object at 0x0000029F5BEF77B8>,
#         <__main__.signal object at 0x0000029F5BEFCA20>,
#         <__main__.signal object at 0x0000029F5BF00C88>,
#         <__main__.signal object at 0x0000029F5BF02EF0>,
#         <__main__.signal object at 0x0000029F5BF08198>,
#         <__main__.signal object at 0x0000029F5BF0B400>,
#         <__main__.signal object at 0x0000029F5BF0F668>,
#         <__main__.signal object at 0x0000029F5BF128D0>,
#         <__main__.signal object at 0x0000029F5BF16B38>,
#         <__main__.signal object at 0x0000029F5BF1ADA0>,
#         <__main__.signal object at 0x0000029F5BF1E048>,
#         <__main__.signal object at 0x0000029F5BF222B0>,
#         <__main__.signal object at 0x0000029F5BF25518>,
#         <__main__.signal object at 0x0000029F5BF29780>,
#         <__main__.signal object at 0x0000029F5BF2C9E8>,
#         <__main__.signal object at 0x0000029F5BF30C50>,
#         <__main__.signal object at 0x0000029F5BF34EB8>,
#         <__main__.signal object at 0x0000029F5BF39160>,
#         <__main__.signal object at 0x0000029F5BF3D3C8>,
#         <__main__.signal object at 0x0000029F5BF3F630>,
#         <__main__.signal object at 0x0000029F5BF44898>,
#         <__main__.signal object at 0x0000029F5BF46B00>,
#         <__main__.signal object at 0x0000029F5BF4AD68>,
#         <__main__.signal object at 0x0000029F5BF4FFD0>,
#         <__main__.signal object at 0x0000029F5BF53278>,
#         <__main__.signal object at 0x0000029F5BF574E0>,
#         <__main__.signal object at 0x0000029F5BF5A748>,
#         <__main__.signal object at 0x0000029F5BF5E9B0>,
#         <__main__.signal object at 0x0000029F5BF61C18>,
#         <__main__.signal object at 0x0000029F5BF65E80>,
#         <__main__.signal object at 0x0000029F5BF6C128>,
#         <__main__.signal object at 0x0000029F5BF6E390>,
#         <__main__.signal object at 0x0000029F5BF725F8>,
#         <__main__.signal object at 0x0000029F5BF76860>,
#         <__main__.signal object at 0x0000029F5BF79AC8>,
#         <__main__.signal object at 0x0000029F5BF7CD30>,
#         <__main__.signal object at 0x0000029F5BF81F98>,
#         <__main__.signal object at 0x0000029F5BF86240>,
#         <__main__.signal object at 0x0000029F5BF894A8>,
#         <__main__.signal object at 0x0000029F5BF8D710>,
#         <__main__.signal object at 0x0000029F5BF8F978>,
#         <__main__.signal object at 0x0000029F5BF94BE0>,
#         <__main__.signal object at 0x0000029F5BF97E48>,
#         <__main__.signal object at 0x0000029F5BF9D0F0>,
#         <__main__.signal object at 0x0000029F5BFA0358>,
#         <__main__.signal object at 0x0000029F5BFA35C0>,
#         <__main__.signal object at 0x0000029F5BFA8828>,
#         <__main__.signal object at 0x0000029F5BFAAA90>,
#         <__main__.signal object at 0x0000029F5BFAECF8>], dtype=object),
#  'black-info-2': array([<__main__.signal object at 0x0000029F5BE6A5F8>,
#         <__main__.signal object at 0x0000029F5BE767F0>,
#         <__main__.signal object at 0x0000029F5BE7FA58>,
#         <__main__.signal object at 0x0000029F5BE83CC0>,
#         <__main__.signal object at 0x0000029F5BE86F28>,
#         <__main__.signal object at 0x0000029F5BE8B1D0>,
#         <__main__.signal object at 0x0000029F5BE8F438>,
#         <__main__.signal object at 0x0000029F5BE926A0>,
#         <__main__.signal object at 0x0000029F5BE96908>,
#         <__main__.signal object at 0x0000029F5BE99B70>,
#         <__main__.signal object at 0x0000029F5BE9DDD8>,
#         <__main__.signal object at 0x0000029F5BEA2080>,
#         <__main__.signal object at 0x0000029F5BEA52E8>,
#         <__main__.signal object at 0x0000029F5BEA9550>,
#         <__main__.signal object at 0x0000029F5BEAD7B8>,
#         <__main__.signal object at 0x0000029F5BEB0A20>,
#         <__main__.signal object at 0x0000029F5BEB3C88>,
#         <__main__.signal object at 0x0000029F5BEB8EF0>,
#         <__main__.signal object at 0x0000029F5BEBC198>,
#         <__main__.signal object at 0x0000029F5BEC0400>,
#         <__main__.signal object at 0x0000029F5BEC4668>,
# ...
#         <__main__.signal object at 0x0000029F5BF60FD0>,
#         <__main__.signal object at 0x0000029F5BF65278>,
#         <__main__.signal object at 0x0000029F5BF674E0>,
#         <__main__.signal object at 0x0000029F5BF6D748>,
#         <__main__.signal object at 0x0000029F5BF719B0>,
#         <__main__.signal object at 0x0000029F5BF73C18>,
#         <__main__.signal object at 0x0000029F5BF78E80>,
#         <__main__.signal object at 0x0000029F5BF7C128>,
#         <__main__.signal object at 0x0000029F5BF81390>,
#         <__main__.signal object at 0x0000029F5BF835F8>,
#         <__main__.signal object at 0x0000029F5BF87860>,
#         <__main__.signal object at 0x0000029F5BF8BAC8>,
#         <__main__.signal object at 0x0000029F5BF8ED30>,
#         <__main__.signal object at 0x0000029F5BF92F98>,
#         <__main__.signal object at 0x0000029F5BF97240>,
#         <__main__.signal object at 0x0000029F5BF9A4A8>,
#         <__main__.signal object at 0x0000029F5BF9E710>,
#         <__main__.signal object at 0x0000029F5BFA2978>,
#         <__main__.signal object at 0x0000029F5BFA5BE0>,
#         <__main__.signal object at 0x0000029F5BFA9E48>,
#         <__main__.signal object at 0x0000029F5BFAE0F0>,
#         <__main__.signal object at 0x0000029F5BFB1358>], dtype=object),
#  'black-stop-9': array([<__main__.signal object at 0x0000029F5BE70C18>,
#         <__main__.signal object at 0x0000029F5BE73E10>,
#         <__main__.signal object at 0x0000029F5BE830B8>,
#         <__main__.signal object at 0x0000029F5BE86320>,
#         <__main__.signal object at 0x0000029F5BE89588>,
#         <__main__.signal object at 0x0000029F5BE8D7F0>,
#         <__main__.signal object at 0x0000029F5BE91A58>,
#         <__main__.signal object at 0x0000029F5BE93CC0>,
#         <__main__.signal object at 0x0000029F5BE98F28>,
#         <__main__.signal object at 0x0000029F5BE9D1D0>,
#         <__main__.signal object at 0x0000029F5BEA1438>,
#         <__main__.signal object at 0x0000029F5BEA46A0>,
#         <__main__.signal object at 0x0000029F5BEA7908>,
#         <__main__.signal object at 0x0000029F5BEABB70>,
#         <__main__.signal object at 0x0000029F5BEAEDD8>,
#         <__main__.signal object at 0x0000029F5BEB3080>,
#         <__main__.signal object at 0x0000029F5BEB82E8>,
#         <__main__.signal object at 0x0000029F5BEBA550>,
#         <__main__.signal object at 0x0000029F5BEBE7B8>,
#         <__main__.signal object at 0x0000029F5BEC2A20>,
#         <__main__.signal object at 0x0000029F5BEC5C88>,
#         <__main__.signal object at 0x0000029F5BEC9EF0>,
#         <__main__.signal object at 0x0000029F5BECE198>,
#         <__main__.signal object at 0x0000029F5BED1400>,
#         <__main__.signal object at 0x0000029F5BED5668>,
#         <__main__.signal object at 0x0000029F5BED98D0>,
#         <__main__.signal object at 0x0000029F5BEDBB38>,
#         <__main__.signal object at 0x0000029F5BEE0DA0>,
#         <__main__.signal object at 0x0000029F5BEE5048>,
#         <__main__.signal object at 0x0000029F5BEE82B0>,
#         <__main__.signal object at 0x0000029F5BEEC518>,
#         <__main__.signal object at 0x0000029F5BEEF780>,
#         <__main__.signal object at 0x0000029F5BEF39E8>,
#         <__main__.signal object at 0x0000029F5BEF6C50>,
#         <__main__.signal object at 0x0000029F5BEFAEB8>,
#         <__main__.signal object at 0x0000029F5BF00160>,
#         <__main__.signal object at 0x0000029F5BF023C8>,
#         <__main__.signal object at 0x0000029F5BF07630>,
#         <__main__.signal object at 0x0000029F5BF09898>,
#         <__main__.signal object at 0x0000029F5BF0DB00>,
#         <__main__.signal object at 0x0000029F5BF11D68>,
#         <__main__.signal object at 0x0000029F5BF14FD0>,
#         <__main__.signal object at 0x0000029F5BF1A278>,
#         <__main__.signal object at 0x0000029F5BF1D4E0>,
#         <__main__.signal object at 0x0000029F5BF21748>,
#         <__main__.signal object at 0x0000029F5BF249B0>,
#         <__main__.signal object at 0x0000029F5BF28C18>,
#         <__main__.signal object at 0x0000029F5BF2AE80>,
#         <__main__.signal object at 0x0000029F5BF30128>,
#         <__main__.signal object at 0x0000029F5BF34390>,
#         <__main__.signal object at 0x0000029F5BF385F8>,
#         <__main__.signal object at 0x0000029F5BF3B860>,
#         <__main__.signal object at 0x0000029F5BF3EAC8>,
#         <__main__.signal object at 0x0000029F5BF43D30>,
#         <__main__.signal object at 0x0000029F5BF45F98>,
#         <__main__.signal object at 0x0000029F5BF4A240>,
#         <__main__.signal object at 0x0000029F5BF4F4A8>,
#         <__main__.signal object at 0x0000029F5BF51710>,
#         <__main__.signal object at 0x0000029F5BF56978>,
#         <__main__.signal object at 0x0000029F5BF59BE0>,
#         <__main__.signal object at 0x0000029F5BF5CE48>,
#         <__main__.signal object at 0x0000029F5BF610F0>,
#         <__main__.signal object at 0x0000029F5BF65358>,
#         <__main__.signal object at 0x0000029F5BF675C0>,
#         <__main__.signal object at 0x0000029F5BF6D828>,
#         <__main__.signal object at 0x0000029F5BF71A90>,
#         <__main__.signal object at 0x0000029F5BF73CF8>,
#         <__main__.signal object at 0x0000029F5BF78F60>,
#         <__main__.signal object at 0x0000029F5BF7C208>,
#         <__main__.signal object at 0x0000029F5BF81470>,
#         <__main__.signal object at 0x0000029F5BF836D8>,
#         <__main__.signal object at 0x0000029F5BF87940>,
#         <__main__.signal object at 0x0000029F5BF8BBA8>,
#         <__main__.signal object at 0x0000029F5BF8EE10>,
#         <__main__.signal object at 0x0000029F5BF940B8>,
#         <__main__.signal object at 0x0000029F5BF97320>,
#         <__main__.signal object at 0x0000029F5BF9A588>,
#         <__main__.signal object at 0x0000029F5BF9E7F0>,
#         <__main__.signal object at 0x0000029F5BFA2A58>,
#         <__main__.signal object at 0x0000029F5BFA5CC0>,
#         <__main__.signal object at 0x0000029F5BFA9F28>,
#         <__main__.signal object at 0x0000029F5BFAE1D0>,
#         <__main__.signal object at 0x0000029F5BFB1438>], dtype=object),
#  'start': array([<__main__.signal object at 0x0000029F5BE70D30>,
#         <__main__.signal object at 0x0000029F5BE73F28>,
#         <__main__.signal object at 0x0000029F5BE831D0>,
#         <__main__.signal object at 0x0000029F5BE86438>,
#         <__main__.signal object at 0x0000029F5BE896A0>,
#         <__main__.signal object at 0x0000029F5BE8D908>,
#         <__main__.signal object at 0x0000029F5BE91B70>,
#         <__main__.signal object at 0x0000029F5BE93DD8>,
#         <__main__.signal object at 0x0000029F5BE99080>,
#         <__main__.signal object at 0x0000029F5BE9D2E8>,
#         <__main__.signal object at 0x0000029F5BEA1550>,
#         <__main__.signal object at 0x0000029F5BEA47B8>,
#         <__main__.signal object at 0x0000029F5BEA7A20>,
#         <__main__.signal object at 0x0000029F5BEABC88>,
#         <__main__.signal object at 0x0000029F5BEAEEF0>,
#         <__main__.signal object at 0x0000029F5BEB3198>,
#         <__main__.signal object at 0x0000029F5BEB8400>,
#         <__main__.signal object at 0x0000029F5BEBA668>,
#         <__main__.signal object at 0x0000029F5BEBE8D0>,
#         <__main__.signal object at 0x0000029F5BEC2B38>,
#         <__main__.signal object at 0x0000029F5BEC5DA0>,
#         <__main__.signal object at 0x0000029F5BECB048>,
#         <__main__.signal object at 0x0000029F5BECE2B0>,
#         <__main__.signal object at 0x0000029F5BED1518>,
#         <__main__.signal object at 0x0000029F5BED5780>,
#         <__main__.signal object at 0x0000029F5BED99E8>,
#         <__main__.signal object at 0x0000029F5BEDBC50>,
#         <__main__.signal object at 0x0000029F5BEE0EB8>,
#         <__main__.signal object at 0x0000029F5BEE5160>,
#         <__main__.signal object at 0x0000029F5BEE83C8>,
#         <__main__.signal object at 0x0000029F5BEEC630>,
#         <__main__.signal object at 0x0000029F5BEEF898>,
#         <__main__.signal object at 0x0000029F5BEF3B00>,
#         <__main__.signal object at 0x0000029F5BEF6D68>,
#         <__main__.signal object at 0x0000029F5BEFAFD0>,
#         <__main__.signal object at 0x0000029F5BF00278>,
#         <__main__.signal object at 0x0000029F5BF024E0>,
#         <__main__.signal object at 0x0000029F5BF07748>,
#         <__main__.signal object at 0x0000029F5BF099B0>,
#         <__main__.signal object at 0x0000029F5BF0DC18>,
#         <__main__.signal object at 0x0000029F5BF11E80>,
#         <__main__.signal object at 0x0000029F5BF16128>,
#         <__main__.signal object at 0x0000029F5BF1A390>,
#         <__main__.signal object at 0x0000029F5BF1D5F8>,
#         <__main__.signal object at 0x0000029F5BF21860>,
#         <__main__.signal object at 0x0000029F5BF24AC8>,
#         <__main__.signal object at 0x0000029F5BF28D30>,
#         <__main__.signal object at 0x0000029F5BF2AF98>,
#         <__main__.signal object at 0x0000029F5BF30240>,
#         <__main__.signal object at 0x0000029F5BF344A8>,
#         <__main__.signal object at 0x0000029F5BF38710>,
#         <__main__.signal object at 0x0000029F5BF3B978>,
#         <__main__.signal object at 0x0000029F5BF3EBE0>,
#         <__main__.signal object at 0x0000029F5BF43E48>,
#         <__main__.signal object at 0x0000029F5BF460F0>,
#         <__main__.signal object at 0x0000029F5BF4A358>,
#         <__main__.signal object at 0x0000029F5BF4F5C0>,
#         <__main__.signal object at 0x0000029F5BF51828>,
#         <__main__.signal object at 0x0000029F5BF56A90>,
#         <__main__.signal object at 0x0000029F5BF59CF8>,
#         <__main__.signal object at 0x0000029F5BF5CF60>,
#         <__main__.signal object at 0x0000029F5BF61208>,
#         <__main__.signal object at 0x0000029F5BF65470>,
#         <__main__.signal object at 0x0000029F5BF676D8>,
#         <__main__.signal object at 0x0000029F5BF6D940>,
#         <__main__.signal object at 0x0000029F5BF71BA8>,
#         <__main__.signal object at 0x0000029F5BF73E10>,
#         <__main__.signal object at 0x0000029F5BF790B8>,
#         <__main__.signal object at 0x0000029F5BF7C320>,
#         <__main__.signal object at 0x0000029F5BF81588>,
#         <__main__.signal object at 0x0000029F5BF837F0>,
#         <__main__.signal object at 0x0000029F5BF87A58>,
#         <__main__.signal object at 0x0000029F5BF8BCC0>,
#         <__main__.signal object at 0x0000029F5BF8EF28>,
#         <__main__.signal object at 0x0000029F5BF941D0>,
#         <__main__.signal object at 0x0000029F5BF97438>,
#         <__main__.signal object at 0x0000029F5BF9A6A0>,
#         <__main__.signal object at 0x0000029F5BF9E908>,
#         <__main__.signal object at 0x0000029F5BFA2B70>,
#         <__main__.signal object at 0x0000029F5BFA5DD8>,
#         <__main__.signal object at 0x0000029F5BFAA080>,
#         <__main__.signal object at 0x0000029F5BFAE2E8>,
#         <__main__.signal object at 0x0000029F5BFB1550>], dtype=object),
#  'summary': array([<__main__.signal_summary object at 0x0000029F5BE5FC50>,
#         <__main__.signal_summary object at 0x0000029F5BE5FC18>,
#         <__main__.signal_summary object at 0x0000029F5BE70E80>,
#         <__main__.signal_summary object at 0x0000029F5BE73F60>,
#         <__main__.signal_summary object at 0x0000029F5BE833C8>,
#         <__main__.signal_summary object at 0x0000029F5BE86630>,
#         <__main__.signal_summary object at 0x0000029F5BE89898>,
#         <__main__.signal_summary object at 0x0000029F5BE8DB00>,
#         <__main__.signal_summary object at 0x0000029F5BE91D68>,
#         <__main__.signal_summary object at 0x0000029F5BE93FD0>,
#         <__main__.signal_summary object at 0x0000029F5BE99278>,
#         <__main__.signal_summary object at 0x0000029F5BE9D4E0>,
#         <__main__.signal_summary object at 0x0000029F5BEA1748>,
#         <__main__.signal_summary object at 0x0000029F5BEA49B0>,
#         <__main__.signal_summary object at 0x0000029F5BEA7C18>,
#         <__main__.signal_summary object at 0x0000029F5BEABE80>,
#         <__main__.signal_summary object at 0x0000029F5BEAEF28>,
#         <__main__.signal_summary object at 0x0000029F5BEB3390>,
#         <__main__.signal_summary object at 0x0000029F5BEB85F8>,
#         <__main__.signal_summary object at 0x0000029F5BEBA860>,
#         <__main__.signal_summary object at 0x0000029F5BEBEAC8>,
#         <__main__.signal_summary object at 0x0000029F5BEC2D30>,
#         <__main__.signal_summary object at 0x0000029F5BEC5F98>,
#         <__main__.signal_summary object at 0x0000029F5BECB240>,
#         <__main__.signal_summary object at 0x0000029F5BECE4A8>,
#         <__main__.signal_summary object at 0x0000029F5BED1710>,
#         <__main__.signal_summary object at 0x0000029F5BED5978>,
#         <__main__.signal_summary object at 0x0000029F5BED9BE0>,
#         <__main__.signal_summary object at 0x0000029F5BEDBE48>,
#         <__main__.signal_summary object at 0x0000029F5BEE0EF0>,
#         <__main__.signal_summary object at 0x0000029F5BEE5358>,
#         <__main__.signal_summary object at 0x0000029F5BEE85C0>,
#         <__main__.signal_summary object at 0x0000029F5BEEC828>,
#         <__main__.signal_summary object at 0x0000029F5BEEFA90>,
#         <__main__.signal_summary object at 0x0000029F5BEF3CF8>,
#         <__main__.signal_summary object at 0x0000029F5BEF6F60>,
#         <__main__.signal_summary object at 0x0000029F5BEFC208>,
#         <__main__.signal_summary object at 0x0000029F5BF00470>,
#         <__main__.signal_summary object at 0x0000029F5BF026D8>,
#         <__main__.signal_summary object at 0x0000029F5BF07940>,
#         <__main__.signal_summary object at 0x0000029F5BF09BA8>,
#         <__main__.signal_summary object at 0x0000029F5BF0DE10>,
#         <__main__.signal_summary object at 0x0000029F5BF11EB8>,
#         <__main__.signal_summary object at 0x0000029F5BF16320>,
#         <__main__.signal_summary object at 0x0000029F5BF1A588>,
#         <__main__.signal_summary object at 0x0000029F5BF1D7F0>,
#         <__main__.signal_summary object at 0x0000029F5BF21A58>,
#         <__main__.signal_summary object at 0x0000029F5BF24CC0>,
#         <__main__.signal_summary object at 0x0000029F5BF28F28>,
#         <__main__.signal_summary object at 0x0000029F5BF2AFD0>,
#         <__main__.signal_summary object at 0x0000029F5BF30438>,
#         <__main__.signal_summary object at 0x0000029F5BF346A0>,
#         <__main__.signal_summary object at 0x0000029F5BF38908>,
#         <__main__.signal_summary object at 0x0000029F5BF3BB70>,
#         <__main__.signal_summary object at 0x0000029F5BF3EDD8>,
#         <__main__.signal_summary object at 0x0000029F5BF44080>,
#         <__main__.signal_summary object at 0x0000029F5BF462E8>,
#         <__main__.signal_summary object at 0x0000029F5BF4A550>,
#         <__main__.signal_summary object at 0x0000029F5BF4F7B8>,
#         <__main__.signal_summary object at 0x0000029F5BF51A20>,
#         <__main__.signal_summary object at 0x0000029F5BF56C88>,
#         <__main__.signal_summary object at 0x0000029F5BF59EF0>,
#         <__main__.signal_summary object at 0x0000029F5BF5CF98>,
#         <__main__.signal_summary object at 0x0000029F5BF61400>,
#         <__main__.signal_summary object at 0x0000029F5BF65668>,
#         <__main__.signal_summary object at 0x0000029F5BF678D0>,
#         <__main__.signal_summary object at 0x0000029F5BF6DB38>,
#         <__main__.signal_summary object at 0x0000029F5BF71DA0>,
#         <__main__.signal_summary object at 0x0000029F5BF76048>,
#         <__main__.signal_summary object at 0x0000029F5BF792B0>,
#         <__main__.signal_summary object at 0x0000029F5BF7C518>,
#         <__main__.signal_summary object at 0x0000029F5BF81780>,
#         <__main__.signal_summary object at 0x0000029F5BF839E8>,
#         <__main__.signal_summary object at 0x0000029F5BF87C50>,
#         <__main__.signal_summary object at 0x0000029F5BF8BEB8>,
#         <__main__.signal_summary object at 0x0000029F5BF8EF60>,
#         <__main__.signal_summary object at 0x0000029F5BF943C8>,
#         <__main__.signal_summary object at 0x0000029F5BF97630>,
#         <__main__.signal_summary object at 0x0000029F5BF9A898>,
#         <__main__.signal_summary object at 0x0000029F5BF9EB00>,
#         <__main__.signal_summary object at 0x0000029F5BFA2D68>,
#         <__main__.signal_summary object at 0x0000029F5BFA5FD0>,
#         <__main__.signal_summary object at 0x0000029F5BFAA278>],
#        dtype=object)}

# %%
len(signal_stat["white-info-2"])
# Out:
# 83

# %%
graph_dir = "graphs/"
if not os.path.exists(graph_dir):
    os.makedirs(graph_dir)

for key in signal_stat.keys():
    if key is not "summary":
        ap = [float(signal.ap) for signal in signal_stat[key]]
        tp = [int(signal.TP) for signal in signal_stat[key]]
        fp = [int(signal.FP) for signal in signal_stat[key]]

        plt.figure(figsize=(15,5))
        plt.subplot(121, title=key, ylabel="percentage")
        plt.plot(ap, label="average precision in %")
        plt.legend()
        plt.grid(True)

        plt.subplot(122, title="class:"+key, ylabel="amount")
        plt.plot(tp, "g", label="true positive")
        plt.plot(fp, "r", label="false positive")
        plt.legend()
        plt.grid(True)
        plt.savefig("graphs/"+key+".png")
        plt.show()

# %%
key = "summary"
tp = [float(signal.TP) for signal in signal_stat[key]]
fp = [int(signal.FP) for signal in signal_stat[key]]
fn = [int(signal.FN) for signal in signal_stat[key]]
average_iou = [float(signal.average_iou) for signal in signal_stat[key]]
mean_ap = [float(signal.mean_ap) for signal in signal_stat[key]]

plt.figure(figsize=(15,5))
plt.subplot(121, title=key, ylabel="percentage")
plt.plot(mean_ap, label="mean average precision in %")
plt.plot(average_iou, label="average IoU in %")
plt.legend()
plt.grid(True)

plt.subplot(122, title=key, ylabel="amount")
plt.plot(tp, "g", label="true positive")
plt.plot(fp, "r", label="false positive")
plt.plot(fn, "m", label="false negative")
plt.legend()
plt.grid(True)
plt.savefig("graphs/"+key+".png")
plt.show()

# %%
plt.figure(figsize=(30,15))
plt.grid(True)
for key in signal_stat.keys():
    if key is not "summary":
        ap = [float(signal.ap) for signal in signal_stat[key]]
        plt.plot(ap, label="average precision in %")
        
plt.show()
