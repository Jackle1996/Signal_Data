# %%
import glob
import re
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
files = glob.glob("weigth stats\*")
len(files)
# Out:
# 83

# %%
class signal:
    def __init__(self, name, ap, TP, FP):
        self.name = name
        self.ap = ap
        self.TP = TP
        self.FP = FP
    
    def printstats(self):
        print("Signal [ name:{}, ap:{}%, tp:{}, fp:{} ]".format(self.name, self.ap, self.TP, self.FP))
    
class signal_summary:
    def __init__(self, TP, FP, FN, average_iou, mean_ap):
        self.TP = TP
        self.FP = FP
        self.FN = FN
        self.average_iou = average_iou
        self.mean_ap = mean_ap   
        
    def printstats(self):
        print("Summary [ TP:{}, FP:{}, FN:{}, averageIoU:{}%, meanAP:{}% ]".format(self.TP, self.FP, self.FN, self.average_iou, self.mean_ap))

# %%
def addSignalToDictionary(dictionary, key, value):
    if key in dictionary:
        dictionary[str(key)] = np.append(dictionary[str(key)], value)
    else:
        dictionary[str(key)] = np.array([value])

# %%
signal_stat = {}

for file in files:
    with open(file, "r") as openfile:
        summary = signal_summary(0,0,0,0,0)
        for line in openfile:
            
            # get single signal data
            if line.startswith("class_id"):
                result_name = re.search("name = .*, ap", line)
                result_ap = re.search("ap = .*%", line)
                result_tp = re.search("TP = .*,", line)
                result_fp = re.search("FP = .*\)", line)

                if result_name is not None and result_ap is not None and result_tp is not None and result_fp is not None:
                    name = result_name.group().replace(", ap","").replace("name = ","")
                    ap = result_ap.group().replace("ap = ","").replace("%","")
                    tp = result_tp.group().replace("TP = ","").replace(",","")
                    fp = result_fp.group().replace("FP = ","").replace(")","")
                    new_signal = signal(name, ap, tp, fp)
                    #new.printstats()
                    addSignalToDictionary(signal_stat, name, new_signal)
                continue
                    
            # get summary
            if line.startswith(" for thresh"):
                result_tp = re.search("TP = .*, FP", line)
                result_fp = re.search("FP = .*, FN", line)
                result_fn = re.search("FN = .*,", line)
                result_iou = re.search("average IoU = .* %", line)
                
                if result_tp is not None and result_fp is not None and result_fn is not None and result_iou is not None:                    
                    summary.TP = result_tp.group().replace("TP = ","").replace(", FP","")
                    summary.FP = result_fp.group().replace("FP = ","").replace(", FN","")
                    summary.FN = result_fn.group().replace("FN = ","").replace(",","")
                    summary.average_iou = result_iou.group().replace("average IoU = ","").replace(" %","")
                continue
                
            # get mean average precision
            if line.startswith(" mean average"):
                result_map = re.search(", or .* %", line)
                if result_map is not None:
                    summary.mean_ap = result_map.group().replace(", or ", "").replace(" %", "")
                    #summary.printstats()
                    addSignalToDictionary(signal_stat, "summary", summary)
                continue


signal_stat
# Out:
# {'white-info-1': array([<__main__.signal object at 0x000001629A767CC0>,
#         <__main__.signal object at 0x000001629A781F28>,
#         <__main__.signal object at 0x000001629A791160>,
#         <__main__.signal object at 0x000001629A7943C8>,
#         <__main__.signal object at 0x000001629A798630>,
#         <__main__.signal object at 0x000001629A79B898>,
#         <__main__.signal object at 0x000001629A79FB00>,
#         <__main__.signal object at 0x000001629A7A3D68>,
#         <__main__.signal object at 0x000001629A7A5FD0>,
#         <__main__.signal object at 0x000001629A7AB278>,
#         <__main__.signal object at 0x000001629A7AF4E0>,
#         <__main__.signal object at 0x000001629A7B2748>,
#         <__main__.signal object at 0x000001629A7B69B0>,
#         <__main__.signal object at 0x000001629A7B9C18>,
#         <__main__.signal object at 0x000001629A7BDE80>,
#         <__main__.signal object at 0x000001629A7C1128>,
#         <__main__.signal object at 0x000001629A7C5390>,
#         <__main__.signal object at 0x000001629A7CA5F8>,
#         <__main__.signal object at 0x000001629A7CC860>,
#         <__main__.signal object at 0x000001629A7D0AC8>,
#         <__main__.signal object at 0x000001629A7D4D30>,
#         <__main__.signal object at 0x000001629A7D7F98>,
#         <__main__.signal object at 0x000001629A7DC240>,
#         <__main__.signal object at 0x000001629A7E04A8>,
#         <__main__.signal object at 0x000001629A7E3710>,
#         <__main__.signal object at 0x000001629A7E7978>,
#         <__main__.signal object at 0x000001629A7EBBE0>,
#         <__main__.signal object at 0x000001629A7EDE48>,
#         <__main__.signal object at 0x000001629A7F30F0>,
#         <__main__.signal object at 0x000001629A7F6358>,
#         <__main__.signal object at 0x000001629A7FA5C0>,
#         <__main__.signal object at 0x000001629A7FE828>,
#         <__main__.signal object at 0x000001629A801A90>,
#         <__main__.signal object at 0x000001629A805CF8>,
#         <__main__.signal object at 0x000001629A808F60>,
#         <__main__.signal object at 0x000001629A80E208>,
#         <__main__.signal object at 0x000001629A811470>,
#         <__main__.signal object at 0x000001629A8146D8>,
#         <__main__.signal object at 0x000001629A818940>,
#         <__main__.signal object at 0x000001629A81BBA8>,
#         <__main__.signal object at 0x000001629A81FE10>,
#         <__main__.signal object at 0x000001629A8240B8>,
#         <__main__.signal object at 0x000001629A828320>,
#         <__main__.signal object at 0x000001629A82B588>,
#         <__main__.signal object at 0x000001629A82F7F0>,
#         <__main__.signal object at 0x000001629A832A58>,
#         <__main__.signal object at 0x000001629A836CC0>,
#         <__main__.signal object at 0x000001629A83AF28>,
#         <__main__.signal object at 0x000001629A83E1D0>,
#         <__main__.signal object at 0x000001629A842438>,
#         <__main__.signal object at 0x000001629A8456A0>,
#         <__main__.signal object at 0x000001629A849908>,
#         <__main__.signal object at 0x000001629A84CB70>,
#         <__main__.signal object at 0x000001629A850DD8>,
#         <__main__.signal object at 0x000001629A856080>,
#         <__main__.signal object at 0x000001629A8592E8>,
#         <__main__.signal object at 0x000001629A85C550>,
#         <__main__.signal object at 0x000001629A8607B8>,
#         <__main__.signal object at 0x000001629A863A20>,
#         <__main__.signal object at 0x000001629A866C88>,
#         <__main__.signal object at 0x000001629A86BEF0>,
#         <__main__.signal object at 0x000001629A870198>,
#         <__main__.signal object at 0x000001629A873400>,
#         <__main__.signal object at 0x000001629A877668>,
#         <__main__.signal object at 0x000001629A8798D0>,
#         <__main__.signal object at 0x000001629A87FB38>,
#         <__main__.signal object at 0x000001629A882DA0>,
#         <__main__.signal object at 0x000001629A888048>,
#         <__main__.signal object at 0x000001629A88B2B0>,
#         <__main__.signal object at 0x000001629A88E518>,
#         <__main__.signal object at 0x000001629A893780>,
#         <__main__.signal object at 0x000001629A8959E8>,
#         <__main__.signal object at 0x000001629A899C50>,
#         <__main__.signal object at 0x000001629A89CEB8>,
#         <__main__.signal object at 0x000001629A8A1160>,
#         <__main__.signal object at 0x000001629A8A63C8>,
#         <__main__.signal object at 0x000001629A8A9630>,
#         <__main__.signal object at 0x000001629A8AC898>,
#         <__main__.signal object at 0x000001629A8B0B00>,
#         <__main__.signal object at 0x000001629A8B4D68>,
#         <__main__.signal object at 0x000001629A8B6FD0>,
#         <__main__.signal object at 0x000001629A8BC278>,
#         <__main__.signal object at 0x000001629A8C04E0>], dtype=object),
#  'white-info-2': array([<__main__.signal object at 0x000001629A767DA0>,
#         <__main__.signal object at 0x000001629A785048>,
#         <__main__.signal object at 0x000001629A791240>,
#         <__main__.signal object at 0x000001629A7944A8>,
#         <__main__.signal object at 0x000001629A798710>,
#         <__main__.signal object at 0x000001629A79B978>,
#         <__main__.signal object at 0x000001629A79FBE0>,
#         <__main__.signal object at 0x000001629A7A3E48>,
#         <__main__.signal object at 0x000001629A7A80F0>,
#         <__main__.signal object at 0x000001629A7AB358>,
#         <__main__.signal object at 0x000001629A7AF5C0>,
#         <__main__.signal object at 0x000001629A7B2828>,
#         <__main__.signal object at 0x000001629A7B6A90>,
#         <__main__.signal object at 0x000001629A7B9CF8>,
#         <__main__.signal object at 0x000001629A7BDF60>,
#         <__main__.signal object at 0x000001629A7C1208>,
#         <__main__.signal object at 0x000001629A7C5470>,
#         <__main__.signal object at 0x000001629A7CA6D8>,
#         <__main__.signal object at 0x000001629A7CC940>,
#         <__main__.signal object at 0x000001629A7D0BA8>,
#         <__main__.signal object at 0x000001629A7D4E10>,
#         <__main__.signal object at 0x000001629A7D90B8>,
#         <__main__.signal object at 0x000001629A7DC320>,
#         <__main__.signal object at 0x000001629A7E0588>,
#         <__main__.signal object at 0x000001629A7E37F0>,
#         <__main__.signal object at 0x000001629A7E7A58>,
#         <__main__.signal object at 0x000001629A7EBCC0>,
#         <__main__.signal object at 0x000001629A7EDF28>,
#         <__main__.signal object at 0x000001629A7F31D0>,
#         <__main__.signal object at 0x000001629A7F6438>,
#         <__main__.signal object at 0x000001629A7FA6A0>,
#         <__main__.signal object at 0x000001629A7FE908>,
#         <__main__.signal object at 0x000001629A801B70>,
#         <__main__.signal object at 0x000001629A805DD8>,
#         <__main__.signal object at 0x000001629A809080>,
#         <__main__.signal object at 0x000001629A80E2E8>,
#         <__main__.signal object at 0x000001629A811550>,
#         <__main__.signal object at 0x000001629A8147B8>,
#         <__main__.signal object at 0x000001629A818A20>,
#         <__main__.signal object at 0x000001629A81BC88>,
#         <__main__.signal object at 0x000001629A81FEF0>,
#         <__main__.signal object at 0x000001629A824198>,
#         <__main__.signal object at 0x000001629A828400>,
#         <__main__.signal object at 0x000001629A82B668>,
#         <__main__.signal object at 0x000001629A82F8D0>,
#         <__main__.signal object at 0x000001629A832B38>,
#         <__main__.signal object at 0x000001629A836DA0>,
#         <__main__.signal object at 0x000001629A83B048>,
#         <__main__.signal object at 0x000001629A83E2B0>,
#         <__main__.signal object at 0x000001629A842518>,
#         <__main__.signal object at 0x000001629A845780>,
#         <__main__.signal object at 0x000001629A8499E8>,
#         <__main__.signal object at 0x000001629A84CC50>,
#         <__main__.signal object at 0x000001629A850EB8>,
#         <__main__.signal object at 0x000001629A856160>,
#         <__main__.signal object at 0x000001629A8593C8>,
#         <__main__.signal object at 0x000001629A85C630>,
#         <__main__.signal object at 0x000001629A860898>,
#         <__main__.signal object at 0x000001629A863B00>,
#         <__main__.signal object at 0x000001629A866D68>,
#         <__main__.signal object at 0x000001629A86BFD0>,
#         <__main__.signal object at 0x000001629A870278>,
#         <__main__.signal object at 0x000001629A8734E0>,
#         <__main__.signal object at 0x000001629A877748>,
#         <__main__.signal object at 0x000001629A8799B0>,
#         <__main__.signal object at 0x000001629A87FC18>,
#         <__main__.signal object at 0x000001629A882E80>,
#         <__main__.signal object at 0x000001629A888128>,
#         <__main__.signal object at 0x000001629A88B390>,
#         <__main__.signal object at 0x000001629A88E5F8>,
#         <__main__.signal object at 0x000001629A893860>,
#         <__main__.signal object at 0x000001629A895AC8>,
#         <__main__.signal object at 0x000001629A899D30>,
#         <__main__.signal object at 0x000001629A89CF98>,
#         <__main__.signal object at 0x000001629A8A1240>,
#         <__main__.signal object at 0x000001629A8A64A8>,
#         <__main__.signal object at 0x000001629A8A9710>,
#         <__main__.signal object at 0x000001629A8AC978>,
#         <__main__.signal object at 0x000001629A8B0BE0>,
#         <__main__.signal object at 0x000001629A8B4E48>,
#         <__main__.signal object at 0x000001629A8BA0F0>,
#         <__main__.signal object at 0x000001629A8BC358>,
#         <__main__.signal object at 0x000001629A8C05C0>], dtype=object),
#  'white-info-3': array([<__main__.signal object at 0x000001629A767E80>,
#         <__main__.signal object at 0x000001629A785128>,
#         <__main__.signal object at 0x000001629A791320>,
#         <__main__.signal object at 0x000001629A794588>,
#         <__main__.signal object at 0x000001629A7987F0>,
#         <__main__.signal object at 0x000001629A79BA58>,
#         <__main__.signal object at 0x000001629A79FCC0>,
#         <__main__.signal object at 0x000001629A7A3F28>,
#         <__main__.signal object at 0x000001629A7A81D0>,
#         <__main__.signal object at 0x000001629A7AB438>,
#         <__main__.signal object at 0x000001629A7AF6A0>,
#         <__main__.signal object at 0x000001629A7B2908>,
#         <__main__.signal object at 0x000001629A7B6B70>,
#         <__main__.signal object at 0x000001629A7B9DD8>,
#         <__main__.signal object at 0x000001629A7BF080>,
#         <__main__.signal object at 0x000001629A7C12E8>,
#         <__main__.signal object at 0x000001629A7C5550>,
#         <__main__.signal object at 0x000001629A7CA7B8>,
#         <__main__.signal object at 0x000001629A7CCA20>,
#         <__main__.signal object at 0x000001629A7D0C88>,
#         <__main__.signal object at 0x000001629A7D4EF0>,
#         <__main__.signal object at 0x000001629A7D9198>,
#         <__main__.signal object at 0x000001629A7DC400>,
#         <__main__.signal object at 0x000001629A7E0668>,
#         <__main__.signal object at 0x000001629A7E38D0>,
#         <__main__.signal object at 0x000001629A7E7B38>,
#         <__main__.signal object at 0x000001629A7EBDA0>,
#         <__main__.signal object at 0x000001629A7F0048>,
#         <__main__.signal object at 0x000001629A7F32B0>,
#         <__main__.signal object at 0x000001629A7F6518>,
#         <__main__.signal object at 0x000001629A7FA780>,
#         <__main__.signal object at 0x000001629A7FE9E8>,
#         <__main__.signal object at 0x000001629A801C50>,
#         <__main__.signal object at 0x000001629A805EB8>,
#         <__main__.signal object at 0x000001629A809160>,
#         <__main__.signal object at 0x000001629A80E3C8>,
#         <__main__.signal object at 0x000001629A811630>,
#         <__main__.signal object at 0x000001629A814898>,
#         <__main__.signal object at 0x000001629A818B00>,
#         <__main__.signal object at 0x000001629A81BD68>,
#         <__main__.signal object at 0x000001629A81FFD0>,
#         <__main__.signal object at 0x000001629A824278>,
#         <__main__.signal object at 0x000001629A8284E0>,
#         <__main__.signal object at 0x000001629A82B748>,
#         <__main__.signal object at 0x000001629A82F9B0>,
#         <__main__.signal object at 0x000001629A832C18>,
#         <__main__.signal object at 0x000001629A836E80>,
#         <__main__.signal object at 0x000001629A83B128>,
#         <__main__.signal object at 0x000001629A83E390>,
#         <__main__.signal object at 0x000001629A8425F8>,
#         <__main__.signal object at 0x000001629A845860>,
#         <__main__.signal object at 0x000001629A849AC8>,
#         <__main__.signal object at 0x000001629A84CD30>,
#         <__main__.signal object at 0x000001629A850F98>,
#         <__main__.signal object at 0x000001629A856240>,
#         <__main__.signal object at 0x000001629A8594A8>,
#         <__main__.signal object at 0x000001629A85C710>,
#         <__main__.signal object at 0x000001629A860978>,
#         <__main__.signal object at 0x000001629A863BE0>,
#         <__main__.signal object at 0x000001629A866E48>,
#         <__main__.signal object at 0x000001629A86C0F0>,
#         <__main__.signal object at 0x000001629A870358>,
#         <__main__.signal object at 0x000001629A8735C0>,
#         <__main__.signal object at 0x000001629A877828>,
#         <__main__.signal object at 0x000001629A879A90>,
#         <__main__.signal object at 0x000001629A87FCF8>,
#         <__main__.signal object at 0x000001629A882F60>,
#         <__main__.signal object at 0x000001629A888208>,
#         <__main__.signal object at 0x000001629A88B470>,
#         <__main__.signal object at 0x000001629A88E6D8>,
#         <__main__.signal object at 0x000001629A893940>,
#         <__main__.signal object at 0x000001629A895BA8>,
#         <__main__.signal object at 0x000001629A899E10>,
#         <__main__.signal object at 0x000001629A89F0B8>,
#         <__main__.signal object at 0x000001629A8A1320>,
#         <__main__.signal object at 0x000001629A8A6588>,
#         <__main__.signal object at 0x000001629A8A97F0>,
#         <__main__.signal object at 0x000001629A8ACA58>,
#         <__main__.signal object at 0x000001629A8B0CC0>,
#         <__main__.signal object at 0x000001629A8B4F28>,
#         <__main__.signal object at 0x000001629A8BA1D0>,
#         <__main__.signal object at 0x000001629A8BC438>,
#         <__main__.signal object at 0x000001629A8C06A0>], dtype=object),
#  'white-info-4': array([<__main__.signal object at 0x000001629A767F60>,
#         <__main__.signal object at 0x000001629A785208>,
#         <__main__.signal object at 0x000001629A791400>,
#         <__main__.signal object at 0x000001629A794668>,
#         <__main__.signal object at 0x000001629A7988D0>,
#         <__main__.signal object at 0x000001629A79BB38>,
#         <__main__.signal object at 0x000001629A79FDA0>,
#         <__main__.signal object at 0x000001629A7A4048>,
#         <__main__.signal object at 0x000001629A7A82B0>,
#         <__main__.signal object at 0x000001629A7AB518>,
#         <__main__.signal object at 0x000001629A7AF780>,
#         <__main__.signal object at 0x000001629A7B29E8>,
#         <__main__.signal object at 0x000001629A7B6C50>,
#         <__main__.signal object at 0x000001629A7B9EB8>,
#         <__main__.signal object at 0x000001629A7BF160>,
#         <__main__.signal object at 0x000001629A7C13C8>,
#         <__main__.signal object at 0x000001629A7C5630>,
#         <__main__.signal object at 0x000001629A7CA898>,
#         <__main__.signal object at 0x000001629A7CCB00>,
#         <__main__.signal object at 0x000001629A7D0D68>,
#         <__main__.signal object at 0x000001629A7D4FD0>,
#         <__main__.signal object at 0x000001629A7D9278>,
#         <__main__.signal object at 0x000001629A7DC4E0>,
#         <__main__.signal object at 0x000001629A7E0748>,
#         <__main__.signal object at 0x000001629A7E39B0>,
#         <__main__.signal object at 0x000001629A7E7C18>,
#         <__main__.signal object at 0x000001629A7EBE80>,
#         <__main__.signal object at 0x000001629A7F0128>,
#         <__main__.signal object at 0x000001629A7F3390>,
#         <__main__.signal object at 0x000001629A7F65F8>,
#         <__main__.signal object at 0x000001629A7FA860>,
#         <__main__.signal object at 0x000001629A7FEAC8>,
#         <__main__.signal object at 0x000001629A801D30>,
#         <__main__.signal object at 0x000001629A805F98>,
#         <__main__.signal object at 0x000001629A809240>,
#         <__main__.signal object at 0x000001629A80E4A8>,
#         <__main__.signal object at 0x000001629A811710>,
#         <__main__.signal object at 0x000001629A814978>,
#         <__main__.signal object at 0x000001629A818BE0>,
#         <__main__.signal object at 0x000001629A81BE48>,
#         <__main__.signal object at 0x000001629A8200F0>,
#         <__main__.signal object at 0x000001629A824358>,
#         <__main__.signal object at 0x000001629A8285C0>,
#         <__main__.signal object at 0x000001629A82B828>,
#         <__main__.signal object at 0x000001629A82FA90>,
#         <__main__.signal object at 0x000001629A832CF8>,
#         <__main__.signal object at 0x000001629A836F60>,
#         <__main__.signal object at 0x000001629A83B208>,
#         <__main__.signal object at 0x000001629A83E470>,
#         <__main__.signal object at 0x000001629A8426D8>,
#         <__main__.signal object at 0x000001629A845940>,
#         <__main__.signal object at 0x000001629A849BA8>,
#         <__main__.signal object at 0x000001629A84CE10>,
#         <__main__.signal object at 0x000001629A8510B8>,
#         <__main__.signal object at 0x000001629A856320>,
#         <__main__.signal object at 0x000001629A859588>,
#         <__main__.signal object at 0x000001629A85C7F0>,
#         <__main__.signal object at 0x000001629A860A58>,
#         <__main__.signal object at 0x000001629A863CC0>,
#         <__main__.signal object at 0x000001629A866F28>,
#         <__main__.signal object at 0x000001629A86C1D0>,
#         <__main__.signal object at 0x000001629A870438>,
#         <__main__.signal object at 0x000001629A8736A0>,
#         <__main__.signal object at 0x000001629A877908>,
#         <__main__.signal object at 0x000001629A879B70>,
#         <__main__.signal object at 0x000001629A87FDD8>,
#         <__main__.signal object at 0x000001629A884080>,
#         <__main__.signal object at 0x000001629A8882E8>,
#         <__main__.signal object at 0x000001629A88B550>,
#         <__main__.signal object at 0x000001629A88E7B8>,
#         <__main__.signal object at 0x000001629A893A20>,
#         <__main__.signal object at 0x000001629A895C88>,
#         <__main__.signal object at 0x000001629A899EF0>,
#         <__main__.signal object at 0x000001629A89F198>,
#         <__main__.signal object at 0x000001629A8A1400>,
#         <__main__.signal object at 0x000001629A8A6668>,
#         <__main__.signal object at 0x000001629A8A98D0>,
#         <__main__.signal object at 0x000001629A8ACB38>,
#         <__main__.signal object at 0x000001629A8B0DA0>,
#         <__main__.signal object at 0x000001629A8B5048>,
#         <__main__.signal object at 0x000001629A8BA2B0>,
#         <__main__.signal object at 0x000001629A8BC518>,
#         <__main__.signal object at 0x000001629A8C0780>], dtype=object),
#  'white-info-5': array([<__main__.signal object at 0x000001629A77B080>,
#         <__main__.signal object at 0x000001629A7852E8>,
#         <__main__.signal object at 0x000001629A7914E0>,
#         <__main__.signal object at 0x000001629A794748>,
#         <__main__.signal object at 0x000001629A7989B0>,
#         <__main__.signal object at 0x000001629A79BC18>,
#         <__main__.signal object at 0x000001629A79FE80>,
#         <__main__.signal object at 0x000001629A7A4128>,
#         <__main__.signal object at 0x000001629A7A8390>,
#         <__main__.signal object at 0x000001629A7AB5F8>,
#         <__main__.signal object at 0x000001629A7AF860>,
#         <__main__.signal object at 0x000001629A7B2AC8>,
#         <__main__.signal object at 0x000001629A7B6D30>,
#         <__main__.signal object at 0x000001629A7B9F98>,
#         <__main__.signal object at 0x000001629A7BF240>,
#         <__main__.signal object at 0x000001629A7C14A8>,
#         <__main__.signal object at 0x000001629A7C5710>,
#         <__main__.signal object at 0x000001629A7CA978>,
#         <__main__.signal object at 0x000001629A7CCBE0>,
#         <__main__.signal object at 0x000001629A7D0E48>,
#         <__main__.signal object at 0x000001629A7D50F0>,
#         <__main__.signal object at 0x000001629A7D9358>,
#         <__main__.signal object at 0x000001629A7DC5C0>,
#         <__main__.signal object at 0x000001629A7E0828>,
#         <__main__.signal object at 0x000001629A7E3A90>,
#         <__main__.signal object at 0x000001629A7E7CF8>,
#         <__main__.signal object at 0x000001629A7EBF60>,
#         <__main__.signal object at 0x000001629A7F0208>,
#         <__main__.signal object at 0x000001629A7F3470>,
#         <__main__.signal object at 0x000001629A7F66D8>,
#         <__main__.signal object at 0x000001629A7FA940>,
#         <__main__.signal object at 0x000001629A7FEBA8>,
#         <__main__.signal object at 0x000001629A801E10>,
#         <__main__.signal object at 0x000001629A8070B8>,
#         <__main__.signal object at 0x000001629A809320>,
#         <__main__.signal object at 0x000001629A80E588>,
#         <__main__.signal object at 0x000001629A8117F0>,
#         <__main__.signal object at 0x000001629A814A58>,
#         <__main__.signal object at 0x000001629A818CC0>,
#         <__main__.signal object at 0x000001629A81BF28>,
#         <__main__.signal object at 0x000001629A8201D0>,
#         <__main__.signal object at 0x000001629A824438>,
#         <__main__.signal object at 0x000001629A8286A0>,
#         <__main__.signal object at 0x000001629A82B908>,
#         <__main__.signal object at 0x000001629A82FB70>,
#         <__main__.signal object at 0x000001629A832DD8>,
#         <__main__.signal object at 0x000001629A838080>,
#         <__main__.signal object at 0x000001629A83B2E8>,
#         <__main__.signal object at 0x000001629A83E550>,
#         <__main__.signal object at 0x000001629A8427B8>,
#         <__main__.signal object at 0x000001629A845A20>,
#         <__main__.signal object at 0x000001629A849C88>,
#         <__main__.signal object at 0x000001629A84CEF0>,
#         <__main__.signal object at 0x000001629A851198>,
#         <__main__.signal object at 0x000001629A856400>,
#         <__main__.signal object at 0x000001629A859668>,
#         <__main__.signal object at 0x000001629A85C8D0>,
#         <__main__.signal object at 0x000001629A860B38>,
#         <__main__.signal object at 0x000001629A863DA0>,
#         <__main__.signal object at 0x000001629A869048>,
#         <__main__.signal object at 0x000001629A86C2B0>,
#         <__main__.signal object at 0x000001629A870518>,
#         <__main__.signal object at 0x000001629A873780>,
#         <__main__.signal object at 0x000001629A8779E8>,
#         <__main__.signal object at 0x000001629A879C50>,
#         <__main__.signal object at 0x000001629A87FEB8>,
#         <__main__.signal object at 0x000001629A884160>,
#         <__main__.signal object at 0x000001629A8883C8>,
#         <__main__.signal object at 0x000001629A88B630>,
#         <__main__.signal object at 0x000001629A88E898>,
#         <__main__.signal object at 0x000001629A893B00>,
#         <__main__.signal object at 0x000001629A895D68>,
#         <__main__.signal object at 0x000001629A899FD0>,
#         <__main__.signal object at 0x000001629A89F278>,
#         <__main__.signal object at 0x000001629A8A14E0>,
#         <__main__.signal object at 0x000001629A8A6748>,
#         <__main__.signal object at 0x000001629A8A99B0>,
#         <__main__.signal object at 0x000001629A8ACC18>,
#         <__main__.signal object at 0x000001629A8B0E80>,
#         <__main__.signal object at 0x000001629A8B5128>,
#         <__main__.signal object at 0x000001629A8BA390>,
#         <__main__.signal object at 0x000001629A8BC5F8>,
#         <__main__.signal object at 0x000001629A8C0860>], dtype=object),
#  'white-info-6': array([<__main__.signal object at 0x000001629A77B160>,
#         <__main__.signal object at 0x000001629A7853C8>,
#         <__main__.signal object at 0x000001629A7915C0>,
#         <__main__.signal object at 0x000001629A794828>,
#         <__main__.signal object at 0x000001629A798A90>,
#         <__main__.signal object at 0x000001629A79BCF8>,
#         <__main__.signal object at 0x000001629A79FF60>,
#         <__main__.signal object at 0x000001629A7A4208>,
#         <__main__.signal object at 0x000001629A7A8470>,
#         <__main__.signal object at 0x000001629A7AB6D8>,
#         <__main__.signal object at 0x000001629A7AF940>,
#         <__main__.signal object at 0x000001629A7B2BA8>,
#         <__main__.signal object at 0x000001629A7B6E10>,
#         <__main__.signal object at 0x000001629A7BA0B8>,
#         <__main__.signal object at 0x000001629A7BF320>,
#         <__main__.signal object at 0x000001629A7C1588>,
#         <__main__.signal object at 0x000001629A7C57F0>,
#         <__main__.signal object at 0x000001629A7CAA58>,
#         <__main__.signal object at 0x000001629A7CCCC0>,
#         <__main__.signal object at 0x000001629A7D0F28>,
#         <__main__.signal object at 0x000001629A7D51D0>,
#         <__main__.signal object at 0x000001629A7D9438>,
#         <__main__.signal object at 0x000001629A7DC6A0>,
#         <__main__.signal object at 0x000001629A7E0908>,
#         <__main__.signal object at 0x000001629A7E3B70>,
#         <__main__.signal object at 0x000001629A7E7DD8>,
#         <__main__.signal object at 0x000001629A7EC080>,
#         <__main__.signal object at 0x000001629A7F02E8>,
#         <__main__.signal object at 0x000001629A7F3550>,
#         <__main__.signal object at 0x000001629A7F67B8>,
#         <__main__.signal object at 0x000001629A7FAA20>,
#         <__main__.signal object at 0x000001629A7FEC88>,
#         <__main__.signal object at 0x000001629A801EF0>,
#         <__main__.signal object at 0x000001629A807198>,
#         <__main__.signal object at 0x000001629A809400>,
#         <__main__.signal object at 0x000001629A80E668>,
#         <__main__.signal object at 0x000001629A8118D0>,
#         <__main__.signal object at 0x000001629A814B38>,
#         <__main__.signal object at 0x000001629A818DA0>,
#         <__main__.signal object at 0x000001629A81D048>,
#         <__main__.signal object at 0x000001629A8202B0>,
#         <__main__.signal object at 0x000001629A824518>,
#         <__main__.signal object at 0x000001629A828780>,
#         <__main__.signal object at 0x000001629A82B9E8>,
#         <__main__.signal object at 0x000001629A82FC50>,
#         <__main__.signal object at 0x000001629A832EB8>,
#         <__main__.signal object at 0x000001629A838160>,
#         <__main__.signal object at 0x000001629A83B3C8>,
#         <__main__.signal object at 0x000001629A83E630>,
#         <__main__.signal object at 0x000001629A842898>,
#         <__main__.signal object at 0x000001629A845B00>,
#         <__main__.signal object at 0x000001629A849D68>,
#         <__main__.signal object at 0x000001629A84CFD0>,
#         <__main__.signal object at 0x000001629A851278>,
#         <__main__.signal object at 0x000001629A8564E0>,
#         <__main__.signal object at 0x000001629A859748>,
#         <__main__.signal object at 0x000001629A85C9B0>,
#         <__main__.signal object at 0x000001629A860C18>,
#         <__main__.signal object at 0x000001629A863E80>,
#         <__main__.signal object at 0x000001629A869128>,
#         <__main__.signal object at 0x000001629A86C390>,
#         <__main__.signal object at 0x000001629A8705F8>,
#         <__main__.signal object at 0x000001629A873860>,
#         <__main__.signal object at 0x000001629A877AC8>,
#         <__main__.signal object at 0x000001629A879D30>,
#         <__main__.signal object at 0x000001629A87FF98>,
#         <__main__.signal object at 0x000001629A884240>,
#         <__main__.signal object at 0x000001629A8884A8>,
#         <__main__.signal object at 0x000001629A88B710>,
#         <__main__.signal object at 0x000001629A88E978>,
#         <__main__.signal object at 0x000001629A893BE0>,
#         <__main__.signal object at 0x000001629A895E48>,
#         <__main__.signal object at 0x000001629A89B0F0>,
#         <__main__.signal object at 0x000001629A89F358>,
#         <__main__.signal object at 0x000001629A8A15C0>,
#         <__main__.signal object at 0x000001629A8A6828>,
#         <__main__.signal object at 0x000001629A8A9A90>,
#         <__main__.signal object at 0x000001629A8ACCF8>,
#         <__main__.signal object at 0x000001629A8B0F60>,
#         <__main__.signal object at 0x000001629A8B5208>,
#         <__main__.signal object at 0x000001629A8BA470>,
#         <__main__.signal object at 0x000001629A8BC6D8>,
#         <__main__.signal object at 0x000001629A8C0940>], dtype=object),
#  'white-info-7': array([<__main__.signal object at 0x000001629A77B240>,
#         <__main__.signal object at 0x000001629A7854A8>,
#         <__main__.signal object at 0x000001629A7916A0>,
#         <__main__.signal object at 0x000001629A794908>,
#         <__main__.signal object at 0x000001629A798B70>,
#         <__main__.signal object at 0x000001629A79BDD8>,
#         <__main__.signal object at 0x000001629A7A0080>,
#         <__main__.signal object at 0x000001629A7A42E8>,
#         <__main__.signal object at 0x000001629A7A8550>,
#         <__main__.signal object at 0x000001629A7AB7B8>,
#         <__main__.signal object at 0x000001629A7AFA20>,
#         <__main__.signal object at 0x000001629A7B2C88>,
#         <__main__.signal object at 0x000001629A7B6EF0>,
#         <__main__.signal object at 0x000001629A7BA198>,
#         <__main__.signal object at 0x000001629A7BF400>,
#         <__main__.signal object at 0x000001629A7C1668>,
#         <__main__.signal object at 0x000001629A7C58D0>,
#         <__main__.signal object at 0x000001629A7CAB38>,
#         <__main__.signal object at 0x000001629A7CCDA0>,
#         <__main__.signal object at 0x000001629A7D2048>,
#         <__main__.signal object at 0x000001629A7D52B0>,
#         <__main__.signal object at 0x000001629A7D9518>,
#         <__main__.signal object at 0x000001629A7DC780>,
#         <__main__.signal object at 0x000001629A7E09E8>,
#         <__main__.signal object at 0x000001629A7E3C50>,
#         <__main__.signal object at 0x000001629A7E7EB8>,
#         <__main__.signal object at 0x000001629A7EC160>,
#         <__main__.signal object at 0x000001629A7F03C8>,
#         <__main__.signal object at 0x000001629A7F3630>,
#         <__main__.signal object at 0x000001629A7F6898>,
#         <__main__.signal object at 0x000001629A7FAB00>,
#         <__main__.signal object at 0x000001629A7FED68>,
#         <__main__.signal object at 0x000001629A801FD0>,
#         <__main__.signal object at 0x000001629A807278>,
#         <__main__.signal object at 0x000001629A8094E0>,
#         <__main__.signal object at 0x000001629A80E748>,
#         <__main__.signal object at 0x000001629A8119B0>,
#         <__main__.signal object at 0x000001629A814C18>,
#         <__main__.signal object at 0x000001629A818E80>,
#         <__main__.signal object at 0x000001629A81D128>,
#         <__main__.signal object at 0x000001629A820390>,
#         <__main__.signal object at 0x000001629A8245F8>,
#         <__main__.signal object at 0x000001629A828860>,
#         <__main__.signal object at 0x000001629A82BAC8>,
#         <__main__.signal object at 0x000001629A82FD30>,
#         <__main__.signal object at 0x000001629A832F98>,
#         <__main__.signal object at 0x000001629A838240>,
#         <__main__.signal object at 0x000001629A83B4A8>,
#         <__main__.signal object at 0x000001629A83E710>,
#         <__main__.signal object at 0x000001629A842978>,
#         <__main__.signal object at 0x000001629A845BE0>,
#         <__main__.signal object at 0x000001629A849E48>,
#         <__main__.signal object at 0x000001629A84F0F0>,
#         <__main__.signal object at 0x000001629A851358>,
#         <__main__.signal object at 0x000001629A8565C0>,
#         <__main__.signal object at 0x000001629A859828>,
#         <__main__.signal object at 0x000001629A85CA90>,
#         <__main__.signal object at 0x000001629A860CF8>,
#         <__main__.signal object at 0x000001629A863F60>,
#         <__main__.signal object at 0x000001629A869208>,
#         <__main__.signal object at 0x000001629A86C470>,
#         <__main__.signal object at 0x000001629A8706D8>,
#         <__main__.signal object at 0x000001629A873940>,
#         <__main__.signal object at 0x000001629A877BA8>,
#         <__main__.signal object at 0x000001629A879E10>,
#         <__main__.signal object at 0x000001629A8800B8>,
#         <__main__.signal object at 0x000001629A884320>,
#         <__main__.signal object at 0x000001629A888588>,
#         <__main__.signal object at 0x000001629A88B7F0>,
#         <__main__.signal object at 0x000001629A88EA58>,
#         <__main__.signal object at 0x000001629A893CC0>,
#         <__main__.signal object at 0x000001629A895F28>,
#         <__main__.signal object at 0x000001629A89B1D0>,
#         <__main__.signal object at 0x000001629A89F438>,
#         <__main__.signal object at 0x000001629A8A16A0>,
#         <__main__.signal object at 0x000001629A8A6908>,
#         <__main__.signal object at 0x000001629A8A9B70>,
#         <__main__.signal object at 0x000001629A8ACDD8>,
#         <__main__.signal object at 0x000001629A8B2080>,
#         <__main__.signal object at 0x000001629A8B52E8>,
#         <__main__.signal object at 0x000001629A8BA550>,
#         <__main__.signal object at 0x000001629A8BC7B8>,
#         <__main__.signal object at 0x000001629A8C0A20>], dtype=object),
#  'white-info-8': array([<__main__.signal object at 0x000001629A77B320>,
#         <__main__.signal object at 0x000001629A785588>,
#         <__main__.signal object at 0x000001629A791780>,
#         <__main__.signal object at 0x000001629A7949E8>,
#         <__main__.signal object at 0x000001629A798C50>,
#         <__main__.signal object at 0x000001629A79BEB8>,
#         <__main__.signal object at 0x000001629A7A0160>,
#         <__main__.signal object at 0x000001629A7A43C8>,
#         <__main__.signal object at 0x000001629A7A8630>,
#         <__main__.signal object at 0x000001629A7AB898>,
#         <__main__.signal object at 0x000001629A7AFB00>,
#         <__main__.signal object at 0x000001629A7B2D68>,
#         <__main__.signal object at 0x000001629A7B6FD0>,
#         <__main__.signal object at 0x000001629A7BA278>,
#         <__main__.signal object at 0x000001629A7BF4E0>,
#         <__main__.signal object at 0x000001629A7C1748>,
#         <__main__.signal object at 0x000001629A7C59B0>,
#         <__main__.signal object at 0x000001629A7CAC18>,
#         <__main__.signal object at 0x000001629A7CCE80>,
#         <__main__.signal object at 0x000001629A7D2128>,
#         <__main__.signal object at 0x000001629A7D5390>,
#         <__main__.signal object at 0x000001629A7D95F8>,
#         <__main__.signal object at 0x000001629A7DC860>,
#         <__main__.signal object at 0x000001629A7E0AC8>,
#         <__main__.signal object at 0x000001629A7E3D30>,
#         <__main__.signal object at 0x000001629A7E7F98>,
#         <__main__.signal object at 0x000001629A7EC240>,
#         <__main__.signal object at 0x000001629A7F04A8>,
#         <__main__.signal object at 0x000001629A7F3710>,
#         <__main__.signal object at 0x000001629A7F6978>,
#         <__main__.signal object at 0x000001629A7FABE0>,
#         <__main__.signal object at 0x000001629A7FEE48>,
#         <__main__.signal object at 0x000001629A8030F0>,
#         <__main__.signal object at 0x000001629A807358>,
#         <__main__.signal object at 0x000001629A8095C0>,
#         <__main__.signal object at 0x000001629A80E828>,
#         <__main__.signal object at 0x000001629A811A90>,
#         <__main__.signal object at 0x000001629A814CF8>,
#         <__main__.signal object at 0x000001629A818F60>,
#         <__main__.signal object at 0x000001629A81D208>,
#         <__main__.signal object at 0x000001629A820470>,
#         <__main__.signal object at 0x000001629A8246D8>,
#         <__main__.signal object at 0x000001629A828940>,
#         <__main__.signal object at 0x000001629A82BBA8>,
#         <__main__.signal object at 0x000001629A82FE10>,
#         <__main__.signal object at 0x000001629A8340B8>,
#         <__main__.signal object at 0x000001629A838320>,
#         <__main__.signal object at 0x000001629A83B588>,
#         <__main__.signal object at 0x000001629A83E7F0>,
#         <__main__.signal object at 0x000001629A842A58>,
#         <__main__.signal object at 0x000001629A845CC0>,
#         <__main__.signal object at 0x000001629A849F28>,
#         <__main__.signal object at 0x000001629A84F1D0>,
#         <__main__.signal object at 0x000001629A851438>,
#         <__main__.signal object at 0x000001629A8566A0>,
#         <__main__.signal object at 0x000001629A859908>,
#         <__main__.signal object at 0x000001629A85CB70>,
#         <__main__.signal object at 0x000001629A860DD8>,
#         <__main__.signal object at 0x000001629A865080>,
#         <__main__.signal object at 0x000001629A8692E8>,
#         <__main__.signal object at 0x000001629A86C550>,
#         <__main__.signal object at 0x000001629A8707B8>,
#         <__main__.signal object at 0x000001629A873A20>,
#         <__main__.signal object at 0x000001629A877C88>,
#         <__main__.signal object at 0x000001629A879EF0>,
#         <__main__.signal object at 0x000001629A880198>,
#         <__main__.signal object at 0x000001629A884400>,
#         <__main__.signal object at 0x000001629A888668>,
#         <__main__.signal object at 0x000001629A88B8D0>,
#         <__main__.signal object at 0x000001629A88EB38>,
#         <__main__.signal object at 0x000001629A893DA0>,
#         <__main__.signal object at 0x000001629A898048>,
#         <__main__.signal object at 0x000001629A89B2B0>,
#         <__main__.signal object at 0x000001629A89F518>,
#         <__main__.signal object at 0x000001629A8A1780>,
#         <__main__.signal object at 0x000001629A8A69E8>,
#         <__main__.signal object at 0x000001629A8A9C50>,
#         <__main__.signal object at 0x000001629A8ACEB8>,
#         <__main__.signal object at 0x000001629A8B2160>,
#         <__main__.signal object at 0x000001629A8B53C8>,
#         <__main__.signal object at 0x000001629A8BA630>,
#         <__main__.signal object at 0x000001629A8BC898>,
#         <__main__.signal object at 0x000001629A8C0B00>], dtype=object),
#  'white-info-9': array([<__main__.signal object at 0x000001629A77B400>,
#         <__main__.signal object at 0x000001629A785668>,
#         <__main__.signal object at 0x000001629A791860>,
#         <__main__.signal object at 0x000001629A794AC8>,
#         <__main__.signal object at 0x000001629A798D30>,
#         <__main__.signal object at 0x000001629A79BF98>,
#         <__main__.signal object at 0x000001629A7A0240>,
#         <__main__.signal object at 0x000001629A7A44A8>,
#         <__main__.signal object at 0x000001629A7A8710>,
#         <__main__.signal object at 0x000001629A7AB978>,
#         <__main__.signal object at 0x000001629A7AFBE0>,
#         <__main__.signal object at 0x000001629A7B2E48>,
#         <__main__.signal object at 0x000001629A7B80F0>,
#         <__main__.signal object at 0x000001629A7BA358>,
#         <__main__.signal object at 0x000001629A7BF5C0>,
#         <__main__.signal object at 0x000001629A7C1828>,
#         <__main__.signal object at 0x000001629A7C5A90>,
#         <__main__.signal object at 0x000001629A7CACF8>,
#         <__main__.signal object at 0x000001629A7CCF60>,
#         <__main__.signal object at 0x000001629A7D2208>,
#         <__main__.signal object at 0x000001629A7D5470>,
#         <__main__.signal object at 0x000001629A7D96D8>,
#         <__main__.signal object at 0x000001629A7DC940>,
#         <__main__.signal object at 0x000001629A7E0BA8>,
#         <__main__.signal object at 0x000001629A7E3E10>,
#         <__main__.signal object at 0x000001629A7E80B8>,
#         <__main__.signal object at 0x000001629A7EC320>,
#         <__main__.signal object at 0x000001629A7F0588>,
#         <__main__.signal object at 0x000001629A7F37F0>,
#         <__main__.signal object at 0x000001629A7F6A58>,
#         <__main__.signal object at 0x000001629A7FACC0>,
#         <__main__.signal object at 0x000001629A7FEF28>,
#         <__main__.signal object at 0x000001629A8031D0>,
#         <__main__.signal object at 0x000001629A807438>,
#         <__main__.signal object at 0x000001629A8096A0>,
#         <__main__.signal object at 0x000001629A80E908>,
#         <__main__.signal object at 0x000001629A811B70>,
#         <__main__.signal object at 0x000001629A814DD8>,
#         <__main__.signal object at 0x000001629A81A080>,
#         <__main__.signal object at 0x000001629A81D2E8>,
#         <__main__.signal object at 0x000001629A820550>,
#         <__main__.signal object at 0x000001629A8247B8>,
#         <__main__.signal object at 0x000001629A828A20>,
#         <__main__.signal object at 0x000001629A82BC88>,
#         <__main__.signal object at 0x000001629A82FEF0>,
#         <__main__.signal object at 0x000001629A834198>,
#         <__main__.signal object at 0x000001629A838400>,
#         <__main__.signal object at 0x000001629A83B668>,
#         <__main__.signal object at 0x000001629A83E8D0>,
#         <__main__.signal object at 0x000001629A842B38>,
#         <__main__.signal object at 0x000001629A845DA0>,
#         <__main__.signal object at 0x000001629A84B048>,
#         <__main__.signal object at 0x000001629A84F2B0>,
#         <__main__.signal object at 0x000001629A851518>,
#         <__main__.signal object at 0x000001629A856780>,
#         <__main__.signal object at 0x000001629A8599E8>,
#         <__main__.signal object at 0x000001629A85CC50>,
#         <__main__.signal object at 0x000001629A860EB8>,
#         <__main__.signal object at 0x000001629A865160>,
#         <__main__.signal object at 0x000001629A8693C8>,
#         <__main__.signal object at 0x000001629A86C630>,
#         <__main__.signal object at 0x000001629A870898>,
#         <__main__.signal object at 0x000001629A873B00>,
#         <__main__.signal object at 0x000001629A877D68>,
#         <__main__.signal object at 0x000001629A879FD0>,
#         <__main__.signal object at 0x000001629A880278>,
#         <__main__.signal object at 0x000001629A8844E0>,
#         <__main__.signal object at 0x000001629A888748>,
#         <__main__.signal object at 0x000001629A88B9B0>,
#         <__main__.signal object at 0x000001629A88EC18>,
#         <__main__.signal object at 0x000001629A893E80>,
#         <__main__.signal object at 0x000001629A898128>,
#         <__main__.signal object at 0x000001629A89B390>,
#         <__main__.signal object at 0x000001629A89F5F8>,
#         <__main__.signal object at 0x000001629A8A1860>,
#         <__main__.signal object at 0x000001629A8A6AC8>,
#         <__main__.signal object at 0x000001629A8A9D30>,
#         <__main__.signal object at 0x000001629A8ACF98>,
#         <__main__.signal object at 0x000001629A8B2240>,
#         <__main__.signal object at 0x000001629A8B54A8>,
#         <__main__.signal object at 0x000001629A8BA710>,
#         <__main__.signal object at 0x000001629A8BC978>,
#         <__main__.signal object at 0x000001629A8C0BE0>], dtype=object),
#  'black-info-1': array([<__main__.signal object at 0x000001629A77B4E0>,
#         <__main__.signal object at 0x000001629A785748>,
#         <__main__.signal object at 0x000001629A791940>,
#         <__main__.signal object at 0x000001629A794BA8>,
#         <__main__.signal object at 0x000001629A798E10>,
#         <__main__.signal object at 0x000001629A79D0B8>,
#         <__main__.signal object at 0x000001629A7A0320>,
#         <__main__.signal object at 0x000001629A7A4588>,
#         <__main__.signal object at 0x000001629A7A87F0>,
#         <__main__.signal object at 0x000001629A7ABA58>,
#         <__main__.signal object at 0x000001629A7AFCC0>,
#         <__main__.signal object at 0x000001629A7B2F28>,
#         <__main__.signal object at 0x000001629A7B81D0>,
#         <__main__.signal object at 0x000001629A7BA438>,
#         <__main__.signal object at 0x000001629A7BF6A0>,
#         <__main__.signal object at 0x000001629A7C1908>,
#         <__main__.signal object at 0x000001629A7C5B70>,
#         <__main__.signal object at 0x000001629A7CADD8>,
#         <__main__.signal object at 0x000001629A7CE080>,
#         <__main__.signal object at 0x000001629A7D22E8>,
#         <__main__.signal object at 0x000001629A7D5550>,
#         <__main__.signal object at 0x000001629A7D97B8>,
#         <__main__.signal object at 0x000001629A7DCA20>,
#         <__main__.signal object at 0x000001629A7E0C88>,
#         <__main__.signal object at 0x000001629A7E3EF0>,
#         <__main__.signal object at 0x000001629A7E8198>,
#         <__main__.signal object at 0x000001629A7EC400>,
#         <__main__.signal object at 0x000001629A7F0668>,
#         <__main__.signal object at 0x000001629A7F38D0>,
#         <__main__.signal object at 0x000001629A7F6B38>,
#         <__main__.signal object at 0x000001629A7FADA0>,
#         <__main__.signal object at 0x000001629A7FF048>,
#         <__main__.signal object at 0x000001629A8032B0>,
#         <__main__.signal object at 0x000001629A807518>,
#         <__main__.signal object at 0x000001629A809780>,
#         <__main__.signal object at 0x000001629A80E9E8>,
#         <__main__.signal object at 0x000001629A811C50>,
#         <__main__.signal object at 0x000001629A814EB8>,
#         <__main__.signal object at 0x000001629A81A160>,
#         <__main__.signal object at 0x000001629A81D3C8>,
#         <__main__.signal object at 0x000001629A820630>,
#         <__main__.signal object at 0x000001629A824898>,
#         <__main__.signal object at 0x000001629A828B00>,
#         <__main__.signal object at 0x000001629A82BD68>,
#         <__main__.signal object at 0x000001629A82FFD0>,
#         <__main__.signal object at 0x000001629A834278>,
#         <__main__.signal object at 0x000001629A8384E0>,
#         <__main__.signal object at 0x000001629A83B748>,
#         <__main__.signal object at 0x000001629A83E9B0>,
#         <__main__.signal object at 0x000001629A842C18>,
#         <__main__.signal object at 0x000001629A845E80>,
#         <__main__.signal object at 0x000001629A84B128>,
#         <__main__.signal object at 0x000001629A84F390>,
#         <__main__.signal object at 0x000001629A8515F8>,
#         <__main__.signal object at 0x000001629A856860>,
#         <__main__.signal object at 0x000001629A859AC8>,
#         <__main__.signal object at 0x000001629A85CD30>,
#         <__main__.signal object at 0x000001629A860F98>,
#         <__main__.signal object at 0x000001629A865240>,
#         <__main__.signal object at 0x000001629A8694A8>,
#         <__main__.signal object at 0x000001629A86C710>,
#         <__main__.signal object at 0x000001629A870978>,
#         <__main__.signal object at 0x000001629A873BE0>,
#         <__main__.signal object at 0x000001629A877E48>,
#         <__main__.signal object at 0x000001629A87E0F0>,
#         <__main__.signal object at 0x000001629A880358>,
#         <__main__.signal object at 0x000001629A8845C0>,
#         <__main__.signal object at 0x000001629A888828>,
#         <__main__.signal object at 0x000001629A88BA90>,
#         <__main__.signal object at 0x000001629A88ECF8>,
#         <__main__.signal object at 0x000001629A893F60>,
#         <__main__.signal object at 0x000001629A898208>,
#         <__main__.signal object at 0x000001629A89B470>,
#         <__main__.signal object at 0x000001629A89F6D8>,
#         <__main__.signal object at 0x000001629A8A1940>,
#         <__main__.signal object at 0x000001629A8A6BA8>,
#         <__main__.signal object at 0x000001629A8A9E10>,
#         <__main__.signal object at 0x000001629A8AE0B8>,
#         <__main__.signal object at 0x000001629A8B2320>,
#         <__main__.signal object at 0x000001629A8B5588>,
#         <__main__.signal object at 0x000001629A8BA7F0>,
#         <__main__.signal object at 0x000001629A8BCA58>,
#         <__main__.signal object at 0x000001629A8C0CC0>], dtype=object),
#  'black-info-2': array([<__main__.signal object at 0x000001629A77B5C0>,
#         <__main__.signal object at 0x000001629A785828>,
#         <__main__.signal object at 0x000001629A791A20>,
#         <__main__.signal object at 0x000001629A794C88>,
#         <__main__.signal object at 0x000001629A798EF0>,
#         <__main__.signal object at 0x000001629A79D198>,
#         <__main__.signal object at 0x000001629A7A0400>,
#         <__main__.signal object at 0x000001629A7A4668>,
#         <__main__.signal object at 0x000001629A7A88D0>,
#         <__main__.signal object at 0x000001629A7ABB38>,
#         <__main__.signal object at 0x000001629A7AFDA0>,
#         <__main__.signal object at 0x000001629A7B4048>,
#         <__main__.signal object at 0x000001629A7B82B0>,
#         <__main__.signal object at 0x000001629A7BA518>,
#         <__main__.signal object at 0x000001629A7BF780>,
#         <__main__.signal object at 0x000001629A7C19E8>,
#         <__main__.signal object at 0x000001629A7C5C50>,
#         <__main__.signal object at 0x000001629A7CAEB8>,
#         <__main__.signal object at 0x000001629A7CE160>,
#         <__main__.signal object at 0x000001629A7D23C8>,
#         <__main__.signal object at 0x000001629A7D5630>,
# ...
#         <__main__.signal object at 0x000001629A872F98>,
#         <__main__.signal object at 0x000001629A877240>,
#         <__main__.signal object at 0x000001629A8794A8>,
#         <__main__.signal object at 0x000001629A87F710>,
#         <__main__.signal object at 0x000001629A882978>,
#         <__main__.signal object at 0x000001629A885BE0>,
#         <__main__.signal object at 0x000001629A889E48>,
#         <__main__.signal object at 0x000001629A88E0F0>,
#         <__main__.signal object at 0x000001629A893358>,
#         <__main__.signal object at 0x000001629A8955C0>,
#         <__main__.signal object at 0x000001629A899828>,
#         <__main__.signal object at 0x000001629A89CA90>,
#         <__main__.signal object at 0x000001629A8A0CF8>,
#         <__main__.signal object at 0x000001629A8A3F60>,
#         <__main__.signal object at 0x000001629A8A9208>,
#         <__main__.signal object at 0x000001629A8AC470>,
#         <__main__.signal object at 0x000001629A8B06D8>,
#         <__main__.signal object at 0x000001629A8B4940>,
#         <__main__.signal object at 0x000001629A8B6BA8>,
#         <__main__.signal object at 0x000001629A8BBE10>,
#         <__main__.signal object at 0x000001629A8C00B8>,
#         <__main__.signal object at 0x000001629A8C3320>], dtype=object),
#  'black-stop-9': array([<__main__.signal object at 0x000001629A781BE0>,
#         <__main__.signal object at 0x000001629A78FE48>,
#         <__main__.signal object at 0x000001629A794080>,
#         <__main__.signal object at 0x000001629A7982E8>,
#         <__main__.signal object at 0x000001629A79B550>,
#         <__main__.signal object at 0x000001629A79F7B8>,
#         <__main__.signal object at 0x000001629A7A3A20>,
#         <__main__.signal object at 0x000001629A7A5C88>,
#         <__main__.signal object at 0x000001629A7AAEF0>,
#         <__main__.signal object at 0x000001629A7AF198>,
#         <__main__.signal object at 0x000001629A7B2400>,
#         <__main__.signal object at 0x000001629A7B6668>,
#         <__main__.signal object at 0x000001629A7B98D0>,
#         <__main__.signal object at 0x000001629A7BDB38>,
#         <__main__.signal object at 0x000001629A7C0DA0>,
#         <__main__.signal object at 0x000001629A7C5048>,
#         <__main__.signal object at 0x000001629A7CA2B0>,
#         <__main__.signal object at 0x000001629A7CC518>,
#         <__main__.signal object at 0x000001629A7D0780>,
#         <__main__.signal object at 0x000001629A7D49E8>,
#         <__main__.signal object at 0x000001629A7D7C50>,
#         <__main__.signal object at 0x000001629A7DAEB8>,
#         <__main__.signal object at 0x000001629A7E0160>,
#         <__main__.signal object at 0x000001629A7E33C8>,
#         <__main__.signal object at 0x000001629A7E7630>,
#         <__main__.signal object at 0x000001629A7EB898>,
#         <__main__.signal object at 0x000001629A7EDB00>,
#         <__main__.signal object at 0x000001629A7F2D68>,
#         <__main__.signal object at 0x000001629A7F5FD0>,
#         <__main__.signal object at 0x000001629A7FA278>,
#         <__main__.signal object at 0x000001629A7FE4E0>,
#         <__main__.signal object at 0x000001629A801748>,
#         <__main__.signal object at 0x000001629A8059B0>,
#         <__main__.signal object at 0x000001629A808C18>,
#         <__main__.signal object at 0x000001629A80CE80>,
#         <__main__.signal object at 0x000001629A811128>,
#         <__main__.signal object at 0x000001629A814390>,
#         <__main__.signal object at 0x000001629A8185F8>,
#         <__main__.signal object at 0x000001629A81B860>,
#         <__main__.signal object at 0x000001629A81FAC8>,
#         <__main__.signal object at 0x000001629A823D30>,
#         <__main__.signal object at 0x000001629A826F98>,
#         <__main__.signal object at 0x000001629A82B240>,
#         <__main__.signal object at 0x000001629A82F4A8>,
#         <__main__.signal object at 0x000001629A832710>,
#         <__main__.signal object at 0x000001629A836978>,
#         <__main__.signal object at 0x000001629A83ABE0>,
#         <__main__.signal object at 0x000001629A83CE48>,
#         <__main__.signal object at 0x000001629A8420F0>,
#         <__main__.signal object at 0x000001629A845358>,
#         <__main__.signal object at 0x000001629A8495C0>,
#         <__main__.signal object at 0x000001629A84C828>,
#         <__main__.signal object at 0x000001629A850A90>,
#         <__main__.signal object at 0x000001629A855CF8>,
#         <__main__.signal object at 0x000001629A857F60>,
#         <__main__.signal object at 0x000001629A85C208>,
#         <__main__.signal object at 0x000001629A860470>,
#         <__main__.signal object at 0x000001629A8636D8>,
#         <__main__.signal object at 0x000001629A866940>,
#         <__main__.signal object at 0x000001629A86BBA8>,
#         <__main__.signal object at 0x000001629A86EE10>,
#         <__main__.signal object at 0x000001629A8730B8>,
#         <__main__.signal object at 0x000001629A877320>,
#         <__main__.signal object at 0x000001629A879588>,
#         <__main__.signal object at 0x000001629A87F7F0>,
#         <__main__.signal object at 0x000001629A882A58>,
#         <__main__.signal object at 0x000001629A885CC0>,
#         <__main__.signal object at 0x000001629A889F28>,
#         <__main__.signal object at 0x000001629A88E1D0>,
#         <__main__.signal object at 0x000001629A893438>,
#         <__main__.signal object at 0x000001629A8956A0>,
#         <__main__.signal object at 0x000001629A899908>,
#         <__main__.signal object at 0x000001629A89CB70>,
#         <__main__.signal object at 0x000001629A8A0DD8>,
#         <__main__.signal object at 0x000001629A8A6080>,
#         <__main__.signal object at 0x000001629A8A92E8>,
#         <__main__.signal object at 0x000001629A8AC550>,
#         <__main__.signal object at 0x000001629A8B07B8>,
#         <__main__.signal object at 0x000001629A8B4A20>,
#         <__main__.signal object at 0x000001629A8B6C88>,
#         <__main__.signal object at 0x000001629A8BBEF0>,
#         <__main__.signal object at 0x000001629A8C0198>,
#         <__main__.signal object at 0x000001629A8C3400>], dtype=object),
#  'start': array([<__main__.signal object at 0x000001629A781CF8>,
#         <__main__.signal object at 0x000001629A78FF60>,
#         <__main__.signal object at 0x000001629A794198>,
#         <__main__.signal object at 0x000001629A798400>,
#         <__main__.signal object at 0x000001629A79B668>,
#         <__main__.signal object at 0x000001629A79F8D0>,
#         <__main__.signal object at 0x000001629A7A3B38>,
#         <__main__.signal object at 0x000001629A7A5DA0>,
#         <__main__.signal object at 0x000001629A7AB048>,
#         <__main__.signal object at 0x000001629A7AF2B0>,
#         <__main__.signal object at 0x000001629A7B2518>,
#         <__main__.signal object at 0x000001629A7B6780>,
#         <__main__.signal object at 0x000001629A7B99E8>,
#         <__main__.signal object at 0x000001629A7BDC50>,
#         <__main__.signal object at 0x000001629A7C0EB8>,
#         <__main__.signal object at 0x000001629A7C5160>,
#         <__main__.signal object at 0x000001629A7CA3C8>,
#         <__main__.signal object at 0x000001629A7CC630>,
#         <__main__.signal object at 0x000001629A7D0898>,
#         <__main__.signal object at 0x000001629A7D4B00>,
#         <__main__.signal object at 0x000001629A7D7D68>,
#         <__main__.signal object at 0x000001629A7DAFD0>,
#         <__main__.signal object at 0x000001629A7E0278>,
#         <__main__.signal object at 0x000001629A7E34E0>,
#         <__main__.signal object at 0x000001629A7E7748>,
#         <__main__.signal object at 0x000001629A7EB9B0>,
#         <__main__.signal object at 0x000001629A7EDC18>,
#         <__main__.signal object at 0x000001629A7F2E80>,
#         <__main__.signal object at 0x000001629A7F6128>,
#         <__main__.signal object at 0x000001629A7FA390>,
#         <__main__.signal object at 0x000001629A7FE5F8>,
#         <__main__.signal object at 0x000001629A801860>,
#         <__main__.signal object at 0x000001629A805AC8>,
#         <__main__.signal object at 0x000001629A808D30>,
#         <__main__.signal object at 0x000001629A80CF98>,
#         <__main__.signal object at 0x000001629A811240>,
#         <__main__.signal object at 0x000001629A8144A8>,
#         <__main__.signal object at 0x000001629A818710>,
#         <__main__.signal object at 0x000001629A81B978>,
#         <__main__.signal object at 0x000001629A81FBE0>,
#         <__main__.signal object at 0x000001629A823E48>,
#         <__main__.signal object at 0x000001629A8280F0>,
#         <__main__.signal object at 0x000001629A82B358>,
#         <__main__.signal object at 0x000001629A82F5C0>,
#         <__main__.signal object at 0x000001629A832828>,
#         <__main__.signal object at 0x000001629A836A90>,
#         <__main__.signal object at 0x000001629A83ACF8>,
#         <__main__.signal object at 0x000001629A83CF60>,
#         <__main__.signal object at 0x000001629A842208>,
#         <__main__.signal object at 0x000001629A845470>,
#         <__main__.signal object at 0x000001629A8496D8>,
#         <__main__.signal object at 0x000001629A84C940>,
#         <__main__.signal object at 0x000001629A850BA8>,
#         <__main__.signal object at 0x000001629A855E10>,
#         <__main__.signal object at 0x000001629A8590B8>,
#         <__main__.signal object at 0x000001629A85C320>,
#         <__main__.signal object at 0x000001629A860588>,
#         <__main__.signal object at 0x000001629A8637F0>,
#         <__main__.signal object at 0x000001629A866A58>,
#         <__main__.signal object at 0x000001629A86BCC0>,
#         <__main__.signal object at 0x000001629A86EF28>,
#         <__main__.signal object at 0x000001629A8731D0>,
#         <__main__.signal object at 0x000001629A877438>,
#         <__main__.signal object at 0x000001629A8796A0>,
#         <__main__.signal object at 0x000001629A87F908>,
#         <__main__.signal object at 0x000001629A882B70>,
#         <__main__.signal object at 0x000001629A885DD8>,
#         <__main__.signal object at 0x000001629A88B080>,
#         <__main__.signal object at 0x000001629A88E2E8>,
#         <__main__.signal object at 0x000001629A893550>,
#         <__main__.signal object at 0x000001629A8957B8>,
#         <__main__.signal object at 0x000001629A899A20>,
#         <__main__.signal object at 0x000001629A89CC88>,
#         <__main__.signal object at 0x000001629A8A0EF0>,
#         <__main__.signal object at 0x000001629A8A6198>,
#         <__main__.signal object at 0x000001629A8A9400>,
#         <__main__.signal object at 0x000001629A8AC668>,
#         <__main__.signal object at 0x000001629A8B08D0>,
#         <__main__.signal object at 0x000001629A8B4B38>,
#         <__main__.signal object at 0x000001629A8B6DA0>,
#         <__main__.signal object at 0x000001629A8BC048>,
#         <__main__.signal object at 0x000001629A8C02B0>,
#         <__main__.signal object at 0x000001629A8C3518>], dtype=object),
#  'summary': array([<__main__.signal_summary object at 0x000001629A767BE0>,
#         <__main__.signal_summary object at 0x000001629A767BA8>,
#         <__main__.signal_summary object at 0x000001629A781EF0>,
#         <__main__.signal_summary object at 0x000001629A791128>,
#         <__main__.signal_summary object at 0x000001629A794390>,
#         <__main__.signal_summary object at 0x000001629A7985F8>,
#         <__main__.signal_summary object at 0x000001629A79B860>,
#         <__main__.signal_summary object at 0x000001629A79FAC8>,
#         <__main__.signal_summary object at 0x000001629A7A3D30>,
#         <__main__.signal_summary object at 0x000001629A7A5F98>,
#         <__main__.signal_summary object at 0x000001629A7AB240>,
#         <__main__.signal_summary object at 0x000001629A7AF4A8>,
#         <__main__.signal_summary object at 0x000001629A7B2710>,
#         <__main__.signal_summary object at 0x000001629A7B6978>,
#         <__main__.signal_summary object at 0x000001629A7B9BE0>,
#         <__main__.signal_summary object at 0x000001629A7BDE48>,
#         <__main__.signal_summary object at 0x000001629A7C0EF0>,
#         <__main__.signal_summary object at 0x000001629A7C5358>,
#         <__main__.signal_summary object at 0x000001629A7CA5C0>,
#         <__main__.signal_summary object at 0x000001629A7CC828>,
#         <__main__.signal_summary object at 0x000001629A7D0A90>,
#         <__main__.signal_summary object at 0x000001629A7D4CF8>,
#         <__main__.signal_summary object at 0x000001629A7D7F60>,
#         <__main__.signal_summary object at 0x000001629A7DC208>,
#         <__main__.signal_summary object at 0x000001629A7E0470>,
#         <__main__.signal_summary object at 0x000001629A7E36D8>,
#         <__main__.signal_summary object at 0x000001629A7E7940>,
#         <__main__.signal_summary object at 0x000001629A7EBBA8>,
#         <__main__.signal_summary object at 0x000001629A7EDE10>,
#         <__main__.signal_summary object at 0x000001629A7F2EB8>,
#         <__main__.signal_summary object at 0x000001629A7F6320>,
#         <__main__.signal_summary object at 0x000001629A7FA588>,
#         <__main__.signal_summary object at 0x000001629A7FE7F0>,
#         <__main__.signal_summary object at 0x000001629A801A58>,
#         <__main__.signal_summary object at 0x000001629A805CC0>,
#         <__main__.signal_summary object at 0x000001629A808F28>,
#         <__main__.signal_summary object at 0x000001629A80CFD0>,
#         <__main__.signal_summary object at 0x000001629A811438>,
#         <__main__.signal_summary object at 0x000001629A8146A0>,
#         <__main__.signal_summary object at 0x000001629A818908>,
#         <__main__.signal_summary object at 0x000001629A81BB70>,
#         <__main__.signal_summary object at 0x000001629A81FDD8>,
#         <__main__.signal_summary object at 0x000001629A824080>,
#         <__main__.signal_summary object at 0x000001629A8282E8>,
#         <__main__.signal_summary object at 0x000001629A82B550>,
#         <__main__.signal_summary object at 0x000001629A82F7B8>,
#         <__main__.signal_summary object at 0x000001629A832A20>,
#         <__main__.signal_summary object at 0x000001629A836C88>,
#         <__main__.signal_summary object at 0x000001629A83AEF0>,
#         <__main__.signal_summary object at 0x000001629A83CF98>,
#         <__main__.signal_summary object at 0x000001629A842400>,
#         <__main__.signal_summary object at 0x000001629A845668>,
#         <__main__.signal_summary object at 0x000001629A8498D0>,
#         <__main__.signal_summary object at 0x000001629A84CB38>,
#         <__main__.signal_summary object at 0x000001629A850DA0>,
#         <__main__.signal_summary object at 0x000001629A856048>,
#         <__main__.signal_summary object at 0x000001629A8592B0>,
#         <__main__.signal_summary object at 0x000001629A85C518>,
#         <__main__.signal_summary object at 0x000001629A860780>,
#         <__main__.signal_summary object at 0x000001629A8639E8>,
#         <__main__.signal_summary object at 0x000001629A866C50>,
#         <__main__.signal_summary object at 0x000001629A86BEB8>,
#         <__main__.signal_summary object at 0x000001629A86EF60>,
#         <__main__.signal_summary object at 0x000001629A8733C8>,
#         <__main__.signal_summary object at 0x000001629A877630>,
#         <__main__.signal_summary object at 0x000001629A879898>,
#         <__main__.signal_summary object at 0x000001629A87FB00>,
#         <__main__.signal_summary object at 0x000001629A882D68>,
#         <__main__.signal_summary object at 0x000001629A885FD0>,
#         <__main__.signal_summary object at 0x000001629A88B278>,
#         <__main__.signal_summary object at 0x000001629A88E4E0>,
#         <__main__.signal_summary object at 0x000001629A893748>,
#         <__main__.signal_summary object at 0x000001629A8959B0>,
#         <__main__.signal_summary object at 0x000001629A899C18>,
#         <__main__.signal_summary object at 0x000001629A89CE80>,
#         <__main__.signal_summary object at 0x000001629A8A0F28>,
#         <__main__.signal_summary object at 0x000001629A8A6390>,
#         <__main__.signal_summary object at 0x000001629A8A95F8>,
#         <__main__.signal_summary object at 0x000001629A8AC860>,
#         <__main__.signal_summary object at 0x000001629A8B0AC8>,
#         <__main__.signal_summary object at 0x000001629A8B4D30>,
#         <__main__.signal_summary object at 0x000001629A8B6F98>,
#         <__main__.signal_summary object at 0x000001629A8BC240>],
#        dtype=object)}

# %%
len(signal_stat["white-info-2"])
# Out:
# 83

# %%
graph_dir = "graphs/"
if not os.path.exists(graph_dir):
    os.makedirs(graph_dir)

for key in signal_stat.keys():
    if key is not "summary":
        ap = [float(signal.ap) for signal in signal_stat[key]]
        tp = [int(signal.TP) for signal in signal_stat[key]]
        fp = [int(signal.FP) for signal in signal_stat[key]]

        plt.figure(figsize=(15,5))
        plt.subplot(121, title="class: "+key, ylabel="percentage")
        plt.plot(ap, label="average precision in %")
        plt.legend()
        plt.grid(True)

        plt.subplot(122, title="class: "+key, ylabel="amount")
        plt.plot(tp, "g", label="true positive")
        plt.plot(fp, "r", label="false positive")
        plt.legend()
        plt.grid(True)
        plt.savefig("graphs/"+key+".png")
        plt.show()

# %%
key = "summary"
tp = [float(signal.TP) for signal in signal_stat[key]]
fp = [int(signal.FP) for signal in signal_stat[key]]
fn = [int(signal.FN) for signal in signal_stat[key]]
average_iou = [float(signal.average_iou) for signal in signal_stat[key]]
mean_ap = [float(signal.mean_ap) for signal in signal_stat[key]]

plt.figure(figsize=(15,5))
plt.subplot(121, title="class: "+key, ylabel="percentage")
plt.plot(mean_ap, label="mean average precision in %")
plt.plot(average_iou, label="average IoU in %")
plt.legend()
plt.grid(True)

plt.subplot(122, title="class: "+key, ylabel="amount")
plt.plot(tp, "g", label="true positive")
plt.plot(fp, "r", label="false positive")
plt.plot(fn, "m", label="false negative")
plt.legend()
plt.grid(True)
plt.savefig("graphs/"+key+".png")
plt.show()

# %%
plt.figure(figsize=(30,15))
plt.grid(True)
for key in signal_stat.keys():
    if key is not "summary":
        ap = [float(signal.ap) for signal in signal_stat[key]]
        plt.plot(ap, label="average precision in %")
        
plt.show()
