# %%
import glob
import re
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
files = glob.glob("weigth stats\*")
len(files)
# Out:
# 105

# %%
class signal:
    def __init__(self, name, ap, TP, FP):
        self.name = name
        self.ap = ap
        self.TP = TP
        self.FP = FP
    
    def printstats(self):
        print("Signal [ name:{}, ap:{}%, tp:{}, fp:{} ]".format(self.name, self.ap, self.TP, self.FP))
    
class signal_summary:
    def __init__(self, TP, FP, FN, average_iou, mean_ap):
        self.TP = TP
        self.FP = FP
        self.FN = FN
        self.average_iou = average_iou
        self.mean_ap = mean_ap   
        
    def printstats(self):
        print("Summary [ TP:{}, FP:{}, FN:{}, averageIoU:{}%, meanAP:{}% ]".format(self.TP, self.FP, self.FN, self.average_iou, self.mean_ap))

# %%
def addSignalToDictionary(dictionary, key, value):
    if key in dictionary:
        dictionary[str(key)] = np.append(dictionary[str(key)], value)
    else:
        dictionary[str(key)] = np.array([value])

# %%
signal_stat = {}

for file in files:
    with open(file, "r") as openfile:
        summary = signal_summary(0,0,0,0,0)
        for line in openfile:
            
            # get single signal data
            if line.startswith("class_id"):
                result_name = re.search("name = .*, ap", line)
                result_ap = re.search("ap = .*%", line)
                result_tp = re.search("TP = .*,", line)
                result_fp = re.search("FP = .*\)", line)

                if result_name is not None and result_ap is not None and result_tp is not None and result_fp is not None:
                    name = result_name.group().replace(", ap","").replace("name = ","")
                    ap = result_ap.group().replace("ap = ","").replace("%","")
                    tp = result_tp.group().replace("TP = ","").replace(",","")
                    fp = result_fp.group().replace("FP = ","").replace(")","")
                    new_signal = signal(name, ap, tp, fp)
                    #new.printstats()
                    addSignalToDictionary(signal_stat, name, new_signal)
                continue
                    
            # get summary
            if line.startswith(" for thresh"):
                result_tp = re.search("TP = .*, FP", line)
                result_fp = re.search("FP = .*, FN", line)
                result_fn = re.search("FN = .*,", line)
                result_iou = re.search("average IoU = .* %", line)
                
                if result_tp is not None and result_fp is not None and result_fn is not None and result_iou is not None:                    
                    summary.TP = result_tp.group().replace("TP = ","").replace(", FP","")
                    summary.FP = result_fp.group().replace("FP = ","").replace(", FN","")
                    summary.FN = result_fn.group().replace("FN = ","").replace(",","")
                    summary.average_iou = result_iou.group().replace("average IoU = ","").replace(" %","")
                continue
                
            # get mean average precision
            if line.startswith(" mean average"):
                result_map = re.search(", or .* %", line)
                if result_map is not None:
                    summary.mean_ap = result_map.group().replace(", or ", "").replace(" %", "")
                    #summary.printstats()
                    addSignalToDictionary(signal_stat, "summary", summary)
                continue


signal_stat
# Out:
# {'white-info-1': array([<__main__.signal object at 0x000002647FDFC518>,
#         <__main__.signal object at 0x000002647FDEC748>,
#         <__main__.signal object at 0x000002647FDF8940>,
#         <__main__.signal object at 0x000002647FE04BA8>,
#         <__main__.signal object at 0x000002647FE09E10>,
#         <__main__.signal object at 0x000002647FE0C0B8>,
#         <__main__.signal object at 0x000002647FE19320>,
#         <__main__.signal object at 0x000002647FE1B588>,
#         <__main__.signal object at 0x000002647FE1F7F0>,
#         <__main__.signal object at 0x000002647FE23A58>,
#         <__main__.signal object at 0x000002647FE26CC0>,
#         <__main__.signal object at 0x000002647FE29F28>,
#         <__main__.signal object at 0x000002647FE2F1D0>,
#         <__main__.signal object at 0x000002647FE31438>,
#         <__main__.signal object at 0x000002647FE356A0>,
#         <__main__.signal object at 0x000002647FE3A908>,
#         <__main__.signal object at 0x000002647FE3CB70>,
#         <__main__.signal object at 0x000002647FE41DD8>,
#         <__main__.signal object at 0x000002647FE45080>,
#         <__main__.signal object at 0x000002647FE492E8>,
#         <__main__.signal object at 0x000002647FE4C550>,
#         <__main__.signal object at 0x000002647FE507B8>,
#         <__main__.signal object at 0x000002647FE53A20>,
#         <__main__.signal object at 0x000002647FE57C88>,
#         <__main__.signal object at 0x000002647FE5BEF0>,
#         <__main__.signal object at 0x000002647FE60198>,
#         <__main__.signal object at 0x000002647FE63400>,
#         <__main__.signal object at 0x000002647FE66668>,
#         <__main__.signal object at 0x000002647FE6B8D0>,
#         <__main__.signal object at 0x000002647FE6EB38>,
#         <__main__.signal object at 0x000002647FE71DA0>,
#         <__main__.signal object at 0x000002647FE77048>,
#         <__main__.signal object at 0x000002647FE792B0>,
#         <__main__.signal object at 0x000002647FE7E518>,
#         <__main__.signal object at 0x000002647FE81780>,
#         <__main__.signal object at 0x000002647FE849E8>,
#         <__main__.signal object at 0x000002647FE89C50>,
#         <__main__.signal object at 0x000002647FE8CEB8>,
#         <__main__.signal object at 0x000002647FE91160>,
#         <__main__.signal object at 0x000002647FE943C8>,
#         <__main__.signal object at 0x000002647FE98630>,
#         <__main__.signal object at 0x000002647FE9B898>,
#         <__main__.signal object at 0x000002647FE9FB00>,
#         <__main__.signal object at 0x000002647FEA2D68>,
#         <__main__.signal object at 0x000002647FEA6FD0>,
#         <__main__.signal object at 0x000002647FEAB278>,
#         <__main__.signal object at 0x000002647FEAF4E0>,
#         <__main__.signal object at 0x000002647FEB2748>,
#         <__main__.signal object at 0x000002647FEB59B0>,
#         <__main__.signal object at 0x000002647FEBAC18>,
#         <__main__.signal object at 0x000002647FEBCE80>,
#         <__main__.signal object at 0x000002647FEC2128>,
#         <__main__.signal object at 0x000002647FEC7390>,
#         <__main__.signal object at 0x000002647FECA5F8>,
#         <__main__.signal object at 0x000002647FECE860>,
#         <__main__.signal object at 0x000002647FED1AC8>,
#         <__main__.signal object at 0x000002647FED4D30>,
#         <__main__.signal object at 0x000002647FED8F98>,
#         <__main__.signal object at 0x000002647FEDD240>,
#         <__main__.signal object at 0x000002647FEE14A8>,
#         <__main__.signal object at 0x000002647FEE4710>,
#         <__main__.signal object at 0x000002647FEE8978>,
#         <__main__.signal object at 0x000002647FEEBBE0>,
#         <__main__.signal object at 0x000002647FEEFE48>,
#         <__main__.signal object at 0x000002647FEF40F0>,
#         <__main__.signal object at 0x000002647FEF8358>,
#         <__main__.signal object at 0x000002647FEFB5C0>,
#         <__main__.signal object at 0x000002647FEFE828>,
#         <__main__.signal object at 0x000002647FF03A90>,
#         <__main__.signal object at 0x000002647FF05CF8>,
#         <__main__.signal object at 0x000002647FF09F60>,
#         <__main__.signal object at 0x000002647FF0F208>,
#         <__main__.signal object at 0x000002647FF12470>,
#         <__main__.signal object at 0x000002647FF166D8>,
#         <__main__.signal object at 0x000002647FF19940>,
#         <__main__.signal object at 0x000002647FF1CBA8>,
#         <__main__.signal object at 0x000002647FF20E10>,
#         <__main__.signal object at 0x000002647FF250B8>,
#         <__main__.signal object at 0x000002647FF2A320>,
#         <__main__.signal object at 0x000002647FF2C588>,
#         <__main__.signal object at 0x000002647FF307F0>,
#         <__main__.signal object at 0x000002647FF34A58>,
#         <__main__.signal object at 0x000002647FF37CC0>,
#         <__main__.signal object at 0x000002647FF3AF28>,
#         <__main__.signal object at 0x000002647FF401D0>,
#         <__main__.signal object at 0x000002647FF43438>,
#         <__main__.signal object at 0x000002647FF476A0>,
#         <__main__.signal object at 0x000002647FF4B908>,
#         <__main__.signal object at 0x000002647FF4DB70>,
#         <__main__.signal object at 0x000002647FF52DD8>,
#         <__main__.signal object at 0x000002647FF57080>,
#         <__main__.signal object at 0x000002647FF592E8>,
#         <__main__.signal object at 0x000002647FF5E550>,
#         <__main__.signal object at 0x000002647FF617B8>,
#         <__main__.signal object at 0x000002647FF65A20>,
#         <__main__.signal object at 0x000002647FF68C88>,
#         <__main__.signal object at 0x000002647FF6CEF0>,
#         <__main__.signal object at 0x000002647FF72198>,
#         <__main__.signal object at 0x000002647FF74400>,
#         <__main__.signal object at 0x000002647FF78668>,
#         <__main__.signal object at 0x000002647FF7B8D0>,
#         <__main__.signal object at 0x000002647FF7FB38>,
#         <__main__.signal object at 0x000002647FF83DA0>,
#         <__main__.signal object at 0x000002647FF88048>,
#         <__main__.signal object at 0x000002647FF8B2B0>], dtype=object),
#  'white-info-2': array([<__main__.signal object at 0x000002647FDFC5F8>,
#         <__main__.signal object at 0x000002647FDEC828>,
#         <__main__.signal object at 0x000002647FDF8A20>,
#         <__main__.signal object at 0x000002647FE04C88>,
#         <__main__.signal object at 0x000002647FE09EF0>,
#         <__main__.signal object at 0x000002647FE0C198>,
#         <__main__.signal object at 0x000002647FE19400>,
#         <__main__.signal object at 0x000002647FE1B668>,
#         <__main__.signal object at 0x000002647FE1F8D0>,
#         <__main__.signal object at 0x000002647FE23B38>,
#         <__main__.signal object at 0x000002647FE26DA0>,
#         <__main__.signal object at 0x000002647FE2A048>,
#         <__main__.signal object at 0x000002647FE2F2B0>,
#         <__main__.signal object at 0x000002647FE31518>,
#         <__main__.signal object at 0x000002647FE35780>,
#         <__main__.signal object at 0x000002647FE3A9E8>,
#         <__main__.signal object at 0x000002647FE3CC50>,
#         <__main__.signal object at 0x000002647FE41EB8>,
#         <__main__.signal object at 0x000002647FE45160>,
#         <__main__.signal object at 0x000002647FE493C8>,
#         <__main__.signal object at 0x000002647FE4C630>,
#         <__main__.signal object at 0x000002647FE50898>,
#         <__main__.signal object at 0x000002647FE53B00>,
#         <__main__.signal object at 0x000002647FE57D68>,
#         <__main__.signal object at 0x000002647FE5BFD0>,
#         <__main__.signal object at 0x000002647FE60278>,
#         <__main__.signal object at 0x000002647FE634E0>,
#         <__main__.signal object at 0x000002647FE66748>,
#         <__main__.signal object at 0x000002647FE6B9B0>,
#         <__main__.signal object at 0x000002647FE6EC18>,
#         <__main__.signal object at 0x000002647FE71E80>,
#         <__main__.signal object at 0x000002647FE77128>,
#         <__main__.signal object at 0x000002647FE79390>,
#         <__main__.signal object at 0x000002647FE7E5F8>,
#         <__main__.signal object at 0x000002647FE81860>,
#         <__main__.signal object at 0x000002647FE84AC8>,
#         <__main__.signal object at 0x000002647FE89D30>,
#         <__main__.signal object at 0x000002647FE8CF98>,
#         <__main__.signal object at 0x000002647FE91240>,
#         <__main__.signal object at 0x000002647FE944A8>,
#         <__main__.signal object at 0x000002647FE98710>,
#         <__main__.signal object at 0x000002647FE9B978>,
#         <__main__.signal object at 0x000002647FE9FBE0>,
#         <__main__.signal object at 0x000002647FEA2E48>,
#         <__main__.signal object at 0x000002647FEA80F0>,
#         <__main__.signal object at 0x000002647FEAB358>,
#         <__main__.signal object at 0x000002647FEAF5C0>,
#         <__main__.signal object at 0x000002647FEB2828>,
#         <__main__.signal object at 0x000002647FEB5A90>,
#         <__main__.signal object at 0x000002647FEBACF8>,
#         <__main__.signal object at 0x000002647FEBCF60>,
#         <__main__.signal object at 0x000002647FEC2208>,
#         <__main__.signal object at 0x000002647FEC7470>,
#         <__main__.signal object at 0x000002647FECA6D8>,
#         <__main__.signal object at 0x000002647FECE940>,
#         <__main__.signal object at 0x000002647FED1BA8>,
#         <__main__.signal object at 0x000002647FED4E10>,
#         <__main__.signal object at 0x000002647FEDA0B8>,
#         <__main__.signal object at 0x000002647FEDD320>,
#         <__main__.signal object at 0x000002647FEE1588>,
#         <__main__.signal object at 0x000002647FEE47F0>,
#         <__main__.signal object at 0x000002647FEE8A58>,
#         <__main__.signal object at 0x000002647FEEBCC0>,
#         <__main__.signal object at 0x000002647FEEFF28>,
#         <__main__.signal object at 0x000002647FEF41D0>,
#         <__main__.signal object at 0x000002647FEF8438>,
#         <__main__.signal object at 0x000002647FEFB6A0>,
#         <__main__.signal object at 0x000002647FEFE908>,
#         <__main__.signal object at 0x000002647FF03B70>,
#         <__main__.signal object at 0x000002647FF05DD8>,
#         <__main__.signal object at 0x000002647FF0B080>,
#         <__main__.signal object at 0x000002647FF0F2E8>,
#         <__main__.signal object at 0x000002647FF12550>,
#         <__main__.signal object at 0x000002647FF167B8>,
#         <__main__.signal object at 0x000002647FF19A20>,
#         <__main__.signal object at 0x000002647FF1CC88>,
#         <__main__.signal object at 0x000002647FF20EF0>,
#         <__main__.signal object at 0x000002647FF25198>,
#         <__main__.signal object at 0x000002647FF2A400>,
#         <__main__.signal object at 0x000002647FF2C668>,
#         <__main__.signal object at 0x000002647FF308D0>,
#         <__main__.signal object at 0x000002647FF34B38>,
#         <__main__.signal object at 0x000002647FF37DA0>,
#         <__main__.signal object at 0x000002647FF3D048>,
#         <__main__.signal object at 0x000002647FF402B0>,
#         <__main__.signal object at 0x000002647FF43518>,
#         <__main__.signal object at 0x000002647FF47780>,
#         <__main__.signal object at 0x000002647FF4B9E8>,
#         <__main__.signal object at 0x000002647FF4DC50>,
#         <__main__.signal object at 0x000002647FF52EB8>,
#         <__main__.signal object at 0x000002647FF57160>,
#         <__main__.signal object at 0x000002647FF593C8>,
#         <__main__.signal object at 0x000002647FF5E630>,
#         <__main__.signal object at 0x000002647FF61898>,
#         <__main__.signal object at 0x000002647FF65B00>,
#         <__main__.signal object at 0x000002647FF68D68>,
#         <__main__.signal object at 0x000002647FF6CFD0>,
#         <__main__.signal object at 0x000002647FF72278>,
#         <__main__.signal object at 0x000002647FF744E0>,
#         <__main__.signal object at 0x000002647FF78748>,
#         <__main__.signal object at 0x000002647FF7B9B0>,
#         <__main__.signal object at 0x000002647FF7FC18>,
#         <__main__.signal object at 0x000002647FF83E80>,
#         <__main__.signal object at 0x000002647FF88128>,
#         <__main__.signal object at 0x000002647FF8B390>], dtype=object),
#  'white-info-3': array([<__main__.signal object at 0x000002647FDFC6D8>,
#         <__main__.signal object at 0x000002647FDEC908>,
#         <__main__.signal object at 0x000002647FDF8B00>,
#         <__main__.signal object at 0x000002647FE04D68>,
#         <__main__.signal object at 0x000002647FE09FD0>,
#         <__main__.signal object at 0x000002647FE0C278>,
#         <__main__.signal object at 0x000002647FE194E0>,
#         <__main__.signal object at 0x000002647FE1B748>,
#         <__main__.signal object at 0x000002647FE1F9B0>,
#         <__main__.signal object at 0x000002647FE23C18>,
#         <__main__.signal object at 0x000002647FE26E80>,
#         <__main__.signal object at 0x000002647FE2A128>,
#         <__main__.signal object at 0x000002647FE2F390>,
#         <__main__.signal object at 0x000002647FE315F8>,
#         <__main__.signal object at 0x000002647FE35860>,
#         <__main__.signal object at 0x000002647FE3AAC8>,
#         <__main__.signal object at 0x000002647FE3CD30>,
#         <__main__.signal object at 0x000002647FE41F98>,
#         <__main__.signal object at 0x000002647FE45240>,
#         <__main__.signal object at 0x000002647FE494A8>,
#         <__main__.signal object at 0x000002647FE4C710>,
#         <__main__.signal object at 0x000002647FE50978>,
#         <__main__.signal object at 0x000002647FE53BE0>,
#         <__main__.signal object at 0x000002647FE57E48>,
#         <__main__.signal object at 0x000002647FE5C0F0>,
#         <__main__.signal object at 0x000002647FE60358>,
#         <__main__.signal object at 0x000002647FE635C0>,
#         <__main__.signal object at 0x000002647FE66828>,
#         <__main__.signal object at 0x000002647FE6BA90>,
#         <__main__.signal object at 0x000002647FE6ECF8>,
#         <__main__.signal object at 0x000002647FE71F60>,
#         <__main__.signal object at 0x000002647FE77208>,
#         <__main__.signal object at 0x000002647FE79470>,
#         <__main__.signal object at 0x000002647FE7E6D8>,
#         <__main__.signal object at 0x000002647FE81940>,
#         <__main__.signal object at 0x000002647FE84BA8>,
#         <__main__.signal object at 0x000002647FE89E10>,
#         <__main__.signal object at 0x000002647FE8D0B8>,
#         <__main__.signal object at 0x000002647FE91320>,
#         <__main__.signal object at 0x000002647FE94588>,
#         <__main__.signal object at 0x000002647FE987F0>,
#         <__main__.signal object at 0x000002647FE9BA58>,
#         <__main__.signal object at 0x000002647FE9FCC0>,
#         <__main__.signal object at 0x000002647FEA2F28>,
#         <__main__.signal object at 0x000002647FEA81D0>,
#         <__main__.signal object at 0x000002647FEAB438>,
#         <__main__.signal object at 0x000002647FEAF6A0>,
#         <__main__.signal object at 0x000002647FEB2908>,
#         <__main__.signal object at 0x000002647FEB5B70>,
#         <__main__.signal object at 0x000002647FEBADD8>,
#         <__main__.signal object at 0x000002647FEC0080>,
#         <__main__.signal object at 0x000002647FEC22E8>,
#         <__main__.signal object at 0x000002647FEC7550>,
#         <__main__.signal object at 0x000002647FECA7B8>,
#         <__main__.signal object at 0x000002647FECEA20>,
#         <__main__.signal object at 0x000002647FED1C88>,
#         <__main__.signal object at 0x000002647FED4EF0>,
#         <__main__.signal object at 0x000002647FEDA198>,
#         <__main__.signal object at 0x000002647FEDD400>,
#         <__main__.signal object at 0x000002647FEE1668>,
#         <__main__.signal object at 0x000002647FEE48D0>,
#         <__main__.signal object at 0x000002647FEE8B38>,
#         <__main__.signal object at 0x000002647FEEBDA0>,
#         <__main__.signal object at 0x000002647FEF1048>,
#         <__main__.signal object at 0x000002647FEF42B0>,
#         <__main__.signal object at 0x000002647FEF8518>,
#         <__main__.signal object at 0x000002647FEFB780>,
#         <__main__.signal object at 0x000002647FEFE9E8>,
#         <__main__.signal object at 0x000002647FF03C50>,
#         <__main__.signal object at 0x000002647FF05EB8>,
#         <__main__.signal object at 0x000002647FF0B160>,
#         <__main__.signal object at 0x000002647FF0F3C8>,
#         <__main__.signal object at 0x000002647FF12630>,
#         <__main__.signal object at 0x000002647FF16898>,
#         <__main__.signal object at 0x000002647FF19B00>,
#         <__main__.signal object at 0x000002647FF1CD68>,
#         <__main__.signal object at 0x000002647FF20FD0>,
#         <__main__.signal object at 0x000002647FF25278>,
#         <__main__.signal object at 0x000002647FF2A4E0>,
#         <__main__.signal object at 0x000002647FF2C748>,
#         <__main__.signal object at 0x000002647FF309B0>,
#         <__main__.signal object at 0x000002647FF34C18>,
#         <__main__.signal object at 0x000002647FF37E80>,
#         <__main__.signal object at 0x000002647FF3D128>,
#         <__main__.signal object at 0x000002647FF40390>,
#         <__main__.signal object at 0x000002647FF435F8>,
#         <__main__.signal object at 0x000002647FF47860>,
#         <__main__.signal object at 0x000002647FF4BAC8>,
#         <__main__.signal object at 0x000002647FF4DD30>,
#         <__main__.signal object at 0x000002647FF52F98>,
#         <__main__.signal object at 0x000002647FF57240>,
#         <__main__.signal object at 0x000002647FF594A8>,
#         <__main__.signal object at 0x000002647FF5E710>,
#         <__main__.signal object at 0x000002647FF61978>,
#         <__main__.signal object at 0x000002647FF65BE0>,
#         <__main__.signal object at 0x000002647FF68E48>,
#         <__main__.signal object at 0x000002647FF6D0F0>,
#         <__main__.signal object at 0x000002647FF72358>,
#         <__main__.signal object at 0x000002647FF745C0>,
#         <__main__.signal object at 0x000002647FF78828>,
#         <__main__.signal object at 0x000002647FF7BA90>,
#         <__main__.signal object at 0x000002647FF7FCF8>,
#         <__main__.signal object at 0x000002647FF83F60>,
#         <__main__.signal object at 0x000002647FF88208>,
#         <__main__.signal object at 0x000002647FF8B470>], dtype=object),
#  'white-info-4': array([<__main__.signal object at 0x000002647FDFC7B8>,
#         <__main__.signal object at 0x000002647FDEC9E8>,
#         <__main__.signal object at 0x000002647FDF8BE0>,
#         <__main__.signal object at 0x000002647FE04E48>,
#         <__main__.signal object at 0x000002647FE070F0>,
#         <__main__.signal object at 0x000002647FE0C358>,
#         <__main__.signal object at 0x000002647FE195C0>,
#         <__main__.signal object at 0x000002647FE1B828>,
#         <__main__.signal object at 0x000002647FE1FA90>,
#         <__main__.signal object at 0x000002647FE23CF8>,
#         <__main__.signal object at 0x000002647FE26F60>,
#         <__main__.signal object at 0x000002647FE2A208>,
#         <__main__.signal object at 0x000002647FE2F470>,
#         <__main__.signal object at 0x000002647FE316D8>,
#         <__main__.signal object at 0x000002647FE35940>,
#         <__main__.signal object at 0x000002647FE3ABA8>,
#         <__main__.signal object at 0x000002647FE3CE10>,
#         <__main__.signal object at 0x000002647FE420B8>,
#         <__main__.signal object at 0x000002647FE45320>,
#         <__main__.signal object at 0x000002647FE49588>,
#         <__main__.signal object at 0x000002647FE4C7F0>,
#         <__main__.signal object at 0x000002647FE50A58>,
#         <__main__.signal object at 0x000002647FE53CC0>,
#         <__main__.signal object at 0x000002647FE57F28>,
#         <__main__.signal object at 0x000002647FE5C1D0>,
#         <__main__.signal object at 0x000002647FE60438>,
#         <__main__.signal object at 0x000002647FE636A0>,
#         <__main__.signal object at 0x000002647FE66908>,
#         <__main__.signal object at 0x000002647FE6BB70>,
#         <__main__.signal object at 0x000002647FE6EDD8>,
#         <__main__.signal object at 0x000002647FE73080>,
#         <__main__.signal object at 0x000002647FE772E8>,
#         <__main__.signal object at 0x000002647FE79550>,
#         <__main__.signal object at 0x000002647FE7E7B8>,
#         <__main__.signal object at 0x000002647FE81A20>,
#         <__main__.signal object at 0x000002647FE84C88>,
#         <__main__.signal object at 0x000002647FE89EF0>,
#         <__main__.signal object at 0x000002647FE8D198>,
#         <__main__.signal object at 0x000002647FE91400>,
#         <__main__.signal object at 0x000002647FE94668>,
#         <__main__.signal object at 0x000002647FE988D0>,
#         <__main__.signal object at 0x000002647FE9BB38>,
#         <__main__.signal object at 0x000002647FE9FDA0>,
#         <__main__.signal object at 0x000002647FEA4048>,
#         <__main__.signal object at 0x000002647FEA82B0>,
#         <__main__.signal object at 0x000002647FEAB518>,
#         <__main__.signal object at 0x000002647FEAF780>,
#         <__main__.signal object at 0x000002647FEB29E8>,
#         <__main__.signal object at 0x000002647FEB5C50>,
#         <__main__.signal object at 0x000002647FEBAEB8>,
#         <__main__.signal object at 0x000002647FEC0160>,
#         <__main__.signal object at 0x000002647FEC23C8>,
#         <__main__.signal object at 0x000002647FEC7630>,
#         <__main__.signal object at 0x000002647FECA898>,
#         <__main__.signal object at 0x000002647FECEB00>,
#         <__main__.signal object at 0x000002647FED1D68>,
#         <__main__.signal object at 0x000002647FED4FD0>,
#         <__main__.signal object at 0x000002647FEDA278>,
#         <__main__.signal object at 0x000002647FEDD4E0>,
#         <__main__.signal object at 0x000002647FEE1748>,
#         <__main__.signal object at 0x000002647FEE49B0>,
#         <__main__.signal object at 0x000002647FEE8C18>,
#         <__main__.signal object at 0x000002647FEEBE80>,
#         <__main__.signal object at 0x000002647FEF1128>,
#         <__main__.signal object at 0x000002647FEF4390>,
#         <__main__.signal object at 0x000002647FEF85F8>,
#         <__main__.signal object at 0x000002647FEFB860>,
#         <__main__.signal object at 0x000002647FEFEAC8>,
#         <__main__.signal object at 0x000002647FF03D30>,
#         <__main__.signal object at 0x000002647FF05F98>,
#         <__main__.signal object at 0x000002647FF0B240>,
#         <__main__.signal object at 0x000002647FF0F4A8>,
#         <__main__.signal object at 0x000002647FF12710>,
#         <__main__.signal object at 0x000002647FF16978>,
#         <__main__.signal object at 0x000002647FF19BE0>,
#         <__main__.signal object at 0x000002647FF1CE48>,
#         <__main__.signal object at 0x000002647FF220F0>,
#         <__main__.signal object at 0x000002647FF25358>,
#         <__main__.signal object at 0x000002647FF2A5C0>,
#         <__main__.signal object at 0x000002647FF2C828>,
#         <__main__.signal object at 0x000002647FF30A90>,
#         <__main__.signal object at 0x000002647FF34CF8>,
#         <__main__.signal object at 0x000002647FF37F60>,
#         <__main__.signal object at 0x000002647FF3D208>,
#         <__main__.signal object at 0x000002647FF40470>,
#         <__main__.signal object at 0x000002647FF436D8>,
#         <__main__.signal object at 0x000002647FF47940>,
#         <__main__.signal object at 0x000002647FF4BBA8>,
#         <__main__.signal object at 0x000002647FF4DE10>,
#         <__main__.signal object at 0x000002647FF530B8>,
#         <__main__.signal object at 0x000002647FF57320>,
#         <__main__.signal object at 0x000002647FF59588>,
#         <__main__.signal object at 0x000002647FF5E7F0>,
#         <__main__.signal object at 0x000002647FF61A58>,
#         <__main__.signal object at 0x000002647FF65CC0>,
#         <__main__.signal object at 0x000002647FF68F28>,
#         <__main__.signal object at 0x000002647FF6D1D0>,
#         <__main__.signal object at 0x000002647FF72438>,
#         <__main__.signal object at 0x000002647FF746A0>,
#         <__main__.signal object at 0x000002647FF78908>,
#         <__main__.signal object at 0x000002647FF7BB70>,
#         <__main__.signal object at 0x000002647FF7FDD8>,
#         <__main__.signal object at 0x000002647FF84080>,
#         <__main__.signal object at 0x000002647FF882E8>,
#         <__main__.signal object at 0x000002647FF8B550>], dtype=object),
#  'white-info-5': array([<__main__.signal object at 0x000002647FDFC898>,
#         <__main__.signal object at 0x000002647FDECAC8>,
#         <__main__.signal object at 0x000002647FDF8CC0>,
#         <__main__.signal object at 0x000002647FE04F28>,
#         <__main__.signal object at 0x000002647FE071D0>,
#         <__main__.signal object at 0x000002647FE0C438>,
#         <__main__.signal object at 0x000002647FE196A0>,
#         <__main__.signal object at 0x000002647FE1B908>,
#         <__main__.signal object at 0x000002647FE1FB70>,
#         <__main__.signal object at 0x000002647FE23DD8>,
#         <__main__.signal object at 0x000002647FE28080>,
#         <__main__.signal object at 0x000002647FE2A2E8>,
#         <__main__.signal object at 0x000002647FE2F550>,
#         <__main__.signal object at 0x000002647FE317B8>,
#         <__main__.signal object at 0x000002647FE35A20>,
#         <__main__.signal object at 0x000002647FE3AC88>,
#         <__main__.signal object at 0x000002647FE3CEF0>,
#         <__main__.signal object at 0x000002647FE42198>,
#         <__main__.signal object at 0x000002647FE45400>,
#         <__main__.signal object at 0x000002647FE49668>,
#         <__main__.signal object at 0x000002647FE4C8D0>,
#         <__main__.signal object at 0x000002647FE50B38>,
#         <__main__.signal object at 0x000002647FE53DA0>,
#         <__main__.signal object at 0x000002647FE58048>,
#         <__main__.signal object at 0x000002647FE5C2B0>,
#         <__main__.signal object at 0x000002647FE60518>,
#         <__main__.signal object at 0x000002647FE63780>,
#         <__main__.signal object at 0x000002647FE669E8>,
#         <__main__.signal object at 0x000002647FE6BC50>,
#         <__main__.signal object at 0x000002647FE6EEB8>,
#         <__main__.signal object at 0x000002647FE73160>,
#         <__main__.signal object at 0x000002647FE773C8>,
#         <__main__.signal object at 0x000002647FE79630>,
#         <__main__.signal object at 0x000002647FE7E898>,
#         <__main__.signal object at 0x000002647FE81B00>,
#         <__main__.signal object at 0x000002647FE84D68>,
#         <__main__.signal object at 0x000002647FE89FD0>,
#         <__main__.signal object at 0x000002647FE8D278>,
#         <__main__.signal object at 0x000002647FE914E0>,
#         <__main__.signal object at 0x000002647FE94748>,
#         <__main__.signal object at 0x000002647FE989B0>,
#         <__main__.signal object at 0x000002647FE9BC18>,
#         <__main__.signal object at 0x000002647FE9FE80>,
#         <__main__.signal object at 0x000002647FEA4128>,
#         <__main__.signal object at 0x000002647FEA8390>,
#         <__main__.signal object at 0x000002647FEAB5F8>,
#         <__main__.signal object at 0x000002647FEAF860>,
#         <__main__.signal object at 0x000002647FEB2AC8>,
#         <__main__.signal object at 0x000002647FEB5D30>,
#         <__main__.signal object at 0x000002647FEBAF98>,
#         <__main__.signal object at 0x000002647FEC0240>,
#         <__main__.signal object at 0x000002647FEC24A8>,
#         <__main__.signal object at 0x000002647FEC7710>,
#         <__main__.signal object at 0x000002647FECA978>,
#         <__main__.signal object at 0x000002647FECEBE0>,
#         <__main__.signal object at 0x000002647FED1E48>,
#         <__main__.signal object at 0x000002647FED60F0>,
#         <__main__.signal object at 0x000002647FEDA358>,
#         <__main__.signal object at 0x000002647FEDD5C0>,
#         <__main__.signal object at 0x000002647FEE1828>,
#         <__main__.signal object at 0x000002647FEE4A90>,
#         <__main__.signal object at 0x000002647FEE8CF8>,
#         <__main__.signal object at 0x000002647FEEBF60>,
#         <__main__.signal object at 0x000002647FEF1208>,
#         <__main__.signal object at 0x000002647FEF4470>,
#         <__main__.signal object at 0x000002647FEF86D8>,
#         <__main__.signal object at 0x000002647FEFB940>,
#         <__main__.signal object at 0x000002647FEFEBA8>,
#         <__main__.signal object at 0x000002647FF03E10>,
#         <__main__.signal object at 0x000002647FF080B8>,
#         <__main__.signal object at 0x000002647FF0B320>,
#         <__main__.signal object at 0x000002647FF0F588>,
#         <__main__.signal object at 0x000002647FF127F0>,
#         <__main__.signal object at 0x000002647FF16A58>,
#         <__main__.signal object at 0x000002647FF19CC0>,
#         <__main__.signal object at 0x000002647FF1CF28>,
#         <__main__.signal object at 0x000002647FF221D0>,
#         <__main__.signal object at 0x000002647FF25438>,
#         <__main__.signal object at 0x000002647FF2A6A0>,
#         <__main__.signal object at 0x000002647FF2C908>,
#         <__main__.signal object at 0x000002647FF30B70>,
#         <__main__.signal object at 0x000002647FF34DD8>,
#         <__main__.signal object at 0x000002647FF38080>,
#         <__main__.signal object at 0x000002647FF3D2E8>,
#         <__main__.signal object at 0x000002647FF40550>,
#         <__main__.signal object at 0x000002647FF437B8>,
#         <__main__.signal object at 0x000002647FF47A20>,
#         <__main__.signal object at 0x000002647FF4BC88>,
#         <__main__.signal object at 0x000002647FF4DEF0>,
#         <__main__.signal object at 0x000002647FF53198>,
#         <__main__.signal object at 0x000002647FF57400>,
#         <__main__.signal object at 0x000002647FF59668>,
#         <__main__.signal object at 0x000002647FF5E8D0>,
#         <__main__.signal object at 0x000002647FF61B38>,
#         <__main__.signal object at 0x000002647FF65DA0>,
#         <__main__.signal object at 0x000002647FF69048>,
#         <__main__.signal object at 0x000002647FF6D2B0>,
#         <__main__.signal object at 0x000002647FF72518>,
#         <__main__.signal object at 0x000002647FF74780>,
#         <__main__.signal object at 0x000002647FF789E8>,
#         <__main__.signal object at 0x000002647FF7BC50>,
#         <__main__.signal object at 0x000002647FF7FEB8>,
#         <__main__.signal object at 0x000002647FF84160>,
#         <__main__.signal object at 0x000002647FF883C8>,
#         <__main__.signal object at 0x000002647FF8B630>], dtype=object),
#  'white-info-6': array([<__main__.signal object at 0x000002647FDFC978>,
#         <__main__.signal object at 0x000002647FDECBA8>,
#         <__main__.signal object at 0x000002647FDF8DA0>,
#         <__main__.signal object at 0x000002647FE06048>,
#         <__main__.signal object at 0x000002647FE072B0>,
#         <__main__.signal object at 0x000002647FE0C518>,
#         <__main__.signal object at 0x000002647FE19780>,
#         <__main__.signal object at 0x000002647FE1B9E8>,
#         <__main__.signal object at 0x000002647FE1FC50>,
#         <__main__.signal object at 0x000002647FE23EB8>,
#         <__main__.signal object at 0x000002647FE28160>,
#         <__main__.signal object at 0x000002647FE2A3C8>,
#         <__main__.signal object at 0x000002647FE2F630>,
#         <__main__.signal object at 0x000002647FE31898>,
#         <__main__.signal object at 0x000002647FE35B00>,
#         <__main__.signal object at 0x000002647FE3AD68>,
#         <__main__.signal object at 0x000002647FE3CFD0>,
#         <__main__.signal object at 0x000002647FE42278>,
#         <__main__.signal object at 0x000002647FE454E0>,
#         <__main__.signal object at 0x000002647FE49748>,
#         <__main__.signal object at 0x000002647FE4C9B0>,
#         <__main__.signal object at 0x000002647FE50C18>,
#         <__main__.signal object at 0x000002647FE53E80>,
#         <__main__.signal object at 0x000002647FE58128>,
#         <__main__.signal object at 0x000002647FE5C390>,
#         <__main__.signal object at 0x000002647FE605F8>,
#         <__main__.signal object at 0x000002647FE63860>,
#         <__main__.signal object at 0x000002647FE66AC8>,
#         <__main__.signal object at 0x000002647FE6BD30>,
#         <__main__.signal object at 0x000002647FE6EF98>,
#         <__main__.signal object at 0x000002647FE73240>,
#         <__main__.signal object at 0x000002647FE774A8>,
#         <__main__.signal object at 0x000002647FE79710>,
#         <__main__.signal object at 0x000002647FE7E978>,
#         <__main__.signal object at 0x000002647FE81BE0>,
#         <__main__.signal object at 0x000002647FE84E48>,
#         <__main__.signal object at 0x000002647FE8A0F0>,
#         <__main__.signal object at 0x000002647FE8D358>,
#         <__main__.signal object at 0x000002647FE915C0>,
#         <__main__.signal object at 0x000002647FE94828>,
#         <__main__.signal object at 0x000002647FE98A90>,
#         <__main__.signal object at 0x000002647FE9BCF8>,
#         <__main__.signal object at 0x000002647FE9FF60>,
#         <__main__.signal object at 0x000002647FEA4208>,
#         <__main__.signal object at 0x000002647FEA8470>,
#         <__main__.signal object at 0x000002647FEAB6D8>,
#         <__main__.signal object at 0x000002647FEAF940>,
#         <__main__.signal object at 0x000002647FEB2BA8>,
#         <__main__.signal object at 0x000002647FEB5E10>,
#         <__main__.signal object at 0x000002647FEBB0B8>,
#         <__main__.signal object at 0x000002647FEC0320>,
#         <__main__.signal object at 0x000002647FEC2588>,
#         <__main__.signal object at 0x000002647FEC77F0>,
#         <__main__.signal object at 0x000002647FECAA58>,
#         <__main__.signal object at 0x000002647FECECC0>,
#         <__main__.signal object at 0x000002647FED1F28>,
#         <__main__.signal object at 0x000002647FED61D0>,
#         <__main__.signal object at 0x000002647FEDA438>,
#         <__main__.signal object at 0x000002647FEDD6A0>,
#         <__main__.signal object at 0x000002647FEE1908>,
#         <__main__.signal object at 0x000002647FEE4B70>,
#         <__main__.signal object at 0x000002647FEE8DD8>,
#         <__main__.signal object at 0x000002647FEEE080>,
#         <__main__.signal object at 0x000002647FEF12E8>,
#         <__main__.signal object at 0x000002647FEF4550>,
#         <__main__.signal object at 0x000002647FEF87B8>,
#         <__main__.signal object at 0x000002647FEFBA20>,
#         <__main__.signal object at 0x000002647FEFEC88>,
#         <__main__.signal object at 0x000002647FF03EF0>,
#         <__main__.signal object at 0x000002647FF08198>,
#         <__main__.signal object at 0x000002647FF0B400>,
#         <__main__.signal object at 0x000002647FF0F668>,
#         <__main__.signal object at 0x000002647FF128D0>,
#         <__main__.signal object at 0x000002647FF16B38>,
#         <__main__.signal object at 0x000002647FF19DA0>,
#         <__main__.signal object at 0x000002647FF1F048>,
#         <__main__.signal object at 0x000002647FF222B0>,
#         <__main__.signal object at 0x000002647FF25518>,
#         <__main__.signal object at 0x000002647FF2A780>,
#         <__main__.signal object at 0x000002647FF2C9E8>,
#         <__main__.signal object at 0x000002647FF30C50>,
#         <__main__.signal object at 0x000002647FF34EB8>,
#         <__main__.signal object at 0x000002647FF38160>,
#         <__main__.signal object at 0x000002647FF3D3C8>,
#         <__main__.signal object at 0x000002647FF40630>,
#         <__main__.signal object at 0x000002647FF43898>,
#         <__main__.signal object at 0x000002647FF47B00>,
#         <__main__.signal object at 0x000002647FF4BD68>,
#         <__main__.signal object at 0x000002647FF4DFD0>,
#         <__main__.signal object at 0x000002647FF53278>,
#         <__main__.signal object at 0x000002647FF574E0>,
#         <__main__.signal object at 0x000002647FF59748>,
#         <__main__.signal object at 0x000002647FF5E9B0>,
#         <__main__.signal object at 0x000002647FF61C18>,
#         <__main__.signal object at 0x000002647FF65E80>,
#         <__main__.signal object at 0x000002647FF69128>,
#         <__main__.signal object at 0x000002647FF6D390>,
#         <__main__.signal object at 0x000002647FF725F8>,
#         <__main__.signal object at 0x000002647FF74860>,
#         <__main__.signal object at 0x000002647FF78AC8>,
#         <__main__.signal object at 0x000002647FF7BD30>,
#         <__main__.signal object at 0x000002647FF7FF98>,
#         <__main__.signal object at 0x000002647FF84240>,
#         <__main__.signal object at 0x000002647FF884A8>,
#         <__main__.signal object at 0x000002647FF8B710>], dtype=object),
#  'white-info-7': array([<__main__.signal object at 0x000002647FDFCA58>,
#         <__main__.signal object at 0x000002647FDECC88>,
#         <__main__.signal object at 0x000002647FDF8E80>,
#         <__main__.signal object at 0x000002647FE06128>,
#         <__main__.signal object at 0x000002647FE07390>,
#         <__main__.signal object at 0x000002647FE0C5F8>,
#         <__main__.signal object at 0x000002647FE19860>,
#         <__main__.signal object at 0x000002647FE1BAC8>,
#         <__main__.signal object at 0x000002647FE1FD30>,
#         <__main__.signal object at 0x000002647FE23F98>,
#         <__main__.signal object at 0x000002647FE28240>,
#         <__main__.signal object at 0x000002647FE2A4A8>,
#         <__main__.signal object at 0x000002647FE2F710>,
#         <__main__.signal object at 0x000002647FE31978>,
#         <__main__.signal object at 0x000002647FE35BE0>,
#         <__main__.signal object at 0x000002647FE3AE48>,
#         <__main__.signal object at 0x000002647FE3E0F0>,
#         <__main__.signal object at 0x000002647FE42358>,
#         <__main__.signal object at 0x000002647FE455C0>,
#         <__main__.signal object at 0x000002647FE49828>,
#         <__main__.signal object at 0x000002647FE4CA90>,
#         <__main__.signal object at 0x000002647FE50CF8>,
#         <__main__.signal object at 0x000002647FE53F60>,
#         <__main__.signal object at 0x000002647FE58208>,
#         <__main__.signal object at 0x000002647FE5C470>,
#         <__main__.signal object at 0x000002647FE606D8>,
#         <__main__.signal object at 0x000002647FE63940>,
#         <__main__.signal object at 0x000002647FE66BA8>,
#         <__main__.signal object at 0x000002647FE6BE10>,
#         <__main__.signal object at 0x000002647FE700B8>,
#         <__main__.signal object at 0x000002647FE73320>,
#         <__main__.signal object at 0x000002647FE77588>,
#         <__main__.signal object at 0x000002647FE797F0>,
#         <__main__.signal object at 0x000002647FE7EA58>,
#         <__main__.signal object at 0x000002647FE81CC0>,
#         <__main__.signal object at 0x000002647FE84F28>,
#         <__main__.signal object at 0x000002647FE8A1D0>,
#         <__main__.signal object at 0x000002647FE8D438>,
#         <__main__.signal object at 0x000002647FE916A0>,
#         <__main__.signal object at 0x000002647FE94908>,
#         <__main__.signal object at 0x000002647FE98B70>,
#         <__main__.signal object at 0x000002647FE9BDD8>,
#         <__main__.signal object at 0x000002647FEA0080>,
#         <__main__.signal object at 0x000002647FEA42E8>,
#         <__main__.signal object at 0x000002647FEA8550>,
#         <__main__.signal object at 0x000002647FEAB7B8>,
#         <__main__.signal object at 0x000002647FEAFA20>,
#         <__main__.signal object at 0x000002647FEB2C88>,
#         <__main__.signal object at 0x000002647FEB5EF0>,
#         <__main__.signal object at 0x000002647FEBB198>,
#         <__main__.signal object at 0x000002647FEC0400>,
#         <__main__.signal object at 0x000002647FEC2668>,
#         <__main__.signal object at 0x000002647FEC78D0>,
#         <__main__.signal object at 0x000002647FECAB38>,
#         <__main__.signal object at 0x000002647FECEDA0>,
#         <__main__.signal object at 0x000002647FED3048>,
#         <__main__.signal object at 0x000002647FED62B0>,
#         <__main__.signal object at 0x000002647FEDA518>,
#         <__main__.signal object at 0x000002647FEDD780>,
#         <__main__.signal object at 0x000002647FEE19E8>,
#         <__main__.signal object at 0x000002647FEE4C50>,
#         <__main__.signal object at 0x000002647FEE8EB8>,
#         <__main__.signal object at 0x000002647FEEE160>,
#         <__main__.signal object at 0x000002647FEF13C8>,
#         <__main__.signal object at 0x000002647FEF4630>,
#         <__main__.signal object at 0x000002647FEF8898>,
#         <__main__.signal object at 0x000002647FEFBB00>,
#         <__main__.signal object at 0x000002647FEFED68>,
#         <__main__.signal object at 0x000002647FF03FD0>,
#         <__main__.signal object at 0x000002647FF08278>,
#         <__main__.signal object at 0x000002647FF0B4E0>,
#         <__main__.signal object at 0x000002647FF0F748>,
#         <__main__.signal object at 0x000002647FF129B0>,
#         <__main__.signal object at 0x000002647FF16C18>,
#         <__main__.signal object at 0x000002647FF19E80>,
#         <__main__.signal object at 0x000002647FF1F128>,
#         <__main__.signal object at 0x000002647FF22390>,
#         <__main__.signal object at 0x000002647FF255F8>,
#         <__main__.signal object at 0x000002647FF2A860>,
#         <__main__.signal object at 0x000002647FF2CAC8>,
#         <__main__.signal object at 0x000002647FF30D30>,
#         <__main__.signal object at 0x000002647FF34F98>,
#         <__main__.signal object at 0x000002647FF38240>,
#         <__main__.signal object at 0x000002647FF3D4A8>,
#         <__main__.signal object at 0x000002647FF40710>,
#         <__main__.signal object at 0x000002647FF43978>,
#         <__main__.signal object at 0x000002647FF47BE0>,
#         <__main__.signal object at 0x000002647FF4BE48>,
#         <__main__.signal object at 0x000002647FF500F0>,
#         <__main__.signal object at 0x000002647FF53358>,
#         <__main__.signal object at 0x000002647FF575C0>,
#         <__main__.signal object at 0x000002647FF59828>,
#         <__main__.signal object at 0x000002647FF5EA90>,
#         <__main__.signal object at 0x000002647FF61CF8>,
#         <__main__.signal object at 0x000002647FF65F60>,
#         <__main__.signal object at 0x000002647FF69208>,
#         <__main__.signal object at 0x000002647FF6D470>,
#         <__main__.signal object at 0x000002647FF726D8>,
#         <__main__.signal object at 0x000002647FF74940>,
#         <__main__.signal object at 0x000002647FF78BA8>,
#         <__main__.signal object at 0x000002647FF7BE10>,
#         <__main__.signal object at 0x000002647FF800B8>,
#         <__main__.signal object at 0x000002647FF84320>,
#         <__main__.signal object at 0x000002647FF88588>,
#         <__main__.signal object at 0x000002647FF8B7F0>], dtype=object),
#  'white-info-8': array([<__main__.signal object at 0x000002647FDFCB38>,
#         <__main__.signal object at 0x000002647FDECD68>,
#         <__main__.signal object at 0x000002647FDF8F60>,
#         <__main__.signal object at 0x000002647FE06208>,
#         <__main__.signal object at 0x000002647FE07470>,
#         <__main__.signal object at 0x000002647FE0C6D8>,
#         <__main__.signal object at 0x000002647FE19940>,
#         <__main__.signal object at 0x000002647FE1BBA8>,
#         <__main__.signal object at 0x000002647FE1FE10>,
#         <__main__.signal object at 0x000002647FE240B8>,
#         <__main__.signal object at 0x000002647FE28320>,
#         <__main__.signal object at 0x000002647FE2A588>,
#         <__main__.signal object at 0x000002647FE2F7F0>,
#         <__main__.signal object at 0x000002647FE31A58>,
#         <__main__.signal object at 0x000002647FE35CC0>,
#         <__main__.signal object at 0x000002647FE3AF28>,
#         <__main__.signal object at 0x000002647FE3E1D0>,
#         <__main__.signal object at 0x000002647FE42438>,
#         <__main__.signal object at 0x000002647FE456A0>,
#         <__main__.signal object at 0x000002647FE49908>,
#         <__main__.signal object at 0x000002647FE4CB70>,
#         <__main__.signal object at 0x000002647FE50DD8>,
#         <__main__.signal object at 0x000002647FE56080>,
#         <__main__.signal object at 0x000002647FE582E8>,
#         <__main__.signal object at 0x000002647FE5C550>,
#         <__main__.signal object at 0x000002647FE607B8>,
#         <__main__.signal object at 0x000002647FE63A20>,
#         <__main__.signal object at 0x000002647FE66C88>,
#         <__main__.signal object at 0x000002647FE6BEF0>,
#         <__main__.signal object at 0x000002647FE70198>,
#         <__main__.signal object at 0x000002647FE73400>,
#         <__main__.signal object at 0x000002647FE77668>,
#         <__main__.signal object at 0x000002647FE798D0>,
#         <__main__.signal object at 0x000002647FE7EB38>,
#         <__main__.signal object at 0x000002647FE81DA0>,
#         <__main__.signal object at 0x000002647FE87048>,
#         <__main__.signal object at 0x000002647FE8A2B0>,
#         <__main__.signal object at 0x000002647FE8D518>,
#         <__main__.signal object at 0x000002647FE91780>,
#         <__main__.signal object at 0x000002647FE949E8>,
#         <__main__.signal object at 0x000002647FE98C50>,
#         <__main__.signal object at 0x000002647FE9BEB8>,
#         <__main__.signal object at 0x000002647FEA0160>,
#         <__main__.signal object at 0x000002647FEA43C8>,
#         <__main__.signal object at 0x000002647FEA8630>,
#         <__main__.signal object at 0x000002647FEAB898>,
#         <__main__.signal object at 0x000002647FEAFB00>,
#         <__main__.signal object at 0x000002647FEB2D68>,
#         <__main__.signal object at 0x000002647FEB5FD0>,
#         <__main__.signal object at 0x000002647FEBB278>,
#         <__main__.signal object at 0x000002647FEC04E0>,
#         <__main__.signal object at 0x000002647FEC2748>,
#         <__main__.signal object at 0x000002647FEC79B0>,
#         <__main__.signal object at 0x000002647FECAC18>,
#         <__main__.signal object at 0x000002647FECEE80>,
#         <__main__.signal object at 0x000002647FED3128>,
#         <__main__.signal object at 0x000002647FED6390>,
#         <__main__.signal object at 0x000002647FEDA5F8>,
#         <__main__.signal object at 0x000002647FEDD860>,
#         <__main__.signal object at 0x000002647FEE1AC8>,
#         <__main__.signal object at 0x000002647FEE4D30>,
#         <__main__.signal object at 0x000002647FEE8F98>,
#         <__main__.signal object at 0x000002647FEEE240>,
#         <__main__.signal object at 0x000002647FEF14A8>,
#         <__main__.signal object at 0x000002647FEF4710>,
#         <__main__.signal object at 0x000002647FEF8978>,
#         <__main__.signal object at 0x000002647FEFBBE0>,
#         <__main__.signal object at 0x000002647FEFEE48>,
#         <__main__.signal object at 0x000002647FF040F0>,
#         <__main__.signal object at 0x000002647FF08358>,
#         <__main__.signal object at 0x000002647FF0B5C0>,
#         <__main__.signal object at 0x000002647FF0F828>,
#         <__main__.signal object at 0x000002647FF12A90>,
#         <__main__.signal object at 0x000002647FF16CF8>,
#         <__main__.signal object at 0x000002647FF19F60>,
#         <__main__.signal object at 0x000002647FF1F208>,
#         <__main__.signal object at 0x000002647FF22470>,
#         <__main__.signal object at 0x000002647FF256D8>,
#         <__main__.signal object at 0x000002647FF2A940>,
#         <__main__.signal object at 0x000002647FF2CBA8>,
#         <__main__.signal object at 0x000002647FF30E10>,
#         <__main__.signal object at 0x000002647FF360B8>,
#         <__main__.signal object at 0x000002647FF38320>,
#         <__main__.signal object at 0x000002647FF3D588>,
#         <__main__.signal object at 0x000002647FF407F0>,
#         <__main__.signal object at 0x000002647FF43A58>,
#         <__main__.signal object at 0x000002647FF47CC0>,
#         <__main__.signal object at 0x000002647FF4BF28>,
#         <__main__.signal object at 0x000002647FF501D0>,
#         <__main__.signal object at 0x000002647FF53438>,
#         <__main__.signal object at 0x000002647FF576A0>,
#         <__main__.signal object at 0x000002647FF59908>,
#         <__main__.signal object at 0x000002647FF5EB70>,
#         <__main__.signal object at 0x000002647FF61DD8>,
#         <__main__.signal object at 0x000002647FF67080>,
#         <__main__.signal object at 0x000002647FF692E8>,
#         <__main__.signal object at 0x000002647FF6D550>,
#         <__main__.signal object at 0x000002647FF727B8>,
#         <__main__.signal object at 0x000002647FF74A20>,
#         <__main__.signal object at 0x000002647FF78C88>,
#         <__main__.signal object at 0x000002647FF7BEF0>,
#         <__main__.signal object at 0x000002647FF80198>,
#         <__main__.signal object at 0x000002647FF84400>,
#         <__main__.signal object at 0x000002647FF88668>,
#         <__main__.signal object at 0x000002647FF8B8D0>], dtype=object),
#  'white-info-9': array([<__main__.signal object at 0x000002647FDFCC18>,
#         <__main__.signal object at 0x000002647FDECE48>,
#         <__main__.signal object at 0x000002647FDFA080>,
#         <__main__.signal object at 0x000002647FE062E8>,
#         <__main__.signal object at 0x000002647FE07550>,
#         <__main__.signal object at 0x000002647FE0C7B8>,
#         <__main__.signal object at 0x000002647FE19A20>,
#         <__main__.signal object at 0x000002647FE1BC88>,
#         <__main__.signal object at 0x000002647FE1FEF0>,
#         <__main__.signal object at 0x000002647FE24198>,
#         <__main__.signal object at 0x000002647FE28400>,
#         <__main__.signal object at 0x000002647FE2A668>,
# ...
#         <__main__.signal object at 0x000002647FEB2400>,
#         <__main__.signal object at 0x000002647FEB5668>,
#         <__main__.signal object at 0x000002647FEBA8D0>,
#         <__main__.signal object at 0x000002647FEBCB38>,
#         <__main__.signal object at 0x000002647FEC1DA0>,
#         <__main__.signal object at 0x000002647FEC7048>,
#         <__main__.signal object at 0x000002647FECA2B0>,
#         <__main__.signal object at 0x000002647FECE518>,
#         <__main__.signal object at 0x000002647FED1780>,
#         <__main__.signal object at 0x000002647FED49E8>,
#         <__main__.signal object at 0x000002647FED8C50>,
#         <__main__.signal object at 0x000002647FEDCEB8>,
#         <__main__.signal object at 0x000002647FEE1160>,
#         <__main__.signal object at 0x000002647FEE43C8>,
#         <__main__.signal object at 0x000002647FEE8630>,
#         <__main__.signal object at 0x000002647FEEB898>,
#         <__main__.signal object at 0x000002647FEEFB00>,
#         <__main__.signal object at 0x000002647FEF2D68>,
#         <__main__.signal object at 0x000002647FEF6FD0>,
#         <__main__.signal object at 0x000002647FEFB278>,
#         <__main__.signal object at 0x000002647FEFE4E0>,
#         <__main__.signal object at 0x000002647FF03748>,
#         <__main__.signal object at 0x000002647FF059B0>,
#         <__main__.signal object at 0x000002647FF09C18>,
#         <__main__.signal object at 0x000002647FF0DE80>,
#         <__main__.signal object at 0x000002647FF12128>,
#         <__main__.signal object at 0x000002647FF16390>,
#         <__main__.signal object at 0x000002647FF195F8>,
#         <__main__.signal object at 0x000002647FF1C860>,
#         <__main__.signal object at 0x000002647FF20AC8>,
#         <__main__.signal object at 0x000002647FF24D30>,
#         <__main__.signal object at 0x000002647FF26F98>,
#         <__main__.signal object at 0x000002647FF2C240>,
#         <__main__.signal object at 0x000002647FF304A8>,
#         <__main__.signal object at 0x000002647FF34710>,
#         <__main__.signal object at 0x000002647FF37978>,
#         <__main__.signal object at 0x000002647FF3ABE0>,
#         <__main__.signal object at 0x000002647FF3EE48>,
#         <__main__.signal object at 0x000002647FF430F0>,
#         <__main__.signal object at 0x000002647FF47358>,
#         <__main__.signal object at 0x000002647FF4B5C0>,
#         <__main__.signal object at 0x000002647FF4D828>,
#         <__main__.signal object at 0x000002647FF52A90>,
#         <__main__.signal object at 0x000002647FF54CF8>,
#         <__main__.signal object at 0x000002647FF58F60>,
#         <__main__.signal object at 0x000002647FF5E208>,
#         <__main__.signal object at 0x000002647FF61470>,
#         <__main__.signal object at 0x000002647FF656D8>,
#         <__main__.signal object at 0x000002647FF68940>,
#         <__main__.signal object at 0x000002647FF6CBA8>,
#         <__main__.signal object at 0x000002647FF6FE10>,
#         <__main__.signal object at 0x000002647FF740B8>,
#         <__main__.signal object at 0x000002647FF78320>,
#         <__main__.signal object at 0x000002647FF7B588>,
#         <__main__.signal object at 0x000002647FF7F7F0>,
#         <__main__.signal object at 0x000002647FF83A58>,
#         <__main__.signal object at 0x000002647FF86CC0>,
#         <__main__.signal object at 0x000002647FF89F28>,
#         <__main__.signal object at 0x000002647FF8F1D0>], dtype=object),
#  'start': array([<__main__.signal object at 0x000002647FDEC550>,
#         <__main__.signal object at 0x000002647FDF8780>,
#         <__main__.signal object at 0x000002647FE04978>,
#         <__main__.signal object at 0x000002647FE09BE0>,
#         <__main__.signal object at 0x000002647FE0AE48>,
#         <__main__.signal object at 0x000002647FE190F0>,
#         <__main__.signal object at 0x000002647FE1B358>,
#         <__main__.signal object at 0x000002647FE1F5C0>,
#         <__main__.signal object at 0x000002647FE23828>,
#         <__main__.signal object at 0x000002647FE26A90>,
#         <__main__.signal object at 0x000002647FE29CF8>,
#         <__main__.signal object at 0x000002647FE2EF60>,
#         <__main__.signal object at 0x000002647FE31208>,
#         <__main__.signal object at 0x000002647FE35470>,
#         <__main__.signal object at 0x000002647FE3A6D8>,
#         <__main__.signal object at 0x000002647FE3C940>,
#         <__main__.signal object at 0x000002647FE41BA8>,
#         <__main__.signal object at 0x000002647FE44E10>,
#         <__main__.signal object at 0x000002647FE490B8>,
#         <__main__.signal object at 0x000002647FE4C320>,
#         <__main__.signal object at 0x000002647FE50588>,
#         <__main__.signal object at 0x000002647FE537F0>,
#         <__main__.signal object at 0x000002647FE57A58>,
#         <__main__.signal object at 0x000002647FE5BCC0>,
#         <__main__.signal object at 0x000002647FE5EF28>,
#         <__main__.signal object at 0x000002647FE631D0>,
#         <__main__.signal object at 0x000002647FE66438>,
#         <__main__.signal object at 0x000002647FE6B6A0>,
#         <__main__.signal object at 0x000002647FE6E908>,
#         <__main__.signal object at 0x000002647FE71B70>,
#         <__main__.signal object at 0x000002647FE75DD8>,
#         <__main__.signal object at 0x000002647FE79080>,
#         <__main__.signal object at 0x000002647FE7E2E8>,
#         <__main__.signal object at 0x000002647FE81550>,
#         <__main__.signal object at 0x000002647FE847B8>,
#         <__main__.signal object at 0x000002647FE89A20>,
#         <__main__.signal object at 0x000002647FE8CC88>,
#         <__main__.signal object at 0x000002647FE8FEF0>,
#         <__main__.signal object at 0x000002647FE94198>,
#         <__main__.signal object at 0x000002647FE98400>,
#         <__main__.signal object at 0x000002647FE9B668>,
#         <__main__.signal object at 0x000002647FE9F8D0>,
#         <__main__.signal object at 0x000002647FEA2B38>,
#         <__main__.signal object at 0x000002647FEA6DA0>,
#         <__main__.signal object at 0x000002647FEAB048>,
#         <__main__.signal object at 0x000002647FEAF2B0>,
#         <__main__.signal object at 0x000002647FEB2518>,
#         <__main__.signal object at 0x000002647FEB5780>,
#         <__main__.signal object at 0x000002647FEBA9E8>,
#         <__main__.signal object at 0x000002647FEBCC50>,
#         <__main__.signal object at 0x000002647FEC1EB8>,
#         <__main__.signal object at 0x000002647FEC7160>,
#         <__main__.signal object at 0x000002647FECA3C8>,
#         <__main__.signal object at 0x000002647FECE630>,
#         <__main__.signal object at 0x000002647FED1898>,
#         <__main__.signal object at 0x000002647FED4B00>,
#         <__main__.signal object at 0x000002647FED8D68>,
#         <__main__.signal object at 0x000002647FEDCFD0>,
#         <__main__.signal object at 0x000002647FEE1278>,
#         <__main__.signal object at 0x000002647FEE44E0>,
#         <__main__.signal object at 0x000002647FEE8748>,
#         <__main__.signal object at 0x000002647FEEB9B0>,
#         <__main__.signal object at 0x000002647FEEFC18>,
#         <__main__.signal object at 0x000002647FEF2E80>,
#         <__main__.signal object at 0x000002647FEF8128>,
#         <__main__.signal object at 0x000002647FEFB390>,
#         <__main__.signal object at 0x000002647FEFE5F8>,
#         <__main__.signal object at 0x000002647FF03860>,
#         <__main__.signal object at 0x000002647FF05AC8>,
#         <__main__.signal object at 0x000002647FF09D30>,
#         <__main__.signal object at 0x000002647FF0DF98>,
#         <__main__.signal object at 0x000002647FF12240>,
#         <__main__.signal object at 0x000002647FF164A8>,
#         <__main__.signal object at 0x000002647FF19710>,
#         <__main__.signal object at 0x000002647FF1C978>,
#         <__main__.signal object at 0x000002647FF20BE0>,
#         <__main__.signal object at 0x000002647FF24E48>,
#         <__main__.signal object at 0x000002647FF2A0F0>,
#         <__main__.signal object at 0x000002647FF2C358>,
#         <__main__.signal object at 0x000002647FF305C0>,
#         <__main__.signal object at 0x000002647FF34828>,
#         <__main__.signal object at 0x000002647FF37A90>,
#         <__main__.signal object at 0x000002647FF3ACF8>,
#         <__main__.signal object at 0x000002647FF3EF60>,
#         <__main__.signal object at 0x000002647FF43208>,
#         <__main__.signal object at 0x000002647FF47470>,
#         <__main__.signal object at 0x000002647FF4B6D8>,
#         <__main__.signal object at 0x000002647FF4D940>,
#         <__main__.signal object at 0x000002647FF52BA8>,
#         <__main__.signal object at 0x000002647FF54E10>,
#         <__main__.signal object at 0x000002647FF590B8>,
#         <__main__.signal object at 0x000002647FF5E320>,
#         <__main__.signal object at 0x000002647FF61588>,
#         <__main__.signal object at 0x000002647FF657F0>,
#         <__main__.signal object at 0x000002647FF68A58>,
#         <__main__.signal object at 0x000002647FF6CCC0>,
#         <__main__.signal object at 0x000002647FF6FF28>,
#         <__main__.signal object at 0x000002647FF741D0>,
#         <__main__.signal object at 0x000002647FF78438>,
#         <__main__.signal object at 0x000002647FF7B6A0>,
#         <__main__.signal object at 0x000002647FF7F908>,
#         <__main__.signal object at 0x000002647FF83B70>,
#         <__main__.signal object at 0x000002647FF86DD8>,
#         <__main__.signal object at 0x000002647FF8B080>,
#         <__main__.signal object at 0x000002647FF8F2E8>], dtype=object),
#  'summary': array([<__main__.signal_summary object at 0x000002647FDFC438>,
#         <__main__.signal_summary object at 0x000002647FDFC400>,
#         <__main__.signal_summary object at 0x000002647FDFC2E8>,
#         <__main__.signal_summary object at 0x000002647FDF8908>,
#         <__main__.signal_summary object at 0x000002647FE04B70>,
#         <__main__.signal_summary object at 0x000002647FE09DD8>,
#         <__main__.signal_summary object at 0x000002647FE0C080>,
#         <__main__.signal_summary object at 0x000002647FE192E8>,
#         <__main__.signal_summary object at 0x000002647FE1B550>,
#         <__main__.signal_summary object at 0x000002647FE1F7B8>,
#         <__main__.signal_summary object at 0x000002647FE23A20>,
#         <__main__.signal_summary object at 0x000002647FE26C88>,
#         <__main__.signal_summary object at 0x000002647FE29EF0>,
#         <__main__.signal_summary object at 0x000002647FE2EF98>,
#         <__main__.signal_summary object at 0x000002647FE31400>,
#         <__main__.signal_summary object at 0x000002647FE35668>,
#         <__main__.signal_summary object at 0x000002647FE3A8D0>,
#         <__main__.signal_summary object at 0x000002647FE3CB38>,
#         <__main__.signal_summary object at 0x000002647FE41DA0>,
#         <__main__.signal_summary object at 0x000002647FE45048>,
#         <__main__.signal_summary object at 0x000002647FE492B0>,
#         <__main__.signal_summary object at 0x000002647FE4C518>,
#         <__main__.signal_summary object at 0x000002647FE50780>,
#         <__main__.signal_summary object at 0x000002647FE539E8>,
#         <__main__.signal_summary object at 0x000002647FE57C50>,
#         <__main__.signal_summary object at 0x000002647FE5BEB8>,
#         <__main__.signal_summary object at 0x000002647FE5EF60>,
#         <__main__.signal_summary object at 0x000002647FE633C8>,
#         <__main__.signal_summary object at 0x000002647FE66630>,
#         <__main__.signal_summary object at 0x000002647FE6B898>,
#         <__main__.signal_summary object at 0x000002647FE6EB00>,
#         <__main__.signal_summary object at 0x000002647FE71D68>,
#         <__main__.signal_summary object at 0x000002647FE75FD0>,
#         <__main__.signal_summary object at 0x000002647FE79278>,
#         <__main__.signal_summary object at 0x000002647FE7E4E0>,
#         <__main__.signal_summary object at 0x000002647FE81748>,
#         <__main__.signal_summary object at 0x000002647FE849B0>,
#         <__main__.signal_summary object at 0x000002647FE89C18>,
#         <__main__.signal_summary object at 0x000002647FE8CE80>,
#         <__main__.signal_summary object at 0x000002647FE8FF28>,
#         <__main__.signal_summary object at 0x000002647FE94390>,
#         <__main__.signal_summary object at 0x000002647FE985F8>,
#         <__main__.signal_summary object at 0x000002647FE9B860>,
#         <__main__.signal_summary object at 0x000002647FE9FAC8>,
#         <__main__.signal_summary object at 0x000002647FEA2D30>,
#         <__main__.signal_summary object at 0x000002647FEA6F98>,
#         <__main__.signal_summary object at 0x000002647FEAB240>,
#         <__main__.signal_summary object at 0x000002647FEAF4A8>,
#         <__main__.signal_summary object at 0x000002647FEB2710>,
#         <__main__.signal_summary object at 0x000002647FEB5978>,
#         <__main__.signal_summary object at 0x000002647FEBABE0>,
#         <__main__.signal_summary object at 0x000002647FEBCE48>,
#         <__main__.signal_summary object at 0x000002647FEC1EF0>,
#         <__main__.signal_summary object at 0x000002647FEC7358>,
#         <__main__.signal_summary object at 0x000002647FECA5C0>,
#         <__main__.signal_summary object at 0x000002647FECE828>,
#         <__main__.signal_summary object at 0x000002647FED1A90>,
#         <__main__.signal_summary object at 0x000002647FED4CF8>,
#         <__main__.signal_summary object at 0x000002647FED8F60>,
#         <__main__.signal_summary object at 0x000002647FEDD208>,
#         <__main__.signal_summary object at 0x000002647FEE1470>,
#         <__main__.signal_summary object at 0x000002647FEE46D8>,
#         <__main__.signal_summary object at 0x000002647FEE8940>,
#         <__main__.signal_summary object at 0x000002647FEEBBA8>,
#         <__main__.signal_summary object at 0x000002647FEEFE10>,
#         <__main__.signal_summary object at 0x000002647FEF2EB8>,
#         <__main__.signal_summary object at 0x000002647FEF8320>,
#         <__main__.signal_summary object at 0x000002647FEFB588>,
#         <__main__.signal_summary object at 0x000002647FEFE7F0>,
#         <__main__.signal_summary object at 0x000002647FF03A58>,
#         <__main__.signal_summary object at 0x000002647FF05CC0>,
#         <__main__.signal_summary object at 0x000002647FF09F28>,
#         <__main__.signal_summary object at 0x000002647FF0DFD0>,
#         <__main__.signal_summary object at 0x000002647FF12438>,
#         <__main__.signal_summary object at 0x000002647FF166A0>,
#         <__main__.signal_summary object at 0x000002647FF19908>,
#         <__main__.signal_summary object at 0x000002647FF1CB70>,
#         <__main__.signal_summary object at 0x000002647FF20DD8>,
#         <__main__.signal_summary object at 0x000002647FF25080>,
#         <__main__.signal_summary object at 0x000002647FF2A2E8>,
#         <__main__.signal_summary object at 0x000002647FF2C550>,
#         <__main__.signal_summary object at 0x000002647FF307B8>,
#         <__main__.signal_summary object at 0x000002647FF34A20>,
#         <__main__.signal_summary object at 0x000002647FF37C88>,
#         <__main__.signal_summary object at 0x000002647FF3AEF0>,
#         <__main__.signal_summary object at 0x000002647FF3EF98>,
#         <__main__.signal_summary object at 0x000002647FF43400>,
#         <__main__.signal_summary object at 0x000002647FF47668>,
#         <__main__.signal_summary object at 0x000002647FF4B8D0>,
#         <__main__.signal_summary object at 0x000002647FF4DB38>,
#         <__main__.signal_summary object at 0x000002647FF52DA0>,
#         <__main__.signal_summary object at 0x000002647FF57048>,
#         <__main__.signal_summary object at 0x000002647FF592B0>,
#         <__main__.signal_summary object at 0x000002647FF5E518>,
#         <__main__.signal_summary object at 0x000002647FF61780>,
#         <__main__.signal_summary object at 0x000002647FF659E8>,
#         <__main__.signal_summary object at 0x000002647FF68C50>,
#         <__main__.signal_summary object at 0x000002647FF6CEB8>,
#         <__main__.signal_summary object at 0x000002647FF6FF60>,
#         <__main__.signal_summary object at 0x000002647FF743C8>,
#         <__main__.signal_summary object at 0x000002647FF78630>,
#         <__main__.signal_summary object at 0x000002647FF7B898>,
#         <__main__.signal_summary object at 0x000002647FF7FB00>,
#         <__main__.signal_summary object at 0x000002647FF83D68>,
#         <__main__.signal_summary object at 0x000002647FF86FD0>],
#        dtype=object)}

# %%
len(signal_stat["white-info-2"])
# Out:
# 105

# %%
graph_dir = "graphs/"
if not os.path.exists(graph_dir):
    os.makedirs(graph_dir)

for key in signal_stat.keys():
    if key is not "summary":
        ap = [float(signal.ap) for signal in signal_stat[key]]
        tp = [int(signal.TP) for signal in signal_stat[key]]
        fp = [int(signal.FP) for signal in signal_stat[key]]

        plt.figure(figsize=(15,5))
        plt.subplot(121, title="class: "+key, ylabel="percentage")
        plt.plot(ap, label="average precision in %")
        plt.legend()
        plt.grid(True)

        plt.subplot(122, title="class: "+key, ylabel="amount")
        plt.plot(tp, "g", label="true positive")
        plt.plot(fp, "r", label="false positive")
        plt.legend()
        plt.grid(True)
        plt.savefig("graphs/"+key+".png")
        plt.show()

# %%
key = "summary"
tp = [float(signal.TP) for signal in signal_stat[key]]
fp = [int(signal.FP) for signal in signal_stat[key]]
fn = [int(signal.FN) for signal in signal_stat[key]]
average_iou = [float(signal.average_iou) for signal in signal_stat[key]]
mean_ap = [float(signal.mean_ap) for signal in signal_stat[key]]

plt.figure(figsize=(15,5))
plt.xlim(0,110)
plt.subplot(121, title="class: "+key, ylabel="percentage")
plt.plot(mean_ap, label="mean average precision in %")
plt.plot(average_iou, label="average IoU in %")
plt.legend()

plt.grid(True)

plt.subplot(122, title="class: "+key, ylabel="amount")
plt.plot(tp, "g", label="true positive")
plt.plot(fp, "r", label="false positive")
plt.plot(fn, "m", label="false negative")
plt.legend()
plt.grid(True)
plt.savefig("graphs/"+key+".png")
plt.show()

# %%
plt.figure(figsize=(30,15))
plt.grid(True)
for key in signal_stat.keys():
    if key is not "summary":
        ap = [float(signal.ap) for signal in signal_stat[key]]
        plt.plot(ap, label="average precision in %")
        
plt.show()
