# %%
import glob
import re
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
files = glob.glob("map_after_iteration\*")
len(files)
# Out:
# 132

# %%
class signal:
    def __init__(self, name, ap, TP, FP):
        self.name = name
        self.ap = ap
        self.TP = TP
        self.FP = FP
    
    def printstats(self):
        print("Signal [ name:{}, ap:{}%, tp:{}, fp:{} ]".format(self.name, self.ap, self.TP, self.FP))
    
class signal_summary:
    def __init__(self, TP, FP, FN, average_iou, mean_ap):
        self.TP = TP
        self.FP = FP
        self.FN = FN
        self.average_iou = average_iou
        self.mean_ap = mean_ap   
        
    def printstats(self):
        print("Summary [ TP:{}, FP:{}, FN:{}, averageIoU:{}%, meanAP:{}% ]".format(self.TP, self.FP, self.FN, self.average_iou, self.mean_ap))

# %%
def addSignalToDictionary(dictionary, key, value):
    if key in dictionary:
        dictionary[str(key)] = np.append(dictionary[str(key)], value)
    else:
        dictionary[str(key)] = np.array([value])

# %%
signal_stat = {}

for file in files:
    with open(file, "r") as openfile:
        summary = signal_summary(0,0,0,0,0)
        for line in openfile:
            
            # get single signal data
            if line.startswith("class_id"):
                result_name = re.search("name = .*, ap", line)
                result_ap = re.search("ap = .*%", line)
                result_tp = re.search("TP = .*,", line)
                result_fp = re.search("FP = .*\)", line)

                if result_name is not None and result_ap is not None and result_tp is not None and result_fp is not None:
                    name = result_name.group().replace(", ap","").replace("name = ","")
                    ap = result_ap.group().replace("ap = ","").replace("%","")
                    tp = result_tp.group().replace("TP = ","").replace(",","")
                    fp = result_fp.group().replace("FP = ","").replace(")","")
                    new_signal = signal(name, ap, tp, fp)
                    #new.printstats()
                    addSignalToDictionary(signal_stat, name, new_signal)
                continue
                    
            # get summary
            if line.startswith(" for thresh"):
                result_tp = re.search("TP = .*, FP", line)
                result_fp = re.search("FP = .*, FN", line)
                result_fn = re.search("FN = .*,", line)
                result_iou = re.search("average IoU = .* %", line)
                
                if result_tp is not None and result_fp is not None and result_fn is not None and result_iou is not None:                    
                    summary.TP = result_tp.group().replace("TP = ","").replace(", FP","")
                    summary.FP = result_fp.group().replace("FP = ","").replace(", FN","")
                    summary.FN = result_fn.group().replace("FN = ","").replace(",","")
                    summary.average_iou = result_iou.group().replace("average IoU = ","").replace(" %","")
                continue
                
            # get mean average precision
            if line.startswith(" mean average"):
                result_map = re.search(", or .* %", line)
                if result_map is not None:
                    summary.mean_ap = result_map.group().replace(", or ", "").replace(" %", "")
                    #summary.printstats()
                    addSignalToDictionary(signal_stat, "summary", summary)
                continue


signal_stat
# Out:
# {'white-info-1': array([<__main__.signal object at 0x000002E606AA94A8>,
#         <__main__.signal object at 0x000002E606AAB630>,
#         <__main__.signal object at 0x000002E606AB4898>,
#         <__main__.signal object at 0x000002E606AC3B00>,
#         <__main__.signal object at 0x000002E606AC7D68>,
#         <__main__.signal object at 0x000002E606ACAFD0>,
#         <__main__.signal object at 0x000002E606AD6278>,
#         <__main__.signal object at 0x000002E606ADA4E0>,
#         <__main__.signal object at 0x000002E606ADE748>,
#         <__main__.signal object at 0x000002E606AE19B0>,
#         <__main__.signal object at 0x000002E606AE5C18>,
#         <__main__.signal object at 0x000002E606AE8E80>,
#         <__main__.signal object at 0x000002E606AEE128>,
#         <__main__.signal object at 0x000002E606AF2390>,
#         <__main__.signal object at 0x000002E606AF45F8>,
#         <__main__.signal object at 0x000002E606AF9860>,
#         <__main__.signal object at 0x000002E606AFBAC8>,
#         <__main__.signal object at 0x000002E606AFFD30>,
#         <__main__.signal object at 0x000002E606B03F98>,
#         <__main__.signal object at 0x000002E606B08240>,
#         <__main__.signal object at 0x000002E606B0C4A8>,
#         <__main__.signal object at 0x000002E606B0F710>,
#         <__main__.signal object at 0x000002E606B13978>,
#         <__main__.signal object at 0x000002E606B16BE0>,
#         <__main__.signal object at 0x000002E606B1AE48>,
#         <__main__.signal object at 0x000002E606B1F0F0>,
#         <__main__.signal object at 0x000002E606B22358>,
#         <__main__.signal object at 0x000002E606B265C0>,
#         <__main__.signal object at 0x000002E606B2A828>,
#         <__main__.signal object at 0x000002E606B2DA90>,
#         <__main__.signal object at 0x000002E606B30CF8>,
#         <__main__.signal object at 0x000002E606B35F60>,
#         <__main__.signal object at 0x000002E606B39208>,
#         <__main__.signal object at 0x000002E606B3C470>,
#         <__main__.signal object at 0x000002E606B416D8>,
#         <__main__.signal object at 0x000002E606B43940>,
#         <__main__.signal object at 0x000002E606B48BA8>,
#         <__main__.signal object at 0x000002E606B4CE10>,
#         <__main__.signal object at 0x000002E606B500B8>,
#         <__main__.signal object at 0x000002E606B54320>,
#         <__main__.signal object at 0x000002E606B57588>,
#         <__main__.signal object at 0x000002E606B5A7F0>,
#         <__main__.signal object at 0x000002E606B5FA58>,
#         <__main__.signal object at 0x000002E606B62CC0>,
#         <__main__.signal object at 0x000002E606B65F28>,
#         <__main__.signal object at 0x000002E606B6A1D0>,
#         <__main__.signal object at 0x000002E606B6E438>,
#         <__main__.signal object at 0x000002E606B736A0>,
#         <__main__.signal object at 0x000002E606B75908>,
#         <__main__.signal object at 0x000002E606B79B70>,
#         <__main__.signal object at 0x000002E606B7CDD8>,
#         <__main__.signal object at 0x000002E606B81080>,
#         <__main__.signal object at 0x000002E606B862E8>,
#         <__main__.signal object at 0x000002E606B89550>,
#         <__main__.signal object at 0x000002E606B8C7B8>,
#         <__main__.signal object at 0x000002E606B90A20>,
#         <__main__.signal object at 0x000002E606B94C88>,
#         <__main__.signal object at 0x000002E606B96EF0>,
#         <__main__.signal object at 0x000002E606B9C198>,
#         <__main__.signal object at 0x000002E606BA0400>,
#         <__main__.signal object at 0x000002E606BA3668>,
#         <__main__.signal object at 0x000002E606BA78D0>,
#         <__main__.signal object at 0x000002E606BAAB38>,
#         <__main__.signal object at 0x000002E606BAEDA0>,
#         <__main__.signal object at 0x000002E606BB3048>,
#         <__main__.signal object at 0x000002E606BB72B0>,
#         <__main__.signal object at 0x000002E606BBA518>,
#         <__main__.signal object at 0x000002E606BBD780>,
#         <__main__.signal object at 0x000002E606BC29E8>,
#         <__main__.signal object at 0x000002E606BC4C50>,
#         <__main__.signal object at 0x000002E606BC8EB8>,
#         <__main__.signal object at 0x000002E606BCE160>,
#         <__main__.signal object at 0x000002E606BD13C8>,
#         <__main__.signal object at 0x000002E606BD4630>,
#         <__main__.signal object at 0x000002E606BD8898>,
#         <__main__.signal object at 0x000002E606BDBB00>,
#         <__main__.signal object at 0x000002E606BDFD68>,
#         <__main__.signal object at 0x000002E606BE3FD0>,
#         <__main__.signal object at 0x000002E606BE8278>,
#         <__main__.signal object at 0x000002E606BEB4E0>,
#         <__main__.signal object at 0x000002E606BEF748>,
#         <__main__.signal object at 0x000002E606BF29B0>,
#         <__main__.signal object at 0x000002E606BF6C18>,
#         <__main__.signal object at 0x000002E606BFAE80>,
#         <__main__.signal object at 0x000002E606BFF128>,
#         <__main__.signal object at 0x000002E606C02390>,
#         <__main__.signal object at 0x000002E606C055F8>,
#         <__main__.signal object at 0x000002E606C0A860>,
#         <__main__.signal object at 0x000002E606C0DAC8>,
#         <__main__.signal object at 0x000002E606C10D30>,
#         <__main__.signal object at 0x000002E606C15F98>,
#         <__main__.signal object at 0x000002E606C19240>,
#         <__main__.signal object at 0x000002E606C1D4A8>,
#         <__main__.signal object at 0x000002E606C21710>,
#         <__main__.signal object at 0x000002E606C23978>,
#         <__main__.signal object at 0x000002E606C28BE0>,
#         <__main__.signal object at 0x000002E606C2BE48>,
#         <__main__.signal object at 0x000002E606C310F0>,
#         <__main__.signal object at 0x000002E606C34358>,
#         <__main__.signal object at 0x000002E606C375C0>,
#         <__main__.signal object at 0x000002E606C3B828>,
#         <__main__.signal object at 0x000002E606C3EA90>,
#         <__main__.signal object at 0x000002E606C42CF8>,
#         <__main__.signal object at 0x000002E606C45F60>,
#         <__main__.signal object at 0x000002E606C4A208>,
#         <__main__.signal object at 0x000002E606C4F470>,
#         <__main__.signal object at 0x000002E606C526D8>,
#         <__main__.signal object at 0x000002E606C55940>,
#         <__main__.signal object at 0x000002E606C59BA8>,
#         <__main__.signal object at 0x000002E606C5CE10>,
#         <__main__.signal object at 0x000002E606C610B8>,
#         <__main__.signal object at 0x000002E606C65320>,
#         <__main__.signal object at 0x000002E606C69588>,
#         <__main__.signal object at 0x000002E606C6C7F0>,
#         <__main__.signal object at 0x000002E606C70A58>,
#         <__main__.signal object at 0x000002E606C73CC0>,
#         <__main__.signal object at 0x000002E606C77F28>,
#         <__main__.signal object at 0x000002E606C7C1D0>,
#         <__main__.signal object at 0x000002E606C7F438>,
#         <__main__.signal object at 0x000002E606C836A0>,
#         <__main__.signal object at 0x000002E606C86908>,
#         <__main__.signal object at 0x000002E606C8AB70>,
#         <__main__.signal object at 0x000002E606C8DDD8>,
#         <__main__.signal object at 0x000002E606C92080>,
#         <__main__.signal object at 0x000002E606C972E8>,
#         <__main__.signal object at 0x000002E606C9A550>,
#         <__main__.signal object at 0x000002E606C9D7B8>,
#         <__main__.signal object at 0x000002E606CA1A20>,
#         <__main__.signal object at 0x000002E606CA4C88>,
#         <__main__.signal object at 0x000002E606CA8EF0>,
#         <__main__.signal object at 0x000002E606CAD198>], dtype=object),
#  'white-info-2': array([<__main__.signal object at 0x000002E606AA9588>,
#         <__main__.signal object at 0x000002E606AAB748>,
#         <__main__.signal object at 0x000002E606AB4978>,
#         <__main__.signal object at 0x000002E606AC3BE0>,
#         <__main__.signal object at 0x000002E606AC7E48>,
#         <__main__.signal object at 0x000002E606ACB0F0>,
#         <__main__.signal object at 0x000002E606AD6358>,
#         <__main__.signal object at 0x000002E606ADA5C0>,
#         <__main__.signal object at 0x000002E606ADE828>,
#         <__main__.signal object at 0x000002E606AE1A90>,
#         <__main__.signal object at 0x000002E606AE5CF8>,
#         <__main__.signal object at 0x000002E606AE8F60>,
#         <__main__.signal object at 0x000002E606AEE208>,
#         <__main__.signal object at 0x000002E606AF2470>,
#         <__main__.signal object at 0x000002E606AF46D8>,
#         <__main__.signal object at 0x000002E606AF9940>,
#         <__main__.signal object at 0x000002E606AFBBA8>,
#         <__main__.signal object at 0x000002E606AFFE10>,
#         <__main__.signal object at 0x000002E606B050B8>,
#         <__main__.signal object at 0x000002E606B08320>,
#         <__main__.signal object at 0x000002E606B0C588>,
#         <__main__.signal object at 0x000002E606B0F7F0>,
#         <__main__.signal object at 0x000002E606B13A58>,
#         <__main__.signal object at 0x000002E606B16CC0>,
#         <__main__.signal object at 0x000002E606B1AF28>,
#         <__main__.signal object at 0x000002E606B1F1D0>,
#         <__main__.signal object at 0x000002E606B22438>,
#         <__main__.signal object at 0x000002E606B266A0>,
#         <__main__.signal object at 0x000002E606B2A908>,
#         <__main__.signal object at 0x000002E606B2DB70>,
#         <__main__.signal object at 0x000002E606B30DD8>,
#         <__main__.signal object at 0x000002E606B36080>,
#         <__main__.signal object at 0x000002E606B392E8>,
#         <__main__.signal object at 0x000002E606B3C550>,
#         <__main__.signal object at 0x000002E606B417B8>,
#         <__main__.signal object at 0x000002E606B43A20>,
#         <__main__.signal object at 0x000002E606B48C88>,
#         <__main__.signal object at 0x000002E606B4CEF0>,
#         <__main__.signal object at 0x000002E606B50198>,
#         <__main__.signal object at 0x000002E606B54400>,
#         <__main__.signal object at 0x000002E606B57668>,
#         <__main__.signal object at 0x000002E606B5A8D0>,
#         <__main__.signal object at 0x000002E606B5FB38>,
#         <__main__.signal object at 0x000002E606B62DA0>,
#         <__main__.signal object at 0x000002E606B68048>,
#         <__main__.signal object at 0x000002E606B6A2B0>,
#         <__main__.signal object at 0x000002E606B6E518>,
#         <__main__.signal object at 0x000002E606B73780>,
#         <__main__.signal object at 0x000002E606B759E8>,
#         <__main__.signal object at 0x000002E606B79C50>,
#         <__main__.signal object at 0x000002E606B7CEB8>,
#         <__main__.signal object at 0x000002E606B81160>,
#         <__main__.signal object at 0x000002E606B863C8>,
#         <__main__.signal object at 0x000002E606B89630>,
#         <__main__.signal object at 0x000002E606B8C898>,
#         <__main__.signal object at 0x000002E606B90B00>,
#         <__main__.signal object at 0x000002E606B94D68>,
#         <__main__.signal object at 0x000002E606B96FD0>,
#         <__main__.signal object at 0x000002E606B9C278>,
#         <__main__.signal object at 0x000002E606BA04E0>,
#         <__main__.signal object at 0x000002E606BA3748>,
#         <__main__.signal object at 0x000002E606BA79B0>,
#         <__main__.signal object at 0x000002E606BAAC18>,
#         <__main__.signal object at 0x000002E606BAEE80>,
#         <__main__.signal object at 0x000002E606BB3128>,
#         <__main__.signal object at 0x000002E606BB7390>,
#         <__main__.signal object at 0x000002E606BBA5F8>,
#         <__main__.signal object at 0x000002E606BBD860>,
#         <__main__.signal object at 0x000002E606BC2AC8>,
#         <__main__.signal object at 0x000002E606BC4D30>,
#         <__main__.signal object at 0x000002E606BC8F98>,
#         <__main__.signal object at 0x000002E606BCE240>,
#         <__main__.signal object at 0x000002E606BD14A8>,
#         <__main__.signal object at 0x000002E606BD4710>,
#         <__main__.signal object at 0x000002E606BD8978>,
#         <__main__.signal object at 0x000002E606BDBBE0>,
#         <__main__.signal object at 0x000002E606BDFE48>,
#         <__main__.signal object at 0x000002E606BE40F0>,
#         <__main__.signal object at 0x000002E606BE8358>,
#         <__main__.signal object at 0x000002E606BEB5C0>,
#         <__main__.signal object at 0x000002E606BEF828>,
#         <__main__.signal object at 0x000002E606BF2A90>,
#         <__main__.signal object at 0x000002E606BF6CF8>,
#         <__main__.signal object at 0x000002E606BFAF60>,
#         <__main__.signal object at 0x000002E606BFF208>,
#         <__main__.signal object at 0x000002E606C02470>,
#         <__main__.signal object at 0x000002E606C056D8>,
#         <__main__.signal object at 0x000002E606C0A940>,
#         <__main__.signal object at 0x000002E606C0DBA8>,
#         <__main__.signal object at 0x000002E606C10E10>,
#         <__main__.signal object at 0x000002E606C160B8>,
#         <__main__.signal object at 0x000002E606C19320>,
#         <__main__.signal object at 0x000002E606C1D588>,
#         <__main__.signal object at 0x000002E606C217F0>,
#         <__main__.signal object at 0x000002E606C23A58>,
#         <__main__.signal object at 0x000002E606C28CC0>,
#         <__main__.signal object at 0x000002E606C2BF28>,
#         <__main__.signal object at 0x000002E606C311D0>,
#         <__main__.signal object at 0x000002E606C34438>,
#         <__main__.signal object at 0x000002E606C376A0>,
#         <__main__.signal object at 0x000002E606C3B908>,
#         <__main__.signal object at 0x000002E606C3EB70>,
#         <__main__.signal object at 0x000002E606C42DD8>,
#         <__main__.signal object at 0x000002E606C48080>,
#         <__main__.signal object at 0x000002E606C4A2E8>,
#         <__main__.signal object at 0x000002E606C4F550>,
#         <__main__.signal object at 0x000002E606C527B8>,
#         <__main__.signal object at 0x000002E606C55A20>,
#         <__main__.signal object at 0x000002E606C59C88>,
#         <__main__.signal object at 0x000002E606C5CEF0>,
#         <__main__.signal object at 0x000002E606C61198>,
#         <__main__.signal object at 0x000002E606C65400>,
#         <__main__.signal object at 0x000002E606C69668>,
#         <__main__.signal object at 0x000002E606C6C8D0>,
#         <__main__.signal object at 0x000002E606C70B38>,
#         <__main__.signal object at 0x000002E606C73DA0>,
#         <__main__.signal object at 0x000002E606C79048>,
#         <__main__.signal object at 0x000002E606C7C2B0>,
#         <__main__.signal object at 0x000002E606C7F518>,
#         <__main__.signal object at 0x000002E606C83780>,
#         <__main__.signal object at 0x000002E606C869E8>,
#         <__main__.signal object at 0x000002E606C8AC50>,
#         <__main__.signal object at 0x000002E606C8DEB8>,
#         <__main__.signal object at 0x000002E606C92160>,
#         <__main__.signal object at 0x000002E606C973C8>,
#         <__main__.signal object at 0x000002E606C9A630>,
#         <__main__.signal object at 0x000002E606C9D898>,
#         <__main__.signal object at 0x000002E606CA1B00>,
#         <__main__.signal object at 0x000002E606CA4D68>,
#         <__main__.signal object at 0x000002E606CA8FD0>,
#         <__main__.signal object at 0x000002E606CAD278>], dtype=object),
#  'white-info-3': array([<__main__.signal object at 0x000002E606AA9668>,
#         <__main__.signal object at 0x000002E606AAB828>,
#         <__main__.signal object at 0x000002E606AB4A58>,
#         <__main__.signal object at 0x000002E606AC3CC0>,
#         <__main__.signal object at 0x000002E606AC7F28>,
#         <__main__.signal object at 0x000002E606ACB1D0>,
#         <__main__.signal object at 0x000002E606AD6438>,
#         <__main__.signal object at 0x000002E606ADA6A0>,
#         <__main__.signal object at 0x000002E606ADE908>,
#         <__main__.signal object at 0x000002E606AE1B70>,
#         <__main__.signal object at 0x000002E606AE5DD8>,
#         <__main__.signal object at 0x000002E606AE9080>,
#         <__main__.signal object at 0x000002E606AEE2E8>,
#         <__main__.signal object at 0x000002E606AF2550>,
#         <__main__.signal object at 0x000002E606AF47B8>,
#         <__main__.signal object at 0x000002E606AF9A20>,
#         <__main__.signal object at 0x000002E606AFBC88>,
#         <__main__.signal object at 0x000002E606AFFEF0>,
#         <__main__.signal object at 0x000002E606B05198>,
#         <__main__.signal object at 0x000002E606B08400>,
#         <__main__.signal object at 0x000002E606B0C668>,
#         <__main__.signal object at 0x000002E606B0F8D0>,
#         <__main__.signal object at 0x000002E606B13B38>,
#         <__main__.signal object at 0x000002E606B16DA0>,
#         <__main__.signal object at 0x000002E606B1B048>,
#         <__main__.signal object at 0x000002E606B1F2B0>,
#         <__main__.signal object at 0x000002E606B22518>,
#         <__main__.signal object at 0x000002E606B26780>,
#         <__main__.signal object at 0x000002E606B2A9E8>,
#         <__main__.signal object at 0x000002E606B2DC50>,
#         <__main__.signal object at 0x000002E606B30EB8>,
#         <__main__.signal object at 0x000002E606B36160>,
#         <__main__.signal object at 0x000002E606B393C8>,
#         <__main__.signal object at 0x000002E606B3C630>,
#         <__main__.signal object at 0x000002E606B41898>,
#         <__main__.signal object at 0x000002E606B43B00>,
#         <__main__.signal object at 0x000002E606B48D68>,
#         <__main__.signal object at 0x000002E606B4CFD0>,
#         <__main__.signal object at 0x000002E606B50278>,
#         <__main__.signal object at 0x000002E606B544E0>,
#         <__main__.signal object at 0x000002E606B57748>,
#         <__main__.signal object at 0x000002E606B5A9B0>,
#         <__main__.signal object at 0x000002E606B5FC18>,
#         <__main__.signal object at 0x000002E606B62E80>,
#         <__main__.signal object at 0x000002E606B68128>,
#         <__main__.signal object at 0x000002E606B6A390>,
#         <__main__.signal object at 0x000002E606B6E5F8>,
#         <__main__.signal object at 0x000002E606B73860>,
#         <__main__.signal object at 0x000002E606B75AC8>,
#         <__main__.signal object at 0x000002E606B79D30>,
#         <__main__.signal object at 0x000002E606B7CF98>,
#         <__main__.signal object at 0x000002E606B81240>,
#         <__main__.signal object at 0x000002E606B864A8>,
#         <__main__.signal object at 0x000002E606B89710>,
#         <__main__.signal object at 0x000002E606B8C978>,
#         <__main__.signal object at 0x000002E606B90BE0>,
#         <__main__.signal object at 0x000002E606B94E48>,
#         <__main__.signal object at 0x000002E606B980F0>,
#         <__main__.signal object at 0x000002E606B9C358>,
#         <__main__.signal object at 0x000002E606BA05C0>,
#         <__main__.signal object at 0x000002E606BA3828>,
#         <__main__.signal object at 0x000002E606BA7A90>,
#         <__main__.signal object at 0x000002E606BAACF8>,
#         <__main__.signal object at 0x000002E606BAEF60>,
#         <__main__.signal object at 0x000002E606BB3208>,
#         <__main__.signal object at 0x000002E606BB7470>,
#         <__main__.signal object at 0x000002E606BBA6D8>,
#         <__main__.signal object at 0x000002E606BBD940>,
#         <__main__.signal object at 0x000002E606BC2BA8>,
#         <__main__.signal object at 0x000002E606BC4E10>,
#         <__main__.signal object at 0x000002E606BC90B8>,
#         <__main__.signal object at 0x000002E606BCE320>,
#         <__main__.signal object at 0x000002E606BD1588>,
#         <__main__.signal object at 0x000002E606BD47F0>,
#         <__main__.signal object at 0x000002E606BD8A58>,
#         <__main__.signal object at 0x000002E606BDBCC0>,
#         <__main__.signal object at 0x000002E606BDFF28>,
#         <__main__.signal object at 0x000002E606BE41D0>,
#         <__main__.signal object at 0x000002E606BE8438>,
#         <__main__.signal object at 0x000002E606BEB6A0>,
#         <__main__.signal object at 0x000002E606BEF908>,
#         <__main__.signal object at 0x000002E606BF2B70>,
#         <__main__.signal object at 0x000002E606BF6DD8>,
#         <__main__.signal object at 0x000002E606BFB080>,
#         <__main__.signal object at 0x000002E606BFF2E8>,
#         <__main__.signal object at 0x000002E606C02550>,
#         <__main__.signal object at 0x000002E606C057B8>,
#         <__main__.signal object at 0x000002E606C0AA20>,
#         <__main__.signal object at 0x000002E606C0DC88>,
#         <__main__.signal object at 0x000002E606C10EF0>,
#         <__main__.signal object at 0x000002E606C16198>,
#         <__main__.signal object at 0x000002E606C19400>,
#         <__main__.signal object at 0x000002E606C1D668>,
#         <__main__.signal object at 0x000002E606C218D0>,
#         <__main__.signal object at 0x000002E606C23B38>,
#         <__main__.signal object at 0x000002E606C28DA0>,
#         <__main__.signal object at 0x000002E606C2C048>,
#         <__main__.signal object at 0x000002E606C312B0>,
#         <__main__.signal object at 0x000002E606C34518>,
#         <__main__.signal object at 0x000002E606C37780>,
#         <__main__.signal object at 0x000002E606C3B9E8>,
#         <__main__.signal object at 0x000002E606C3EC50>,
#         <__main__.signal object at 0x000002E606C42EB8>,
#         <__main__.signal object at 0x000002E606C48160>,
#         <__main__.signal object at 0x000002E606C4A3C8>,
#         <__main__.signal object at 0x000002E606C4F630>,
#         <__main__.signal object at 0x000002E606C52898>,
#         <__main__.signal object at 0x000002E606C55B00>,
#         <__main__.signal object at 0x000002E606C59D68>,
#         <__main__.signal object at 0x000002E606C5CFD0>,
#         <__main__.signal object at 0x000002E606C61278>,
#         <__main__.signal object at 0x000002E606C654E0>,
#         <__main__.signal object at 0x000002E606C69748>,
#         <__main__.signal object at 0x000002E606C6C9B0>,
#         <__main__.signal object at 0x000002E606C70C18>,
#         <__main__.signal object at 0x000002E606C73E80>,
#         <__main__.signal object at 0x000002E606C79128>,
#         <__main__.signal object at 0x000002E606C7C390>,
#         <__main__.signal object at 0x000002E606C7F5F8>,
#         <__main__.signal object at 0x000002E606C83860>,
#         <__main__.signal object at 0x000002E606C86AC8>,
#         <__main__.signal object at 0x000002E606C8AD30>,
#         <__main__.signal object at 0x000002E606C8DF98>,
#         <__main__.signal object at 0x000002E606C92240>,
#         <__main__.signal object at 0x000002E606C974A8>,
#         <__main__.signal object at 0x000002E606C9A710>,
#         <__main__.signal object at 0x000002E606C9D978>,
#         <__main__.signal object at 0x000002E606CA1BE0>,
#         <__main__.signal object at 0x000002E606CA4E48>,
#         <__main__.signal object at 0x000002E606CAA0F0>,
#         <__main__.signal object at 0x000002E606CAD358>], dtype=object),
#  'white-info-4': array([<__main__.signal object at 0x000002E606AA9748>,
#         <__main__.signal object at 0x000002E606AAB908>,
#         <__main__.signal object at 0x000002E606AB4B38>,
#         <__main__.signal object at 0x000002E606AC3DA0>,
#         <__main__.signal object at 0x000002E606AC9048>,
#         <__main__.signal object at 0x000002E606ACB2B0>,
#         <__main__.signal object at 0x000002E606AD6518>,
#         <__main__.signal object at 0x000002E606ADA780>,
#         <__main__.signal object at 0x000002E606ADE9E8>,
#         <__main__.signal object at 0x000002E606AE1C50>,
#         <__main__.signal object at 0x000002E606AE5EB8>,
#         <__main__.signal object at 0x000002E606AE9160>,
#         <__main__.signal object at 0x000002E606AEE3C8>,
#         <__main__.signal object at 0x000002E606AF2630>,
#         <__main__.signal object at 0x000002E606AF4898>,
#         <__main__.signal object at 0x000002E606AF9B00>,
#         <__main__.signal object at 0x000002E606AFBD68>,
#         <__main__.signal object at 0x000002E606AFFFD0>,
#         <__main__.signal object at 0x000002E606B05278>,
#         <__main__.signal object at 0x000002E606B084E0>,
#         <__main__.signal object at 0x000002E606B0C748>,
#         <__main__.signal object at 0x000002E606B0F9B0>,
#         <__main__.signal object at 0x000002E606B13C18>,
#         <__main__.signal object at 0x000002E606B16E80>,
#         <__main__.signal object at 0x000002E606B1B128>,
#         <__main__.signal object at 0x000002E606B1F390>,
#         <__main__.signal object at 0x000002E606B225F8>,
#         <__main__.signal object at 0x000002E606B26860>,
#         <__main__.signal object at 0x000002E606B2AAC8>,
#         <__main__.signal object at 0x000002E606B2DD30>,
#         <__main__.signal object at 0x000002E606B30F98>,
#         <__main__.signal object at 0x000002E606B36240>,
#         <__main__.signal object at 0x000002E606B394A8>,
#         <__main__.signal object at 0x000002E606B3C710>,
#         <__main__.signal object at 0x000002E606B41978>,
#         <__main__.signal object at 0x000002E606B43BE0>,
#         <__main__.signal object at 0x000002E606B48E48>,
#         <__main__.signal object at 0x000002E606B4D0F0>,
#         <__main__.signal object at 0x000002E606B50358>,
#         <__main__.signal object at 0x000002E606B545C0>,
#         <__main__.signal object at 0x000002E606B57828>,
#         <__main__.signal object at 0x000002E606B5AA90>,
#         <__main__.signal object at 0x000002E606B5FCF8>,
#         <__main__.signal object at 0x000002E606B62F60>,
#         <__main__.signal object at 0x000002E606B68208>,
#         <__main__.signal object at 0x000002E606B6A470>,
#         <__main__.signal object at 0x000002E606B6E6D8>,
#         <__main__.signal object at 0x000002E606B73940>,
#         <__main__.signal object at 0x000002E606B75BA8>,
#         <__main__.signal object at 0x000002E606B79E10>,
#         <__main__.signal object at 0x000002E606B7E0B8>,
#         <__main__.signal object at 0x000002E606B81320>,
#         <__main__.signal object at 0x000002E606B86588>,
#         <__main__.signal object at 0x000002E606B897F0>,
#         <__main__.signal object at 0x000002E606B8CA58>,
#         <__main__.signal object at 0x000002E606B90CC0>,
#         <__main__.signal object at 0x000002E606B94F28>,
#         <__main__.signal object at 0x000002E606B981D0>,
#         <__main__.signal object at 0x000002E606B9C438>,
#         <__main__.signal object at 0x000002E606BA06A0>,
#         <__main__.signal object at 0x000002E606BA3908>,
#         <__main__.signal object at 0x000002E606BA7B70>,
#         <__main__.signal object at 0x000002E606BAADD8>,
#         <__main__.signal object at 0x000002E606BB0080>,
#         <__main__.signal object at 0x000002E606BB32E8>,
#         <__main__.signal object at 0x000002E606BB7550>,
#         <__main__.signal object at 0x000002E606BBA7B8>,
#         <__main__.signal object at 0x000002E606BBDA20>,
#         <__main__.signal object at 0x000002E606BC2C88>,
#         <__main__.signal object at 0x000002E606BC4EF0>,
#         <__main__.signal object at 0x000002E606BC9198>,
#         <__main__.signal object at 0x000002E606BCE400>,
#         <__main__.signal object at 0x000002E606BD1668>,
#         <__main__.signal object at 0x000002E606BD48D0>,
#         <__main__.signal object at 0x000002E606BD8B38>,
#         <__main__.signal object at 0x000002E606BDBDA0>,
#         <__main__.signal object at 0x000002E606BE1048>,
#         <__main__.signal object at 0x000002E606BE42B0>,
#         <__main__.signal object at 0x000002E606BE8518>,
#         <__main__.signal object at 0x000002E606BEB780>,
#         <__main__.signal object at 0x000002E606BEF9E8>,
#         <__main__.signal object at 0x000002E606BF2C50>,
#         <__main__.signal object at 0x000002E606BF6EB8>,
#         <__main__.signal object at 0x000002E606BFB160>,
#         <__main__.signal object at 0x000002E606BFF3C8>,
#         <__main__.signal object at 0x000002E606C02630>,
#         <__main__.signal object at 0x000002E606C05898>,
#         <__main__.signal object at 0x000002E606C0AB00>,
#         <__main__.signal object at 0x000002E606C0DD68>,
#         <__main__.signal object at 0x000002E606C10FD0>,
#         <__main__.signal object at 0x000002E606C16278>,
#         <__main__.signal object at 0x000002E606C194E0>,
#         <__main__.signal object at 0x000002E606C1D748>,
#         <__main__.signal object at 0x000002E606C219B0>,
#         <__main__.signal object at 0x000002E606C23C18>,
#         <__main__.signal object at 0x000002E606C28E80>,
#         <__main__.signal object at 0x000002E606C2C128>,
#         <__main__.signal object at 0x000002E606C31390>,
#         <__main__.signal object at 0x000002E606C345F8>,
#         <__main__.signal object at 0x000002E606C37860>,
#         <__main__.signal object at 0x000002E606C3BAC8>,
#         <__main__.signal object at 0x000002E606C3ED30>,
#         <__main__.signal object at 0x000002E606C42F98>,
#         <__main__.signal object at 0x000002E606C48240>,
#         <__main__.signal object at 0x000002E606C4A4A8>,
#         <__main__.signal object at 0x000002E606C4F710>,
#         <__main__.signal object at 0x000002E606C52978>,
#         <__main__.signal object at 0x000002E606C55BE0>,
#         <__main__.signal object at 0x000002E606C59E48>,
#         <__main__.signal object at 0x000002E606C5E0F0>,
#         <__main__.signal object at 0x000002E606C61358>,
#         <__main__.signal object at 0x000002E606C655C0>,
#         <__main__.signal object at 0x000002E606C69828>,
#         <__main__.signal object at 0x000002E606C6CA90>,
#         <__main__.signal object at 0x000002E606C70CF8>,
#         <__main__.signal object at 0x000002E606C73F60>,
#         <__main__.signal object at 0x000002E606C79208>,
#         <__main__.signal object at 0x000002E606C7C470>,
#         <__main__.signal object at 0x000002E606C7F6D8>,
#         <__main__.signal object at 0x000002E606C83940>,
#         <__main__.signal object at 0x000002E606C86BA8>,
#         <__main__.signal object at 0x000002E606C8AE10>,
#         <__main__.signal object at 0x000002E606C900B8>,
#         <__main__.signal object at 0x000002E606C92320>,
#         <__main__.signal object at 0x000002E606C97588>,
#         <__main__.signal object at 0x000002E606C9A7F0>,
#         <__main__.signal object at 0x000002E606C9DA58>,
#         <__main__.signal object at 0x000002E606CA1CC0>,
#         <__main__.signal object at 0x000002E606CA4F28>,
#         <__main__.signal object at 0x000002E606CAA1D0>,
#         <__main__.signal object at 0x000002E606CAD438>], dtype=object),
#  'white-info-5': array([<__main__.signal object at 0x000002E606AA9828>,
#         <__main__.signal object at 0x000002E606AAB9E8>,
#         <__main__.signal object at 0x000002E606AB4C18>,
#         <__main__.signal object at 0x000002E606AC3E80>,
#         <__main__.signal object at 0x000002E606AC9128>,
#         <__main__.signal object at 0x000002E606ACB390>,
#         <__main__.signal object at 0x000002E606AD65F8>,
#         <__main__.signal object at 0x000002E606ADA860>,
#         <__main__.signal object at 0x000002E606ADEAC8>,
#         <__main__.signal object at 0x000002E606AE1D30>,
#         <__main__.signal object at 0x000002E606AE5F98>,
#         <__main__.signal object at 0x000002E606AE9240>,
#         <__main__.signal object at 0x000002E606AEE4A8>,
#         <__main__.signal object at 0x000002E606AF2710>,
#         <__main__.signal object at 0x000002E606AF4978>,
#         <__main__.signal object at 0x000002E606AF9BE0>,
#         <__main__.signal object at 0x000002E606AFBE48>,
#         <__main__.signal object at 0x000002E606B010F0>,
#         <__main__.signal object at 0x000002E606B05358>,
#         <__main__.signal object at 0x000002E606B085C0>,
#         <__main__.signal object at 0x000002E606B0C828>,
#         <__main__.signal object at 0x000002E606B0FA90>,
#         <__main__.signal object at 0x000002E606B13CF8>,
#         <__main__.signal object at 0x000002E606B16F60>,
#         <__main__.signal object at 0x000002E606B1B208>,
#         <__main__.signal object at 0x000002E606B1F470>,
#         <__main__.signal object at 0x000002E606B226D8>,
#         <__main__.signal object at 0x000002E606B26940>,
#         <__main__.signal object at 0x000002E606B2ABA8>,
#         <__main__.signal object at 0x000002E606B2DE10>,
#         <__main__.signal object at 0x000002E606B320B8>,
#         <__main__.signal object at 0x000002E606B36320>,
#         <__main__.signal object at 0x000002E606B39588>,
#         <__main__.signal object at 0x000002E606B3C7F0>,
#         <__main__.signal object at 0x000002E606B41A58>,
#         <__main__.signal object at 0x000002E606B43CC0>,
#         <__main__.signal object at 0x000002E606B48F28>,
#         <__main__.signal object at 0x000002E606B4D1D0>,
#         <__main__.signal object at 0x000002E606B50438>,
#         <__main__.signal object at 0x000002E606B546A0>,
#         <__main__.signal object at 0x000002E606B57908>,
#         <__main__.signal object at 0x000002E606B5AB70>,
#         <__main__.signal object at 0x000002E606B5FDD8>,
#         <__main__.signal object at 0x000002E606B63080>,
#         <__main__.signal object at 0x000002E606B682E8>,
#         <__main__.signal object at 0x000002E606B6A550>,
#         <__main__.signal object at 0x000002E606B6E7B8>,
#         <__main__.signal object at 0x000002E606B73A20>,
#         <__main__.signal object at 0x000002E606B75C88>,
#         <__main__.signal object at 0x000002E606B79EF0>,
#         <__main__.signal object at 0x000002E606B7E198>,
#         <__main__.signal object at 0x000002E606B81400>,
#         <__main__.signal object at 0x000002E606B86668>,
#         <__main__.signal object at 0x000002E606B898D0>,
#         <__main__.signal object at 0x000002E606B8CB38>,
#         <__main__.signal object at 0x000002E606B90DA0>,
#         <__main__.signal object at 0x000002E606B95048>,
#         <__main__.signal object at 0x000002E606B982B0>,
#         <__main__.signal object at 0x000002E606B9C518>,
#         <__main__.signal object at 0x000002E606BA0780>,
#         <__main__.signal object at 0x000002E606BA39E8>,
#         <__main__.signal object at 0x000002E606BA7C50>,
#         <__main__.signal object at 0x000002E606BAAEB8>,
#         <__main__.signal object at 0x000002E606BB0160>,
#         <__main__.signal object at 0x000002E606BB33C8>,
#         <__main__.signal object at 0x000002E606BB7630>,
#         <__main__.signal object at 0x000002E606BBA898>,
#         <__main__.signal object at 0x000002E606BBDB00>,
#         <__main__.signal object at 0x000002E606BC2D68>,
#         <__main__.signal object at 0x000002E606BC4FD0>,
#         <__main__.signal object at 0x000002E606BC9278>,
#         <__main__.signal object at 0x000002E606BCE4E0>,
#         <__main__.signal object at 0x000002E606BD1748>,
#         <__main__.signal object at 0x000002E606BD49B0>,
#         <__main__.signal object at 0x000002E606BD8C18>,
#         <__main__.signal object at 0x000002E606BDBE80>,
#         <__main__.signal object at 0x000002E606BE1128>,
#         <__main__.signal object at 0x000002E606BE4390>,
#         <__main__.signal object at 0x000002E606BE85F8>,
#         <__main__.signal object at 0x000002E606BEB860>,
#         <__main__.signal object at 0x000002E606BEFAC8>,
#         <__main__.signal object at 0x000002E606BF2D30>,
#         <__main__.signal object at 0x000002E606BF6F98>,
#         <__main__.signal object at 0x000002E606BFB240>,
#         <__main__.signal object at 0x000002E606BFF4A8>,
#         <__main__.signal object at 0x000002E606C02710>,
#         <__main__.signal object at 0x000002E606C05978>,
#         <__main__.signal object at 0x000002E606C0ABE0>,
#         <__main__.signal object at 0x000002E606C0DE48>,
#         <__main__.signal object at 0x000002E606C120F0>,
#         <__main__.signal object at 0x000002E606C16358>,
#         <__main__.signal object at 0x000002E606C195C0>,
#         <__main__.signal object at 0x000002E606C1D828>,
#         <__main__.signal object at 0x000002E606C21A90>,
#         <__main__.signal object at 0x000002E606C23CF8>,
#         <__main__.signal object at 0x000002E606C28F60>,
#         <__main__.signal object at 0x000002E606C2C208>,
#         <__main__.signal object at 0x000002E606C31470>,
#         <__main__.signal object at 0x000002E606C346D8>,
#         <__main__.signal object at 0x000002E606C37940>,
#         <__main__.signal object at 0x000002E606C3BBA8>,
#         <__main__.signal object at 0x000002E606C3EE10>,
#         <__main__.signal object at 0x000002E606C440B8>,
#         <__main__.signal object at 0x000002E606C48320>,
#         <__main__.signal object at 0x000002E606C4A588>,
#         <__main__.signal object at 0x000002E606C4F7F0>,
#         <__main__.signal object at 0x000002E606C52A58>,
#         <__main__.signal object at 0x000002E606C55CC0>,
#         <__main__.signal object at 0x000002E606C59F28>,
#         <__main__.signal object at 0x000002E606C5E1D0>,
#         <__main__.signal object at 0x000002E606C61438>,
#         <__main__.signal object at 0x000002E606C656A0>,
#         <__main__.signal object at 0x000002E606C69908>,
#         <__main__.signal object at 0x000002E606C6CB70>,
#         <__main__.signal object at 0x000002E606C70DD8>,
#         <__main__.signal object at 0x000002E606C75080>,
#         <__main__.signal object at 0x000002E606C792E8>,
#         <__main__.signal object at 0x000002E606C7C550>,
#         <__main__.signal object at 0x000002E606C7F7B8>,
#         <__main__.signal object at 0x000002E606C83A20>,
#         <__main__.signal object at 0x000002E606C86C88>,
#         <__main__.signal object at 0x000002E606C8AEF0>,
#         <__main__.signal object at 0x000002E606C90198>,
#         <__main__.signal object at 0x000002E606C92400>,
#         <__main__.signal object at 0x000002E606C97668>,
#         <__main__.signal object at 0x000002E606C9A8D0>,
#         <__main__.signal object at 0x000002E606C9DB38>,
#         <__main__.signal object at 0x000002E606CA1DA0>,
#         <__main__.signal object at 0x000002E606CA6048>,
#         <__main__.signal object at 0x000002E606CAA2B0>,
#         <__main__.signal object at 0x000002E606CAD518>], dtype=object),
#  'white-info-6': array([<__main__.signal object at 0x000002E606AA9908>,
#         <__main__.signal object at 0x000002E606AABAC8>,
#         <__main__.signal object at 0x000002E606AB4CF8>,
#         <__main__.signal object at 0x000002E606AC3F60>,
#         <__main__.signal object at 0x000002E606AC9208>,
#         <__main__.signal object at 0x000002E606ACB470>,
#         <__main__.signal object at 0x000002E606AD66D8>,
#         <__main__.signal object at 0x000002E606ADA940>,
#         <__main__.signal object at 0x000002E606ADEBA8>,
#         <__main__.signal object at 0x000002E606AE1E10>,
#         <__main__.signal object at 0x000002E606AE70B8>,
#         <__main__.signal object at 0x000002E606AE9320>,
#         <__main__.signal object at 0x000002E606AEE588>,
#         <__main__.signal object at 0x000002E606AF27F0>,
#         <__main__.signal object at 0x000002E606AF4A58>,
#         <__main__.signal object at 0x000002E606AF9CC0>,
#         <__main__.signal object at 0x000002E606AFBF28>,
#         <__main__.signal object at 0x000002E606B011D0>,
#         <__main__.signal object at 0x000002E606B05438>,
#         <__main__.signal object at 0x000002E606B086A0>,
#         <__main__.signal object at 0x000002E606B0C908>,
#         <__main__.signal object at 0x000002E606B0FB70>,
#         <__main__.signal object at 0x000002E606B13DD8>,
#         <__main__.signal object at 0x000002E606B18080>,
#         <__main__.signal object at 0x000002E606B1B2E8>,
#         <__main__.signal object at 0x000002E606B1F550>,
#         <__main__.signal object at 0x000002E606B227B8>,
#         <__main__.signal object at 0x000002E606B26A20>,
#         <__main__.signal object at 0x000002E606B2AC88>,
#         <__main__.signal object at 0x000002E606B2DEF0>,
#         <__main__.signal object at 0x000002E606B32198>,
#         <__main__.signal object at 0x000002E606B36400>,
#         <__main__.signal object at 0x000002E606B39668>,
#         <__main__.signal object at 0x000002E606B3C8D0>,
#         <__main__.signal object at 0x000002E606B41B38>,
#         <__main__.signal object at 0x000002E606B43DA0>,
#         <__main__.signal object at 0x000002E606B49048>,
#         <__main__.signal object at 0x000002E606B4D2B0>,
#         <__main__.signal object at 0x000002E606B50518>,
#         <__main__.signal object at 0x000002E606B54780>,
#         <__main__.signal object at 0x000002E606B579E8>,
#         <__main__.signal object at 0x000002E606B5AC50>,
#         <__main__.signal object at 0x000002E606B5FEB8>,
#         <__main__.signal object at 0x000002E606B63160>,
#         <__main__.signal object at 0x000002E606B683C8>,
#         <__main__.signal object at 0x000002E606B6A630>,
#         <__main__.signal object at 0x000002E606B6E898>,
#         <__main__.signal object at 0x000002E606B73B00>,
#         <__main__.signal object at 0x000002E606B75D68>,
#         <__main__.signal object at 0x000002E606B79FD0>,
#         <__main__.signal object at 0x000002E606B7E278>,
#         <__main__.signal object at 0x000002E606B814E0>,
#         <__main__.signal object at 0x000002E606B86748>,
#         <__main__.signal object at 0x000002E606B899B0>,
#         <__main__.signal object at 0x000002E606B8CC18>,
#         <__main__.signal object at 0x000002E606B90E80>,
#         <__main__.signal object at 0x000002E606B95128>,
#         <__main__.signal object at 0x000002E606B98390>,
#         <__main__.signal object at 0x000002E606B9C5F8>,
#         <__main__.signal object at 0x000002E606BA0860>,
#         <__main__.signal object at 0x000002E606BA3AC8>,
#         <__main__.signal object at 0x000002E606BA7D30>,
#         <__main__.signal object at 0x000002E606BAAF98>,
#         <__main__.signal object at 0x000002E606BB0240>,
#         <__main__.signal object at 0x000002E606BB34A8>,
#         <__main__.signal object at 0x000002E606BB7710>,
#         <__main__.signal object at 0x000002E606BBA978>,
#         <__main__.signal object at 0x000002E606BBDBE0>,
#         <__main__.signal object at 0x000002E606BC2E48>,
#         <__main__.signal object at 0x000002E606BC70F0>,
#         <__main__.signal object at 0x000002E606BC9358>,
#         <__main__.signal object at 0x000002E606BCE5C0>,
#         <__main__.signal object at 0x000002E606BD1828>,
#         <__main__.signal object at 0x000002E606BD4A90>,
#         <__main__.signal object at 0x000002E606BD8CF8>,
#         <__main__.signal object at 0x000002E606BDBF60>,
#         <__main__.signal object at 0x000002E606BE1208>,
#         <__main__.signal object at 0x000002E606BE4470>,
#         <__main__.signal object at 0x000002E606BE86D8>,
#         <__main__.signal object at 0x000002E606BEB940>,
#         <__main__.signal object at 0x000002E606BEFBA8>,
#         <__main__.signal object at 0x000002E606BF2E10>,
#         <__main__.signal object at 0x000002E606BF80B8>,
#         <__main__.signal object at 0x000002E606BFB320>,
#         <__main__.signal object at 0x000002E606BFF588>,
#         <__main__.signal object at 0x000002E606C027F0>,
#         <__main__.signal object at 0x000002E606C05A58>,
#         <__main__.signal object at 0x000002E606C0ACC0>,
#         <__main__.signal object at 0x000002E606C0DF28>,
#         <__main__.signal object at 0x000002E606C121D0>,
#         <__main__.signal object at 0x000002E606C16438>,
#         <__main__.signal object at 0x000002E606C196A0>,
#         <__main__.signal object at 0x000002E606C1D908>,
#         <__main__.signal object at 0x000002E606C21B70>,
#         <__main__.signal object at 0x000002E606C23DD8>,
#         <__main__.signal object at 0x000002E606C29080>,
#         <__main__.signal object at 0x000002E606C2C2E8>,
#         <__main__.signal object at 0x000002E606C31550>,
#         <__main__.signal object at 0x000002E606C347B8>,
#         <__main__.signal object at 0x000002E606C37A20>,
#         <__main__.signal object at 0x000002E606C3BC88>,
#         <__main__.signal object at 0x000002E606C3EEF0>,
#         <__main__.signal object at 0x000002E606C44198>,
#         <__main__.signal object at 0x000002E606C48400>,
#         <__main__.signal object at 0x000002E606C4A668>,
#         <__main__.signal object at 0x000002E606C4F8D0>,
#         <__main__.signal object at 0x000002E606C52B38>,
#         <__main__.signal object at 0x000002E606C55DA0>,
#         <__main__.signal object at 0x000002E606C5B048>,
#         <__main__.signal object at 0x000002E606C5E2B0>,
#         <__main__.signal object at 0x000002E606C61518>,
#         <__main__.signal object at 0x000002E606C65780>,
#         <__main__.signal object at 0x000002E606C699E8>,
#         <__main__.signal object at 0x000002E606C6CC50>,
#         <__main__.signal object at 0x000002E606C70EB8>,
#         <__main__.signal object at 0x000002E606C75160>,
#         <__main__.signal object at 0x000002E606C793C8>,
#         <__main__.signal object at 0x000002E606C7C630>,
#         <__main__.signal object at 0x000002E606C7F898>,
#         <__main__.signal object at 0x000002E606C83B00>,
#         <__main__.signal object at 0x000002E606C86D68>,
#         <__main__.signal object at 0x000002E606C8AFD0>,
#         <__main__.signal object at 0x000002E606C90278>,
#         <__main__.signal object at 0x000002E606C924E0>,
#         <__main__.signal object at 0x000002E606C97748>,
#         <__main__.signal object at 0x000002E606C9A9B0>,
#         <__main__.signal object at 0x000002E606C9DC18>,
#         <__main__.signal object at 0x000002E606CA1E80>,
#         <__main__.signal object at 0x000002E606CA6128>,
#         <__main__.signal object at 0x000002E606CAA390>,
#         <__main__.signal object at 0x000002E606CAD5F8>], dtype=object),
#  'white-info-7': array([<__main__.signal object at 0x000002E606AA99E8>,
#         <__main__.signal object at 0x000002E606AABBA8>,
#         <__main__.signal object at 0x000002E606AB4DD8>,
#         <__main__.signal object at 0x000002E606AC2080>,
#         <__main__.signal object at 0x000002E606AC92E8>,
#         <__main__.signal object at 0x000002E606ACB550>,
#         <__main__.signal object at 0x000002E606AD67B8>,
#         <__main__.signal object at 0x000002E606ADAA20>,
#         <__main__.signal object at 0x000002E606ADEC88>,
#         <__main__.signal object at 0x000002E606AE1EF0>,
#         <__main__.signal object at 0x000002E606AE7198>,
#         <__main__.signal object at 0x000002E606AE9400>,
#         <__main__.signal object at 0x000002E606AEE668>,
#         <__main__.signal object at 0x000002E606AF28D0>,
#         <__main__.signal object at 0x000002E606AF4B38>,
#         <__main__.signal object at 0x000002E606AF9DA0>,
#         <__main__.signal object at 0x000002E606AFD048>,
#         <__main__.signal object at 0x000002E606B012B0>,
#         <__main__.signal object at 0x000002E606B05518>,
#         <__main__.signal object at 0x000002E606B08780>,
#         <__main__.signal object at 0x000002E606B0C9E8>,
#         <__main__.signal object at 0x000002E606B0FC50>,
#         <__main__.signal object at 0x000002E606B13EB8>,
#         <__main__.signal object at 0x000002E606B18160>,
#         <__main__.signal object at 0x000002E606B1B3C8>,
#         <__main__.signal object at 0x000002E606B1F630>,
#         <__main__.signal object at 0x000002E606B22898>,
#         <__main__.signal object at 0x000002E606B26B00>,
#         <__main__.signal object at 0x000002E606B2AD68>,
#         <__main__.signal object at 0x000002E606B2DFD0>,
#         <__main__.signal object at 0x000002E606B32278>,
#         <__main__.signal object at 0x000002E606B364E0>,
#         <__main__.signal object at 0x000002E606B39748>,
#         <__main__.signal object at 0x000002E606B3C9B0>,
#         <__main__.signal object at 0x000002E606B41C18>,
#         <__main__.signal object at 0x000002E606B43E80>,
#         <__main__.signal object at 0x000002E606B49128>,
#         <__main__.signal object at 0x000002E606B4D390>,
#         <__main__.signal object at 0x000002E606B505F8>,
#         <__main__.signal object at 0x000002E606B54860>,
#         <__main__.signal object at 0x000002E606B57AC8>,
#         <__main__.signal object at 0x000002E606B5AD30>,
#         <__main__.signal object at 0x000002E606B5FF98>,
#         <__main__.signal object at 0x000002E606B63240>,
#         <__main__.signal object at 0x000002E606B684A8>,
#         <__main__.signal object at 0x000002E606B6A710>,
#         <__main__.signal object at 0x000002E606B6E978>,
#         <__main__.signal object at 0x000002E606B73BE0>,
#         <__main__.signal object at 0x000002E606B75E48>,
#         <__main__.signal object at 0x000002E606B7B0F0>,
#         <__main__.signal object at 0x000002E606B7E358>,
#         <__main__.signal object at 0x000002E606B815C0>,
#         <__main__.signal object at 0x000002E606B86828>,
#         <__main__.signal object at 0x000002E606B89A90>,
#         <__main__.signal object at 0x000002E606B8CCF8>,
#         <__main__.signal object at 0x000002E606B90F60>,
#         <__main__.signal object at 0x000002E606B95208>,
#         <__main__.signal object at 0x000002E606B98470>,
#         <__main__.signal object at 0x000002E606B9C6D8>,
#         <__main__.signal object at 0x000002E606BA0940>,
#         <__main__.signal object at 0x000002E606BA3BA8>,
#         <__main__.signal object at 0x000002E606BA7E10>,
#         <__main__.signal object at 0x000002E606BAC0B8>,
#         <__main__.signal object at 0x000002E606BB0320>,
#         <__main__.signal object at 0x000002E606BB3588>,
#         <__main__.signal object at 0x000002E606BB77F0>,
#         <__main__.signal object at 0x000002E606BBAA58>,
# ...
#         <__main__.signal object at 0x000002E606CA8BA8>,
#         <__main__.signal object at 0x000002E606CACE10>,
#         <__main__.signal object at 0x000002E606CB10B8>], dtype=object),
#  'start': array([<__main__.signal object at 0x000002E606AAB4E0>,
#         <__main__.signal object at 0x000002E606AB46A0>,
#         <__main__.signal object at 0x000002E606AC38D0>,
#         <__main__.signal object at 0x000002E606AC7B38>,
#         <__main__.signal object at 0x000002E606ACADA0>,
#         <__main__.signal object at 0x000002E606AD6048>,
#         <__main__.signal object at 0x000002E606ADA2B0>,
#         <__main__.signal object at 0x000002E606ADE518>,
#         <__main__.signal object at 0x000002E606AE1780>,
#         <__main__.signal object at 0x000002E606AE59E8>,
#         <__main__.signal object at 0x000002E606AE8C50>,
#         <__main__.signal object at 0x000002E606AECEB8>,
#         <__main__.signal object at 0x000002E606AF2160>,
#         <__main__.signal object at 0x000002E606AF43C8>,
#         <__main__.signal object at 0x000002E606AF9630>,
#         <__main__.signal object at 0x000002E606AFB898>,
#         <__main__.signal object at 0x000002E606AFFB00>,
#         <__main__.signal object at 0x000002E606B03D68>,
#         <__main__.signal object at 0x000002E606B06FD0>,
#         <__main__.signal object at 0x000002E606B0C278>,
#         <__main__.signal object at 0x000002E606B0F4E0>,
#         <__main__.signal object at 0x000002E606B13748>,
#         <__main__.signal object at 0x000002E606B169B0>,
#         <__main__.signal object at 0x000002E606B1AC18>,
#         <__main__.signal object at 0x000002E606B1CE80>,
#         <__main__.signal object at 0x000002E606B22128>,
#         <__main__.signal object at 0x000002E606B26390>,
#         <__main__.signal object at 0x000002E606B2A5F8>,
#         <__main__.signal object at 0x000002E606B2D860>,
#         <__main__.signal object at 0x000002E606B30AC8>,
#         <__main__.signal object at 0x000002E606B35D30>,
#         <__main__.signal object at 0x000002E606B38F98>,
#         <__main__.signal object at 0x000002E606B3C240>,
#         <__main__.signal object at 0x000002E606B414A8>,
#         <__main__.signal object at 0x000002E606B43710>,
#         <__main__.signal object at 0x000002E606B48978>,
#         <__main__.signal object at 0x000002E606B4CBE0>,
#         <__main__.signal object at 0x000002E606B4EE48>,
#         <__main__.signal object at 0x000002E606B540F0>,
#         <__main__.signal object at 0x000002E606B57358>,
#         <__main__.signal object at 0x000002E606B5A5C0>,
#         <__main__.signal object at 0x000002E606B5F828>,
#         <__main__.signal object at 0x000002E606B62A90>,
#         <__main__.signal object at 0x000002E606B65CF8>,
#         <__main__.signal object at 0x000002E606B69F60>,
#         <__main__.signal object at 0x000002E606B6E208>,
#         <__main__.signal object at 0x000002E606B73470>,
#         <__main__.signal object at 0x000002E606B756D8>,
#         <__main__.signal object at 0x000002E606B79940>,
#         <__main__.signal object at 0x000002E606B7CBA8>,
#         <__main__.signal object at 0x000002E606B80E10>,
#         <__main__.signal object at 0x000002E606B860B8>,
#         <__main__.signal object at 0x000002E606B89320>,
#         <__main__.signal object at 0x000002E606B8C588>,
#         <__main__.signal object at 0x000002E606B907F0>,
#         <__main__.signal object at 0x000002E606B94A58>,
#         <__main__.signal object at 0x000002E606B96CC0>,
#         <__main__.signal object at 0x000002E606B9BF28>,
#         <__main__.signal object at 0x000002E606BA01D0>,
#         <__main__.signal object at 0x000002E606BA3438>,
#         <__main__.signal object at 0x000002E606BA76A0>,
#         <__main__.signal object at 0x000002E606BAA908>,
#         <__main__.signal object at 0x000002E606BAEB70>,
#         <__main__.signal object at 0x000002E606BB1DD8>,
#         <__main__.signal object at 0x000002E606BB7080>,
#         <__main__.signal object at 0x000002E606BBA2E8>,
#         <__main__.signal object at 0x000002E606BBD550>,
#         <__main__.signal object at 0x000002E606BC27B8>,
#         <__main__.signal object at 0x000002E606BC4A20>,
#         <__main__.signal object at 0x000002E606BC8C88>,
#         <__main__.signal object at 0x000002E606BCCEF0>,
#         <__main__.signal object at 0x000002E606BD1198>,
#         <__main__.signal object at 0x000002E606BD4400>,
#         <__main__.signal object at 0x000002E606BD8668>,
#         <__main__.signal object at 0x000002E606BDB8D0>,
#         <__main__.signal object at 0x000002E606BDFB38>,
#         <__main__.signal object at 0x000002E606BE3DA0>,
#         <__main__.signal object at 0x000002E606BE8048>,
#         <__main__.signal object at 0x000002E606BEB2B0>,
#         <__main__.signal object at 0x000002E606BEF518>,
#         <__main__.signal object at 0x000002E606BF2780>,
#         <__main__.signal object at 0x000002E606BF69E8>,
#         <__main__.signal object at 0x000002E606BFAC50>,
#         <__main__.signal object at 0x000002E606BFDEB8>,
#         <__main__.signal object at 0x000002E606C02160>,
#         <__main__.signal object at 0x000002E606C053C8>,
#         <__main__.signal object at 0x000002E606C0A630>,
#         <__main__.signal object at 0x000002E606C0D898>,
#         <__main__.signal object at 0x000002E606C10B00>,
#         <__main__.signal object at 0x000002E606C15D68>,
#         <__main__.signal object at 0x000002E606C17FD0>,
#         <__main__.signal object at 0x000002E606C1D278>,
#         <__main__.signal object at 0x000002E606C214E0>,
#         <__main__.signal object at 0x000002E606C23748>,
#         <__main__.signal object at 0x000002E606C289B0>,
#         <__main__.signal object at 0x000002E606C2BC18>,
#         <__main__.signal object at 0x000002E606C2EE80>,
#         <__main__.signal object at 0x000002E606C34128>,
#         <__main__.signal object at 0x000002E606C37390>,
#         <__main__.signal object at 0x000002E606C3B5F8>,
#         <__main__.signal object at 0x000002E606C3E860>,
#         <__main__.signal object at 0x000002E606C42AC8>,
#         <__main__.signal object at 0x000002E606C45D30>,
#         <__main__.signal object at 0x000002E606C49F98>,
#         <__main__.signal object at 0x000002E606C4F240>,
#         <__main__.signal object at 0x000002E606C524A8>,
#         <__main__.signal object at 0x000002E606C55710>,
#         <__main__.signal object at 0x000002E606C59978>,
#         <__main__.signal object at 0x000002E606C5CBE0>,
#         <__main__.signal object at 0x000002E606C5FE48>,
#         <__main__.signal object at 0x000002E606C650F0>,
#         <__main__.signal object at 0x000002E606C69358>,
#         <__main__.signal object at 0x000002E606C6C5C0>,
#         <__main__.signal object at 0x000002E606C70828>,
#         <__main__.signal object at 0x000002E606C73A90>,
#         <__main__.signal object at 0x000002E606C77CF8>,
#         <__main__.signal object at 0x000002E606C7AF60>,
#         <__main__.signal object at 0x000002E606C7F208>,
#         <__main__.signal object at 0x000002E606C83470>,
#         <__main__.signal object at 0x000002E606C866D8>,
#         <__main__.signal object at 0x000002E606C8A940>,
#         <__main__.signal object at 0x000002E606C8DBA8>,
#         <__main__.signal object at 0x000002E606C91E10>,
#         <__main__.signal object at 0x000002E606C970B8>,
#         <__main__.signal object at 0x000002E606C9A320>,
#         <__main__.signal object at 0x000002E606C9D588>,
#         <__main__.signal object at 0x000002E606CA17F0>,
#         <__main__.signal object at 0x000002E606CA4A58>,
#         <__main__.signal object at 0x000002E606CA8CC0>,
#         <__main__.signal object at 0x000002E606CACF28>,
#         <__main__.signal object at 0x000002E606CB11D0>], dtype=object),
#  'summary': array([<__main__.signal_summary object at 0x000002E606AA93C8>,
#         <__main__.signal_summary object at 0x000002E606AA9390>,
#         <__main__.signal_summary object at 0x000002E606AA92B0>,
#         <__main__.signal_summary object at 0x000002E606AA9358>,
#         <__main__.signal_summary object at 0x000002E606AC3AC8>,
#         <__main__.signal_summary object at 0x000002E606AC7D30>,
#         <__main__.signal_summary object at 0x000002E606ACAF98>,
#         <__main__.signal_summary object at 0x000002E606AD6240>,
#         <__main__.signal_summary object at 0x000002E606ADA4A8>,
#         <__main__.signal_summary object at 0x000002E606ADE710>,
#         <__main__.signal_summary object at 0x000002E606AE1978>,
#         <__main__.signal_summary object at 0x000002E606AE5BE0>,
#         <__main__.signal_summary object at 0x000002E606AE8E48>,
#         <__main__.signal_summary object at 0x000002E606AECEF0>,
#         <__main__.signal_summary object at 0x000002E606AF2358>,
#         <__main__.signal_summary object at 0x000002E606AF45C0>,
#         <__main__.signal_summary object at 0x000002E606AF9828>,
#         <__main__.signal_summary object at 0x000002E606AFBA90>,
#         <__main__.signal_summary object at 0x000002E606AFFCF8>,
#         <__main__.signal_summary object at 0x000002E606B03F60>,
#         <__main__.signal_summary object at 0x000002E606B08208>,
#         <__main__.signal_summary object at 0x000002E606B0C470>,
#         <__main__.signal_summary object at 0x000002E606B0F6D8>,
#         <__main__.signal_summary object at 0x000002E606B13940>,
#         <__main__.signal_summary object at 0x000002E606B16BA8>,
#         <__main__.signal_summary object at 0x000002E606B1AE10>,
#         <__main__.signal_summary object at 0x000002E606B1CEB8>,
#         <__main__.signal_summary object at 0x000002E606B22320>,
#         <__main__.signal_summary object at 0x000002E606B26588>,
#         <__main__.signal_summary object at 0x000002E606B2A7F0>,
#         <__main__.signal_summary object at 0x000002E606B2DA58>,
#         <__main__.signal_summary object at 0x000002E606B30CC0>,
#         <__main__.signal_summary object at 0x000002E606B35F28>,
#         <__main__.signal_summary object at 0x000002E606B38FD0>,
#         <__main__.signal_summary object at 0x000002E606B3C438>,
#         <__main__.signal_summary object at 0x000002E606B416A0>,
#         <__main__.signal_summary object at 0x000002E606B43908>,
#         <__main__.signal_summary object at 0x000002E606B48B70>,
#         <__main__.signal_summary object at 0x000002E606B4CDD8>,
#         <__main__.signal_summary object at 0x000002E606B50080>,
#         <__main__.signal_summary object at 0x000002E606B542E8>,
#         <__main__.signal_summary object at 0x000002E606B57550>,
#         <__main__.signal_summary object at 0x000002E606B5A7B8>,
#         <__main__.signal_summary object at 0x000002E606B5FA20>,
#         <__main__.signal_summary object at 0x000002E606B62C88>,
#         <__main__.signal_summary object at 0x000002E606B65EF0>,
#         <__main__.signal_summary object at 0x000002E606B69F98>,
#         <__main__.signal_summary object at 0x000002E606B6E400>,
#         <__main__.signal_summary object at 0x000002E606B73668>,
#         <__main__.signal_summary object at 0x000002E606B758D0>,
#         <__main__.signal_summary object at 0x000002E606B79B38>,
#         <__main__.signal_summary object at 0x000002E606B7CDA0>,
#         <__main__.signal_summary object at 0x000002E606B81048>,
#         <__main__.signal_summary object at 0x000002E606B862B0>,
#         <__main__.signal_summary object at 0x000002E606B89518>,
#         <__main__.signal_summary object at 0x000002E606B8C780>,
#         <__main__.signal_summary object at 0x000002E606B909E8>,
#         <__main__.signal_summary object at 0x000002E606B94C50>,
#         <__main__.signal_summary object at 0x000002E606B96EB8>,
#         <__main__.signal_summary object at 0x000002E606B9BF60>,
#         <__main__.signal_summary object at 0x000002E606BA03C8>,
#         <__main__.signal_summary object at 0x000002E606BA3630>,
#         <__main__.signal_summary object at 0x000002E606BA7898>,
#         <__main__.signal_summary object at 0x000002E606BAAB00>,
#         <__main__.signal_summary object at 0x000002E606BAED68>,
#         <__main__.signal_summary object at 0x000002E606BB1FD0>,
#         <__main__.signal_summary object at 0x000002E606BB7278>,
#         <__main__.signal_summary object at 0x000002E606BBA4E0>,
#         <__main__.signal_summary object at 0x000002E606BBD748>,
#         <__main__.signal_summary object at 0x000002E606BC29B0>,
#         <__main__.signal_summary object at 0x000002E606BC4C18>,
#         <__main__.signal_summary object at 0x000002E606BC8E80>,
#         <__main__.signal_summary object at 0x000002E606BCCF28>,
#         <__main__.signal_summary object at 0x000002E606BD1390>,
#         <__main__.signal_summary object at 0x000002E606BD45F8>,
#         <__main__.signal_summary object at 0x000002E606BD8860>,
#         <__main__.signal_summary object at 0x000002E606BDBAC8>,
#         <__main__.signal_summary object at 0x000002E606BDFD30>,
#         <__main__.signal_summary object at 0x000002E606BE3F98>,
#         <__main__.signal_summary object at 0x000002E606BE8240>,
#         <__main__.signal_summary object at 0x000002E606BEB4A8>,
#         <__main__.signal_summary object at 0x000002E606BEF710>,
#         <__main__.signal_summary object at 0x000002E606BF2978>,
#         <__main__.signal_summary object at 0x000002E606BF6BE0>,
#         <__main__.signal_summary object at 0x000002E606BFAE48>,
#         <__main__.signal_summary object at 0x000002E606BFDEF0>,
#         <__main__.signal_summary object at 0x000002E606C02358>,
#         <__main__.signal_summary object at 0x000002E606C055C0>,
#         <__main__.signal_summary object at 0x000002E606C0A828>,
#         <__main__.signal_summary object at 0x000002E606C0DA90>,
#         <__main__.signal_summary object at 0x000002E606C10CF8>,
#         <__main__.signal_summary object at 0x000002E606C15F60>,
#         <__main__.signal_summary object at 0x000002E606C19208>,
#         <__main__.signal_summary object at 0x000002E606C1D470>,
#         <__main__.signal_summary object at 0x000002E606C216D8>,
#         <__main__.signal_summary object at 0x000002E606C23940>,
#         <__main__.signal_summary object at 0x000002E606C28BA8>,
#         <__main__.signal_summary object at 0x000002E606C2BE10>,
#         <__main__.signal_summary object at 0x000002E606C2EEB8>,
#         <__main__.signal_summary object at 0x000002E606C34320>,
#         <__main__.signal_summary object at 0x000002E606C37588>,
#         <__main__.signal_summary object at 0x000002E606C3B7F0>,
#         <__main__.signal_summary object at 0x000002E606C3EA58>,
#         <__main__.signal_summary object at 0x000002E606C42CC0>,
#         <__main__.signal_summary object at 0x000002E606C45F28>,
#         <__main__.signal_summary object at 0x000002E606C49FD0>,
#         <__main__.signal_summary object at 0x000002E606C4F438>,
#         <__main__.signal_summary object at 0x000002E606C526A0>,
#         <__main__.signal_summary object at 0x000002E606C55908>,
#         <__main__.signal_summary object at 0x000002E606C59B70>,
#         <__main__.signal_summary object at 0x000002E606C5CDD8>,
#         <__main__.signal_summary object at 0x000002E606C61080>,
#         <__main__.signal_summary object at 0x000002E606C652E8>,
#         <__main__.signal_summary object at 0x000002E606C69550>,
#         <__main__.signal_summary object at 0x000002E606C6C7B8>,
#         <__main__.signal_summary object at 0x000002E606C70A20>,
#         <__main__.signal_summary object at 0x000002E606C73C88>,
#         <__main__.signal_summary object at 0x000002E606C77EF0>,
#         <__main__.signal_summary object at 0x000002E606C7AF98>,
#         <__main__.signal_summary object at 0x000002E606C7F400>,
#         <__main__.signal_summary object at 0x000002E606C83668>,
#         <__main__.signal_summary object at 0x000002E606C868D0>,
#         <__main__.signal_summary object at 0x000002E606C8AB38>,
#         <__main__.signal_summary object at 0x000002E606C8DDA0>,
#         <__main__.signal_summary object at 0x000002E606C92048>,
#         <__main__.signal_summary object at 0x000002E606C972B0>,
#         <__main__.signal_summary object at 0x000002E606C9A518>,
#         <__main__.signal_summary object at 0x000002E606C9D780>,
#         <__main__.signal_summary object at 0x000002E606CA19E8>,
#         <__main__.signal_summary object at 0x000002E606CA4C50>,
#         <__main__.signal_summary object at 0x000002E606CA8EB8>],
#        dtype=object)}

# %%
len(signal_stat["white-info-2"])
# Out:
# 131

# %%
graph_dir = "graphs/"
if not os.path.exists(graph_dir):
    os.makedirs(graph_dir)

for key in signal_stat.keys():
    if key is not "summary":
        ap = [float(signal.ap) for signal in signal_stat[key]]
        tp = [int(signal.TP) for signal in signal_stat[key]]
        fp = [int(signal.FP) for signal in signal_stat[key]]

        plt.figure(figsize=(15,5))
        plt.subplot(121, title="class: "+key, ylabel="percentage")
        plt.plot(ap, label="average precision in %")
        plt.legend()
        plt.grid(True)

        plt.subplot(122, title="class: "+key, ylabel="amount")
        plt.plot(tp, "g", label="true positive")
        plt.plot(fp, "r", label="false positive")
        plt.legend()
        plt.grid(True)
        plt.savefig("graphs/"+key+".png")
        plt.show()

# %%
key = "summary"
tp = [float(signal.TP) for signal in signal_stat[key]]
fp = [int(signal.FP) for signal in signal_stat[key]]
fn = [int(signal.FN) for signal in signal_stat[key]]
average_iou = [float(signal.average_iou) for signal in signal_stat[key]]
mean_ap = [float(signal.mean_ap) for signal in signal_stat[key]]

plt.figure(figsize=(15,5))
plt.xlim(0,110)
plt.subplot(121, title="class: "+key, ylabel="percentage")
plt.plot(mean_ap, label="mean average precision in %")
plt.plot(average_iou, label="average IoU in %")
plt.legend()

plt.grid(True)

plt.subplot(122, title="class: "+key, ylabel="amount")
plt.plot(tp, "g", label="true positive")
plt.plot(fp, "r", label="false positive")
plt.plot(fn, "m", label="false negative")
plt.legend()
plt.grid(True)
plt.savefig("graphs/"+key+".png")
plt.show()

# %%
i = 0
highest = 0
highest_i = 0
best_signal = None
for x in signal_stat["summary"]:
    #print(i, x.mean_ap, x.FP, x.FN)
    check_val = float(x.mean_ap) - (float(x.FP) + float(x.FN))
    if highest < check_val:
        highest = check_val
        highest_i = i
        best_signal = x
    i = i + 1

print("Best iteration was number:", highest_i)
print("which is file: ", files[highest_i])
print("mean_ap:", best_signal.mean_ap, " FP:", best_signal.FP, " FN:", best_signal.FN)
# Out:
# Best iteration was number: 98
# which is file:  map_after_iteration\map1015000
# mean_ap: 98.66  FP: 8  FN: 9

# %%
plt.figure(figsize=(30,15))
plt.grid(True)
for key in signal_stat.keys():
    if key is not "summary":
        ap = [float(signal.ap) for signal in signal_stat[key]]
        plt.plot(ap, label="average precision in %")
        
plt.show()
